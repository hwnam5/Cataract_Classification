# %%
# !pip install wget torchinfo
# !wget -O NCT-CRC-HE-100K.zip https://zenodo.org/record/1214456/files/NCT-CRC-HE-100K.zip
# !unzip -qq NCT-CRC-HE-100K.zip -d train
# Out:
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9655 sha256=b11fa087369f01065128d69fdcf05510b27a84325e6bdea658247027e3172f51
#   Stored in directory: /root/.cache/pip/wheels/40/b3/0f/a40dbd1c6861731779f62cc4babcb234387e11d697df70ee97
# Successfully built wget
# Installing collected packages: wget, torchinfo
# Successfully installed torchinfo-1.8.0 wget-3.2
# --2025-05-12 06:38:08--  https://zenodo.org/record/1214456/files/NCT-CRC-HE-100K.zip
# Resolving zenodo.org (zenodo.org)... 188.185.45.92, 188.185.48.194, 188.185.43.25, ...
# Connecting to zenodo.org (zenodo.org)|188.185.45.92|:443... connected.
# HTTP request sent, awaiting response... 301 MOVED PERMANENTLY
# Location: /records/1214456/files/NCT-CRC-HE-100K.zip [following]
# --2025-05-12 06:38:09--  https://zenodo.org/records/1214456/files/NCT-CRC-HE-100K.zip
# Reusing existing connection to zenodo.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 11690284003 (11G) [application/octet-stream]
# Saving to: ‘NCT-CRC-HE-100K.zip’
#
# NCT-CRC-HE-100K.zip 100%[===================>]  10.89G  24.3MB/s    in 11m 33s
#
# 2025-05-12 06:49:42 (16.1 MB/s) - ‘NCT-CRC-HE-100K.zip’ saved [11690284003/11690284003]

# %%
# !pip install peft
# Out:
# Requirement already satisfied: peft in /usr/local/lib/python3.11/dist-packages (0.15.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from peft) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from peft) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from peft) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from peft) (6.0.2)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.11/dist-packages (from peft) (2.6.0+cu124)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (from peft) (4.51.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from peft) (4.67.1)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from peft) (1.6.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.11/dist-packages (from peft) (0.5.3)
# Requirement already satisfied: huggingface_hub>=0.25.0 in /usr/local/lib/python3.11/dist-packages (from peft) (0.30.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface_hub>=0.25.0->peft) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub>=0.25.0->peft) (2025.3.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface_hub>=0.25.0->peft) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub>=0.25.0->peft) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.13.0->peft)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.13.0->peft)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.13.0->peft)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.13.0->peft)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.13.0->peft)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.13.0->peft)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.13.0->peft)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.13.0->peft)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.13.0->peft)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.13.0->peft)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.13.0->peft) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers->peft) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers->peft) (0.21.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.13.0->peft) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub>=0.25.0->peft) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub>=0.25.0->peft) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub>=0.25.0->peft) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub>=0.25.0->peft) (2025.4.26)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 130.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 103.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 65.6 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 11.8 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 44.6 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 19.8 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 3.3 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 109.4 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
# !pip install torchao
# Out:
# Collecting torchao
#   Downloading torchao-0.11.0-cp39-abi3-manylinux_2_28_x86_64.manylinux_2_24_x86_64.whl.metadata (16 kB)
# Downloading torchao-0.11.0-cp39-abi3-manylinux_2_28_x86_64.manylinux_2_24_x86_64.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 52.6 MB/s eta 0:00:00
# Installing collected packages: torchao
# Successfully installed torchao-0.11.0

# %%
# !pip install torchtune
# Out:
# Collecting torchtune
#   Downloading torchtune-0.6.1-py3-none-any.whl.metadata (24 kB)
# Collecting torchdata==0.11.0 (from torchtune)
#   Downloading torchdata-0.11.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting datasets (from torchtune)
#   Downloading datasets-3.6.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: huggingface_hub[hf_transfer] in /usr/local/lib/python3.11/dist-packages (from torchtune) (0.30.2)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.11/dist-packages (from torchtune) (0.5.3)
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.11/dist-packages (from torchtune) (0.3.12)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (from torchtune) (0.2.0)
# Collecting tiktoken (from torchtune)
#   Downloading tiktoken-0.9.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting blobfile>=2 (from torchtune)
#   Downloading blobfile-3.0.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.11/dist-packages (from torchtune) (0.21.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchtune) (2.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from torchtune) (4.67.1)
# Collecting omegaconf (from torchtune)
#   Downloading omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from torchtune) (5.9.5)
# Requirement already satisfied: Pillow>=9.4.0 in /usr/local/lib/python3.11/dist-packages (from torchtune) (11.2.1)
# Requirement already satisfied: urllib3>=1.25 in /usr/local/lib/python3.11/dist-packages (from torchdata==0.11.0->torchtune) (2.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from torchdata==0.11.0->torchtune) (2.32.3)
# Requirement already satisfied: torch>=2 in /usr/local/lib/python3.11/dist-packages (from torchdata==0.11.0->torchtune) (2.6.0+cu124)
# Collecting pycryptodomex>=3.8 (from blobfile>=2->torchtune)
#   Downloading pycryptodomex-3.22.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: lxml>=4.9 in /usr/local/lib/python3.11/dist-packages (from blobfile>=2->torchtune) (5.4.0)
# Requirement already satisfied: filelock>=3.0 in /usr/local/lib/python3.11/dist-packages (from blobfile>=2->torchtune) (3.18.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets->torchtune) (18.1.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets->torchtune)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets->torchtune) (2.2.2)
# Collecting xxhash (from datasets->torchtune)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets->torchtune)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2025.3.0,>=2023.1.0 (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets->torchtune)
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets->torchtune) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets->torchtune) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[hf_transfer]->torchtune) (4.13.2)
# Collecting hf-transfer>=0.1.4 (from huggingface_hub[hf_transfer]->torchtune)
#   Downloading hf_transfer-0.1.9-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting antlr4-python3-runtime==4.9.* (from omegaconf->torchtune)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 5.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.11/dist-packages (from tiktoken->torchtune) (2024.11.6)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets->torchtune) (3.11.15)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->torchdata==0.11.0->torchtune) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->torchdata==0.11.0->torchtune) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->torchdata==0.11.0->torchtune) (2025.4.26)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2->torchdata==0.11.0->torchtune) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2->torchdata==0.11.0->torchtune) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2->torchdata==0.11.0->torchtune) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2->torchdata==0.11.0->torchtune) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2->torchdata==0.11.0->torchtune) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2->torchdata==0.11.0->torchtune) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2->torchdata==0.11.0->torchtune) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2->torchdata==0.11.0->torchtune) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2->torchdata==0.11.0->torchtune) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2->torchdata==0.11.0->torchtune) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2->torchdata==0.11.0->torchtune) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2->torchdata==0.11.0->torchtune) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2->torchdata==0.11.0->torchtune) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2->torchdata==0.11.0->torchtune) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2->torchdata==0.11.0->torchtune) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2->torchdata==0.11.0->torchtune) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2->torchdata==0.11.0->torchtune) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2->torchdata==0.11.0->torchtune) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets->torchtune) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets->torchtune) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets->torchtune) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->torchtune) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->torchtune) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->torchtune) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->torchtune) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->torchtune) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->torchtune) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->torchtune) (1.20.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets->torchtune) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2->torchdata==0.11.0->torchtune) (3.0.2)
# Downloading torchtune-0.6.1-py3-none-any.whl (910 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 910.7/910.7 kB 25.6 MB/s eta 0:00:00
# Downloading torchdata-0.11.0-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 6.1 MB/s eta 0:00:00
# Downloading blobfile-3.0.0-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.4/75.4 kB 7.8 MB/s eta 0:00:00
# Downloading datasets-3.6.0-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 44.2 MB/s eta 0:00:00
# Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 8.5 MB/s eta 0:00:00
# Downloading tiktoken-0.9.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 59.1 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 13.0 MB/s eta 0:00:00
# Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 21.1 MB/s eta 0:00:00
# Downloading hf_transfer-0.1.9-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 112.0 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 15.9 MB/s eta 0:00:00
# Downloading pycryptodomex-3.22.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 98.1 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 20.6 MB/s eta 0:00:00
# Building wheels for collected packages: antlr4-python3-runtime
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=11df09fec2481591e0628014a99ca2fc2377d50c80d653fb87ae63db453e332f
#   Stored in directory: /root/.cache/pip/wheels/1a/97/32/461f837398029ad76911109f07047fde1d7b661a147c7c56d1
# Successfully built antlr4-python3-runtime
# Installing collected packages: antlr4-python3-runtime, xxhash, pycryptodomex, omegaconf, hf-transfer, fsspec, dill, tiktoken, multiprocess, blobfile, torchdata, datasets, torchtune
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.
# Successfully installed antlr4-python3-runtime-4.9.3 blobfile-3.0.0 datasets-3.6.0 dill-0.3.8 fsspec-2025.3.0 hf-transfer-0.1.9 multiprocess-0.70.16 omegaconf-2.3.0 pycryptodomex-3.22.0 tiktoken-0.9.0 torchdata-0.11.0 torchtune-0.6.1 xxhash-3.5.0

# %%
import timm
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, ConcatDataset
from torch.cuda.amp import autocast, GradScaler
import numpy as np
from tqdm import tqdm

import itertools
from torchinfo import summary
from sklearn.metrics import accuracy_score, balanced_accuracy_score, classification_report, confusion_matrix
from PIL import Image

from matplotlib import pyplot as plt

import random
import torchvision.transforms.functional as TF

from sklearn.model_selection import train_test_split
from torch.utils.data import Subset
#import torchtune

# %%
from torchtune.modules.peft import LoRALinear

# %% [markdown]
# ### LoRA Minimum rank 16

# %%
def convert_to_lora_model(model, rank=16, alpha=32, exclude=[]):
    for name, module in model.named_children():
        if name in exclude:
            continue
        if isinstance(module, nn.Linear):
            lora_linear = LoRALinear(
                in_dim=module.in_features,
                out_dim=module.out_features,
                rank=rank,
                alpha=alpha,
                use_bias=module.bias is not None
            )
            lora_linear.weight.data = module.weight.data #모델이 처음부터 다시 학습할 필요 없게 하기 위해
            if module.bias is not None:
                lora_linear.bias.data = module.bias.data
            lora_linear.to(module.weight.device)
            # 기존 linear layer를 loRA linear로 교체체
            setattr(model, name, lora_linear)
        # 재귀함수 (하위모듈도 확인)
        else:
            convert_to_lora_model(module, rank, alpha, exclude)

    return model

# %%
class ConvNorm(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size=3, stride=2, padding=1):
        super(ConvNorm, self).__init__()
        self.linear = nn.Conv2d(
            in_channels, out_channels, kernel_size=kernel_size,
            stride=stride, padding=padding, bias=False
        )
        self.bn = nn.BatchNorm2d(out_channels)

    def forward(self, x):
        x = self.linear(x)
        x = self.bn(x)
        return x

# %%
class Stem16(nn.Module):
    def __init__(self):
        super(Stem16, self).__init__()
        self.conv1 = ConvNorm(3, 32)
        self.act1 = nn.Hardswish()
        self.conv2 = ConvNorm(32, 64)
        self.act2 = nn.Hardswish()
        self.conv3 = ConvNorm(64, 128)
        self.act3 = nn.Hardswish()
        self.conv4 = ConvNorm(128, 256)

    def forward(self, x):
        x = self.act1(self.conv1(x))
        x = self.act2(self.conv2(x))
        x = self.act3(self.conv3(x))
        x = self.conv4(x)
        return x

# %%
class LinearNorm(nn.Module):
    def __init__(self, in_features, out_features):
        super(LinearNorm, self).__init__()
        self.linear = nn.Linear(in_features, out_features, bias=False)
        self.bn = nn.BatchNorm1d(out_features)

    def forward(self, x):

        if x.dim() == 3:
            B, N, C = x.shape
            x = x.reshape(B * N, C)
            x = self.bn(self.linear(x))
            x = x.reshape(B, N, -1)
        else:
            x = self.bn(self.linear(x))
        return x

# %%
class Attention(nn.Module):
    def __init__(self, dim, num_heads, attn_ratio=2):
        super(Attention, self).__init__()
        self.num_heads = num_heads
        head_dim = dim // num_heads
        self.scale = head_dim ** -0.5
        inner_dim = head_dim * num_heads * 3
        self.qkv = LinearNorm(dim, inner_dim)

        self.proj = nn.Sequential(
            nn.Hardswish(),
            LinearNorm(dim, dim)
        )

        self.attention_biases = None
        self.attention_bias_idxs = None

    def compute_attention_bias(self, resolution):

        points = list(itertools.product(range(resolution), range(resolution)))
        N = len(points)

        attention_offsets = {}
        idxs = []

        # if N = 196, then resolution = 14
        for p1 in points:
            for p2 in points:
                offset = (abs(p1[0] - p2[0]), abs(p1[1] - p2[1]))
                if offset not in attention_offsets:
                    attention_offsets[offset] = len(attention_offsets)
                idxs.append(attention_offsets[offset])

        num_offsets = len(attention_offsets)

        # 각 attention head에 대해 num_offsets 만큼의 학습 가능한 Bias를 생성
        self.attention_biases = nn.Parameter(torch.zeros(self.num_heads, num_offsets).to(next(self.parameters()).device))
        self.attention_bias_idxs = torch.LongTensor(idxs).view(N, N).to(next(self.parameters()).device)

    def forward(self, x):
        B, N, C = x.shape
        resolution = int(N ** 0.5)

        if self.attention_biases is None or self.attention_bias_idxs.shape[0] != N:
            self.compute_attention_bias(resolution)

        qkv = self.qkv(x)
        qkv = qkv.view(B, N, 3, self.num_heads, C // self.num_heads).permute(2, 0, 3, 1, 4)
        # qkv: (3, B, num_heads, N, head_dim)
        q, k, v = qkv[0], qkv[1], qkv[2] # q, k, v: (B, num_heads, N, head_dim)

        attn = (q @ k.transpose(-2, -1)) * self.scale # attn: (B, num_heads, N, N)
        attn_bias = self.attention_biases[:, self.attention_bias_idxs].unsqueeze(0) # attn_bias: (1, num_heads, N, N)
        attn = attn + attn_bias
        attn = attn.softmax(dim=-1)

        x = (attn @ v).transpose(1, 2).reshape(B, N, C)
        return self.proj(x)

# %%
class LevitMlp(nn.Module):
    def __init__(self, in_features, hidden_features, out_features):
        super(LevitMlp, self).__init__()
        self.ln1 = LinearNorm(in_features, hidden_features)
        self.act = nn.Hardswish()
        self.drop = nn.Dropout(p=0.5, inplace=False)#dropout 적용
        self.ln2 = LinearNorm(hidden_features, out_features)

    def forward(self, x):
        x = self.ln1(x)
        x = self.act(x)
        x = self.drop(x)
        x = self.ln2(x)
        return x

# %%
class LevitBlock(nn.Module):
    def __init__(self, dim, num_heads, mlp_ratio=2):
        super(LevitBlock, self).__init__()
        self.attn = Attention(dim, num_heads)
        self.drop_path1 = nn.Identity()
        self.mlp = LevitMlp(dim, dim * mlp_ratio, dim)
        self.drop_path2 = nn.Identity()

    def forward(self, x):
        x = x + self.drop_path1(self.attn(x))
        x = x + self.drop_path2(self.mlp(x))
        return x

# %%
class CNNDownsample(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(CNNDownsample, self).__init__()
        self.out_channels = out_channels
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=2, padding=1)
        self.act = nn.Hardswish()

    def forward(self, x):
        # print(x.shape)
        B, N, C = x.shape # (B, N, C)  N=H*W (16 * 16 = 196)
        H = int(np.sqrt(N))
        x = x.view(B, H, H, C).permute(0, 3, 1, 2)
        x = self.conv(x)
        x = self.act(x)
        x = x.permute(0, 2, 3, 1).view(B, -1, self.out_channels)
        return x

# %%
class LevitStage(nn.Module):
    def __init__(self, dim, out_dim, num_heads, num_blocks, downsample=True):
        super(LevitStage, self).__init__()
        self.downsample = CNNDownsample(dim, out_dim) if downsample else nn.Identity()
        self.blocks = nn.Sequential(*[LevitBlock(out_dim, num_heads) for _ in range(num_blocks)])

    def forward(self, x):
        x = self.downsample(x)
        x = self.blocks(x)
        return x

# %%
import torch.nn.functional as F

class LevitStage_TinyFusion(nn.Module):
    def __init__(self, dim, out_dim, num_heads, num_blocks, num_select, downsample=True):
        super(LevitStage_TinyFusion, self).__init__()
        assert num_select <= num_blocks
        self.downsample = CNNDownsample(dim, out_dim) if downsample else nn.Identity()
        self.blocks = nn.Sequential(*[LevitBlock(out_dim, num_heads) for _ in range(num_blocks)])
        self.num_blocks = num_blocks
        self.num_select = num_select
        init_probs = torch.ones(num_blocks) / num_blocks
        self.gumbel_gate = nn.Parameter(torch.log(init_probs))


    def forward(self, x, tau=1):
        x = self.downsample(x)
        gate_probs = F.gumbel_softmax(self.gumbel_gate, tau=tau, hard=False)
        if self.training:
            for i in range(self.num_blocks):
              x = x + gate_probs[i] * self.blocks[i](x)
        else:
            _, topk_indices = torch.topk(gate_probs, self.num_select)
            for i in range(self.num_blocks):
                if i in topk_indices:
                    x = x + self.blocks[i](x)
                else:
                    x = x

            x = x / self.num_select

        return x

# %%
class ConvLevitStage(nn.Module):
    def __init__(self, in_channels, out_channels, num_blocks, kernel_size, stride, padding):
        super(ConvLevitStage, self).__init__()
        self.layers = nn.Sequential(
            *[nn.Conv2d(in_channels if i == 0 else out_channels, out_channels, kernel_size, stride, padding)
              for i in range(num_blocks)],
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        return self.layers(x)

# %%
class NormLinear(nn.Module):
    def __init__(self, in_features, out_features, dropout_prob=0.5):#drop_out_0.5 적용
        super(NormLinear, self).__init__()
        self.bn = nn.BatchNorm1d(in_features)
        self.drop = nn.Dropout(p=dropout_prob, inplace=False)
        self.linear = nn.Linear(in_features, out_features, bias=True)

    def forward(self, x):
        x = self.bn(x)
        x = self.drop(x)
        x = self.linear(x)
        return x

# %%
class LevitDistilledTinyfusion(nn.Module):
    def __init__(self, num_classes=9):
        super(LevitDistilledTinyfusion, self).__init__()

        self.stem = Stem16()

        self.stage1 = LevitStage_TinyFusion(dim=256, out_dim=256, num_heads=4, num_blocks=4, num_select=2, downsample=False) # block 수 적용
        self.stage2 = LevitStage_TinyFusion(dim=256, out_dim=384, num_heads=6, num_blocks=4, num_select=2, downsample=True)

        self.conv1x1 = nn.Sequential(
            nn.Conv2d(384, 512, kernel_size=1, stride=1, padding=0),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True)
        )

        self.head = NormLinear(in_features=512, out_features=num_classes, dropout_prob=0.0)
        self.head_dist = NormLinear(in_features=512, out_features=num_classes, dropout_prob=0.0)

    def forward(self, x, tau):
        x = self.stem(x)

        B, C, H, W = x.shape
        x = x.view(B, C, -1).transpose(1, 2)
        x = self.stage1(x, tau)
        x = self.stage2(x, tau)

        H = W = int(x.shape[1]**0.5)
        x = x.transpose(1, 2).view(B, 384, H, W)

        x = self.conv1x1(x)

        x = torch.mean(x, dim=(2, 3))
        out = self.head(x)
        out_dist = self.head_dist(x)
        return out

# %%
class LevitDistilled(nn.Module):
    def __init__(self, num_classes=9):
        super(LevitDistilled, self).__init__()

        self.stem = Stem16()

        self.stage1 = LevitStage(dim=256, out_dim=256, num_heads=4, num_blocks=4, downsample=False) # block 수 적용
        self.stage2 = LevitStage(dim=256, out_dim=384, num_heads=6, num_blocks=4, downsample=True)

        self.conv1x1 = nn.Sequential(
            nn.Conv2d(384, 512, kernel_size=1, stride=1, padding=0),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True)
        )

        self.head = NormLinear(in_features=512, out_features=num_classes, dropout_prob=0.0)
        self.head_dist = NormLinear(in_features=512, out_features=num_classes, dropout_prob=0.0)

    def forward(self, x):
        x = self.stem(x)

        B, C, H, W = x.shape
        x = x.view(B, C, -1).transpose(1, 2)
        x = self.stage1(x)
        x = self.stage2(x)

        H = W = int(x.shape[1]**0.5)
        x = x.transpose(1, 2).view(B, 384, H, W)

        x = self.conv1x1(x)

        x = torch.mean(x, dim=(2, 3))
        out = self.head(x)
        out_dist = self.head_dist(x)
        return out

# %%
model = LevitDistilledTinyfusion(num_classes=9)
print(model)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

batch_size = 32
learning_rate = 5e-4
num_epochs = 100
# Out:
# LevitDistilledTinyfusion(
#   (stem): Stem16(
#     (conv1): ConvNorm(
#       (linear): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (act1): Hardswish()
#     (conv2): ConvNorm(
#       (linear): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (act2): Hardswish()
#     (conv3): ConvNorm(
#       (linear): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (act3): Hardswish()
#     (conv4): ConvNorm(
#       (linear): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (stage1): LevitStage_TinyFusion(
#     (downsample): Identity()
#     (blocks): Sequential(
#       (0): LevitBlock(
#         (attn): Attention(
#           (qkv): LinearNorm(
#             (linear): Linear(in_features=256, out_features=768, bias=False)
#             (bn): BatchNorm1d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (proj): Sequential(
#             (0): Hardswish()
#             (1): LinearNorm(
#               (linear): Linear(in_features=256, out_features=256, bias=False)
#               (bn): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (drop_path1): Identity()
#         (mlp): LevitMlp(
#           (ln1): LinearNorm(
#             (linear): Linear(in_features=256, out_features=512, bias=False)
#             (bn): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (act): Hardswish()
#           (drop): Dropout(p=0.5, inplace=False)
#           (ln2): LinearNorm(
#             (linear): Linear(in_features=512, out_features=256, bias=False)
#             (bn): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (drop_path2): Identity()
#       )
#       (1): LevitBlock(
#         (attn): Attention(
#           (qkv): LinearNorm(
#             (linear): Linear(in_features=256, out_features=768, bias=False)
#             (bn): BatchNorm1d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (proj): Sequential(
#             (0): Hardswish()
#             (1): LinearNorm(
#               (linear): Linear(in_features=256, out_features=256, bias=False)
#               (bn): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (drop_path1): Identity()
#         (mlp): LevitMlp(
#           (ln1): LinearNorm(
#             (linear): Linear(in_features=256, out_features=512, bias=False)
#             (bn): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (act): Hardswish()
#           (drop): Dropout(p=0.5, inplace=False)
#           (ln2): LinearNorm(
#             (linear): Linear(in_features=512, out_features=256, bias=False)
#             (bn): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (drop_path2): Identity()
#       )
#       (2): LevitBlock(
#         (attn): Attention(
#           (qkv): LinearNorm(
#             (linear): Linear(in_features=256, out_features=768, bias=False)
#             (bn): BatchNorm1d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (proj): Sequential(
#             (0): Hardswish()
#             (1): LinearNorm(
#               (linear): Linear(in_features=256, out_features=256, bias=False)
#               (bn): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (drop_path1): Identity()
#         (mlp): LevitMlp(
#           (ln1): LinearNorm(
#             (linear): Linear(in_features=256, out_features=512, bias=False)
#             (bn): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (act): Hardswish()
#           (drop): Dropout(p=0.5, inplace=False)
#           (ln2): LinearNorm(
#             (linear): Linear(in_features=512, out_features=256, bias=False)
#             (bn): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (drop_path2): Identity()
#       )
#       (3): LevitBlock(
#         (attn): Attention(
#           (qkv): LinearNorm(
#             (linear): Linear(in_features=256, out_features=768, bias=False)
#             (bn): BatchNorm1d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (proj): Sequential(
#             (0): Hardswish()
#             (1): LinearNorm(
#               (linear): Linear(in_features=256, out_features=256, bias=False)
#               (bn): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (drop_path1): Identity()
#         (mlp): LevitMlp(
#           (ln1): LinearNorm(
#             (linear): Linear(in_features=256, out_features=512, bias=False)
#             (bn): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (act): Hardswish()
#           (drop): Dropout(p=0.5, inplace=False)
#           (ln2): LinearNorm(
#             (linear): Linear(in_features=512, out_features=256, bias=False)
#             (bn): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (drop_path2): Identity()
#       )
#     )
#   )
#   (stage2): LevitStage_TinyFusion(
#     (downsample): CNNDownsample(
#       (conv): Conv2d(256, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (act): Hardswish()
#     )
#     (blocks): Sequential(
#       (0): LevitBlock(
#         (attn): Attention(
#           (qkv): LinearNorm(
#             (linear): Linear(in_features=384, out_features=1152, bias=False)
#             (bn): BatchNorm1d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (proj): Sequential(
#             (0): Hardswish()
#             (1): LinearNorm(
#               (linear): Linear(in_features=384, out_features=384, bias=False)
#               (bn): BatchNorm1d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (drop_path1): Identity()
#         (mlp): LevitMlp(
#           (ln1): LinearNorm(
#             (linear): Linear(in_features=384, out_features=768, bias=False)
#             (bn): BatchNorm1d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (act): Hardswish()
#           (drop): Dropout(p=0.5, inplace=False)
#           (ln2): LinearNorm(
#             (linear): Linear(in_features=768, out_features=384, bias=False)
#             (bn): BatchNorm1d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (drop_path2): Identity()
#       )
#       (1): LevitBlock(
#         (attn): Attention(
#           (qkv): LinearNorm(
#             (linear): Linear(in_features=384, out_features=1152, bias=False)
#             (bn): BatchNorm1d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (proj): Sequential(
#             (0): Hardswish()
#             (1): LinearNorm(
#               (linear): Linear(in_features=384, out_features=384, bias=False)
#               (bn): BatchNorm1d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (drop_path1): Identity()
#         (mlp): LevitMlp(
#           (ln1): LinearNorm(
#             (linear): Linear(in_features=384, out_features=768, bias=False)
#             (bn): BatchNorm1d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (act): Hardswish()
#           (drop): Dropout(p=0.5, inplace=False)
#           (ln2): LinearNorm(
#             (linear): Linear(in_features=768, out_features=384, bias=False)
#             (bn): BatchNorm1d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (drop_path2): Identity()
#       )
#       (2): LevitBlock(
#         (attn): Attention(
#           (qkv): LinearNorm(
#             (linear): Linear(in_features=384, out_features=1152, bias=False)
#             (bn): BatchNorm1d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (proj): Sequential(
#             (0): Hardswish()
#             (1): LinearNorm(
#               (linear): Linear(in_features=384, out_features=384, bias=False)
#               (bn): BatchNorm1d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (drop_path1): Identity()
#         (mlp): LevitMlp(
#           (ln1): LinearNorm(
#             (linear): Linear(in_features=384, out_features=768, bias=False)
#             (bn): BatchNorm1d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (act): Hardswish()
#           (drop): Dropout(p=0.5, inplace=False)
#           (ln2): LinearNorm(
#             (linear): Linear(in_features=768, out_features=384, bias=False)
#             (bn): BatchNorm1d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (drop_path2): Identity()
#       )
#       (3): LevitBlock(
#         (attn): Attention(
#           (qkv): LinearNorm(
#             (linear): Linear(in_features=384, out_features=1152, bias=False)
#             (bn): BatchNorm1d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (proj): Sequential(
#             (0): Hardswish()
#             (1): LinearNorm(
#               (linear): Linear(in_features=384, out_features=384, bias=False)
#               (bn): BatchNorm1d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (drop_path1): Identity()
#         (mlp): LevitMlp(
#           (ln1): LinearNorm(
#             (linear): Linear(in_features=384, out_features=768, bias=False)
#             (bn): BatchNorm1d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (act): Hardswish()
#           (drop): Dropout(p=0.5, inplace=False)
#           (ln2): LinearNorm(
#             (linear): Linear(in_features=768, out_features=384, bias=False)
#             (bn): BatchNorm1d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (drop_path2): Identity()
#       )
#     )
#   )
#   (conv1x1): Sequential(
#     (0): Conv2d(384, 512, kernel_size=(1, 1), stride=(1, 1))
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (head): NormLinear(
#     (bn): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (drop): Dropout(p=0.0, inplace=False)
#     (linear): Linear(in_features=512, out_features=9, bias=True)
#   )
#   (head_dist): NormLinear(
#     (bn): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (drop): Dropout(p=0.0, inplace=False)
#     (linear): Linear(in_features=512, out_features=9, bias=True)
#   )
# )

# %%
print(summary(model, input_size=(32, 3, 224, 224), tau = 10))
# Out:
# =========================================================================================================
# Layer (type:depth-idx)                                  Output Shape              Param #
# =========================================================================================================
# LevitDistilledTinyfusion                                [32, 9]                   --
# ├─Stem16: 1-1                                           [32, 256, 14, 14]         --
# │    └─ConvNorm: 2-1                                    [32, 32, 112, 112]        --
# │    │    └─Conv2d: 3-1                                 [32, 32, 112, 112]        864
# │    │    └─BatchNorm2d: 3-2                            [32, 32, 112, 112]        64
# │    └─Hardswish: 2-2                                   [32, 32, 112, 112]        --
# │    └─ConvNorm: 2-3                                    [32, 64, 56, 56]          --
# │    │    └─Conv2d: 3-3                                 [32, 64, 56, 56]          18,432
# │    │    └─BatchNorm2d: 3-4                            [32, 64, 56, 56]          128
# │    └─Hardswish: 2-4                                   [32, 64, 56, 56]          --
# │    └─ConvNorm: 2-5                                    [32, 128, 28, 28]         --
# │    │    └─Conv2d: 3-5                                 [32, 128, 28, 28]         73,728
# │    │    └─BatchNorm2d: 3-6                            [32, 128, 28, 28]         256
# │    └─Hardswish: 2-6                                   [32, 128, 28, 28]         --
# │    └─ConvNorm: 2-7                                    [32, 256, 14, 14]         --
# │    │    └─Conv2d: 3-7                                 [32, 256, 14, 14]         294,912
# │    │    └─BatchNorm2d: 3-8                            [32, 256, 14, 14]         512
# ├─LevitStage_TinyFusion: 1-2                            [32, 196, 256]            --
# │    └─Identity: 2-8                                    [32, 196, 256]            --
# │    └─Sequential: 2-9                                  --                        1,057,312
# │    │    └─LevitBlock: 3-9                             [32, 196, 256]            527,872
# │    │    └─LevitBlock: 3-10                            [32, 196, 256]            527,872
# ├─LevitStage_TinyFusion: 1-3                            [32, 49, 384]             --
# │    └─CNNDownsample: 2-10                              [32, 49, 384]             --
# │    │    └─Conv2d: 3-11                                [32, 384, 7, 7]           885,120
# │    │    └─Hardswish: 3-12                             [32, 384, 7, 7]           --
# │    └─Sequential: 2-11                                 --                        2,370,636
# │    │    └─LevitBlock: 3-13                            [32, 49, 384]             1,185,024
# │    │    └─LevitBlock: 3-14                            [32, 49, 384]             1,185,024
# ├─Sequential: 1-4                                       [32, 512, 7, 7]           --
# │    └─Conv2d: 2-12                                     [32, 512, 7, 7]           197,120
# │    └─BatchNorm2d: 2-13                                [32, 512, 7, 7]           1,024
# │    └─ReLU: 2-14                                       [32, 512, 7, 7]           --
# ├─NormLinear: 1-5                                       [32, 9]                   --
# │    └─BatchNorm1d: 2-15                                [32, 512]                 1,024
# │    └─Dropout: 2-16                                    [32, 512]                 --
# │    └─Linear: 2-17                                     [32, 9]                   4,617
# ├─NormLinear: 1-6                                       [32, 9]                   --
# │    └─BatchNorm1d: 2-18                                [32, 512]                 1,024
# │    └─Dropout: 2-19                                    [32, 512]                 --
# │    └─Linear: 2-20                                     [32, 9]                   4,617
# =========================================================================================================
# Total params: 8,337,182
# Trainable params: 8,337,182
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 17.93
# =========================================================================================================
# Input size (MB): 19.27
# Forward/backward pass size (MB): 897.82
# Params size (MB): 19.64
# Estimated Total Size (MB): 936.72
# =========================================================================================================

# %%
print(summary(model, input_size=(32, 3, 224, 224), verbose=2, tau = 10))
# Out:
# =========================================================================================================
# Layer (type:depth-idx)                                  Output Shape              Param #
# =========================================================================================================
# LevitDistilledTinyfusion                                [32, 9]                   --
# ├─Stem16: 1-1                                           [32, 256, 14, 14]         --
# │    └─conv1.linear.weight                                                        ├─864
# │    └─conv1.bn.weight                                                            ├─32
# │    └─conv1.bn.bias                                                              ├─32
# │    └─conv2.linear.weight                                                        ├─18,432
# │    └─conv2.bn.weight                                                            ├─64
# │    └─conv2.bn.bias                                                              ├─64
# │    └─conv3.linear.weight                                                        ├─73,728
# │    └─conv3.bn.weight                                                            ├─128
# │    └─conv3.bn.bias                                                              ├─128
# │    └─conv4.linear.weight                                                        ├─294,912
# │    └─conv4.bn.weight                                                            ├─256
# │    └─conv4.bn.bias                                                              └─256
# │    └─ConvNorm: 2-1                                    [32, 32, 112, 112]        --
# │    │    └─linear.weight                                                         ├─864
# │    │    └─bn.weight                                                             ├─32
# │    │    └─bn.bias                                                               └─32
# │    │    └─Conv2d: 3-1                                 [32, 32, 112, 112]        864
# │    │    │    └─weight                                                           └─864
# │    │    └─BatchNorm2d: 3-2                            [32, 32, 112, 112]        64
# │    │    │    └─weight                                                           ├─32
# │    │    │    └─bias                                                             └─32
# │    └─Hardswish: 2-2                                   [32, 32, 112, 112]        --
# │    └─ConvNorm: 2-3                                    [32, 64, 56, 56]          --
# │    │    └─linear.weight                                                         ├─18,432
# │    │    └─bn.weight                                                             ├─64
# │    │    └─bn.bias                                                               └─64
# │    │    └─Conv2d: 3-3                                 [32, 64, 56, 56]          18,432
# │    │    │    └─weight                                                           └─18,432
# │    │    └─BatchNorm2d: 3-4                            [32, 64, 56, 56]          128
# │    │    │    └─weight                                                           ├─64
# │    │    │    └─bias                                                             └─64
# │    └─Hardswish: 2-4                                   [32, 64, 56, 56]          --
# │    └─ConvNorm: 2-5                                    [32, 128, 28, 28]         --
# │    │    └─linear.weight                                                         ├─73,728
# │    │    └─bn.weight                                                             ├─128
# │    │    └─bn.bias                                                               └─128
# │    │    └─Conv2d: 3-5                                 [32, 128, 28, 28]         73,728
# │    │    │    └─weight                                                           └─73,728
# │    │    └─BatchNorm2d: 3-6                            [32, 128, 28, 28]         256
# │    │    │    └─weight                                                           ├─128
# │    │    │    └─bias                                                             └─128
# │    └─Hardswish: 2-6                                   [32, 128, 28, 28]         --
# │    └─ConvNorm: 2-7                                    [32, 256, 14, 14]         --
# │    │    └─linear.weight                                                         ├─294,912
# │    │    └─bn.weight                                                             ├─256
# │    │    └─bn.bias                                                               └─256
# │    │    └─Conv2d: 3-7                                 [32, 256, 14, 14]         294,912
# │    │    │    └─weight                                                           └─294,912
# │    │    └─BatchNorm2d: 3-8                            [32, 256, 14, 14]         512
# │    │    │    └─weight                                                           ├─256
# │    │    │    └─bias                                                             └─256
# ├─LevitStage_TinyFusion: 1-2                            [32, 196, 256]            --
# │    └─gumbel_gate                                                                ├─4
# │    └─blocks.0.attn.qkv.linear.weight                                            ├─196,608
# │    └─blocks.0.attn.qkv.bn.weight                                                ├─768
# │    └─blocks.0.attn.qkv.bn.bias                                                  ├─768
# │    └─blocks.0.attn.proj.1.linear.weight                                         ├─65,536
# │    └─blocks.0.attn.proj.1.bn.weight                                             ├─256
# │    └─blocks.0.attn.proj.1.bn.bias                                               ├─256
# │    └─blocks.0.mlp.ln1.linear.weight                                             ├─131,072
# │    └─blocks.0.mlp.ln1.bn.weight                                                 ├─512
# │    └─blocks.0.mlp.ln1.bn.bias                                                   ├─512
# │    └─blocks.0.mlp.ln2.linear.weight                                             ├─131,072
# │    └─blocks.0.mlp.ln2.bn.weight                                                 ├─256
# │    └─blocks.0.mlp.ln2.bn.bias                                                   ├─256
# │    └─blocks.1.attn.attention_biases                                             ├─784
# │    └─blocks.1.attn.qkv.linear.weight                                            ├─196,608
# │    └─blocks.1.attn.qkv.bn.weight                                                ├─768
# │    └─blocks.1.attn.qkv.bn.bias                                                  ├─768
# │    └─blocks.1.attn.proj.1.linear.weight                                         ├─65,536
# │    └─blocks.1.attn.proj.1.bn.weight                                             ├─256
# │    └─blocks.1.attn.proj.1.bn.bias                                               ├─256
# │    └─blocks.1.mlp.ln1.linear.weight                                             ├─131,072
# │    └─blocks.1.mlp.ln1.bn.weight                                                 ├─512
# │    └─blocks.1.mlp.ln1.bn.bias                                                   ├─512
# │    └─blocks.1.mlp.ln2.linear.weight                                             ├─131,072
# │    └─blocks.1.mlp.ln2.bn.weight                                                 ├─256
# │    └─blocks.1.mlp.ln2.bn.bias                                                   ├─256
# │    └─blocks.2.attn.attention_biases                                             ├─784
# │    └─blocks.2.attn.qkv.linear.weight                                            ├─196,608
# │    └─blocks.2.attn.qkv.bn.weight                                                ├─768
# │    └─blocks.2.attn.qkv.bn.bias                                                  ├─768
# │    └─blocks.2.attn.proj.1.linear.weight                                         ├─65,536
# │    └─blocks.2.attn.proj.1.bn.weight                                             ├─256
# │    └─blocks.2.attn.proj.1.bn.bias                                               ├─256
# │    └─blocks.2.mlp.ln1.linear.weight                                             ├─131,072
# │    └─blocks.2.mlp.ln1.bn.weight                                                 ├─512
# │    └─blocks.2.mlp.ln1.bn.bias                                                   ├─512
# │    └─blocks.2.mlp.ln2.linear.weight                                             ├─131,072
# │    └─blocks.2.mlp.ln2.bn.weight                                                 ├─256
# │    └─blocks.2.mlp.ln2.bn.bias                                                   ├─256
# │    └─blocks.3.attn.qkv.linear.weight                                            ├─196,608
# │    └─blocks.3.attn.qkv.bn.weight                                                ├─768
# │    └─blocks.3.attn.qkv.bn.bias                                                  ├─768
# │    └─blocks.3.attn.proj.1.linear.weight                                         ├─65,536
# │    └─blocks.3.attn.proj.1.bn.weight                                             ├─256
# │    └─blocks.3.attn.proj.1.bn.bias                                               ├─256
# │    └─blocks.3.mlp.ln1.linear.weight                                             ├─131,072
# │    └─blocks.3.mlp.ln1.bn.weight                                                 ├─512
# │    └─blocks.3.mlp.ln1.bn.bias                                                   ├─512
# │    └─blocks.3.mlp.ln2.linear.weight                                             ├─131,072
# │    └─blocks.3.mlp.ln2.bn.weight                                                 ├─256
# │    └─blocks.3.mlp.ln2.bn.bias                                                   └─256
# │    └─Identity: 2-8                                    [32, 196, 256]            --
# │    └─Sequential: 2-9                                  --                        1,057,312
# │    │    └─0.attn.attention_biases                                               ├─784
# │    │    └─0.attn.qkv.linear.weight                                              ├─196,608
# │    │    └─0.attn.qkv.bn.weight                                                  ├─768
# │    │    └─0.attn.qkv.bn.bias                                                    ├─768
# │    │    └─0.attn.proj.1.linear.weight                                           ├─65,536
# │    │    └─0.attn.proj.1.bn.weight                                               ├─256
# │    │    └─0.attn.proj.1.bn.bias                                                 ├─256
# │    │    └─0.mlp.ln1.linear.weight                                               ├─131,072
# │    │    └─0.mlp.ln1.bn.weight                                                   ├─512
# │    │    └─0.mlp.ln1.bn.bias                                                     ├─512
# │    │    └─0.mlp.ln2.linear.weight                                               ├─131,072
# │    │    └─0.mlp.ln2.bn.weight                                                   ├─256
# │    │    └─0.mlp.ln2.bn.bias                                                     ├─256
# │    │    └─1.attn.attention_biases                                               ├─784
# │    │    └─1.attn.qkv.linear.weight                                              ├─196,608
# │    │    └─1.attn.qkv.bn.weight                                                  ├─768
# │    │    └─1.attn.qkv.bn.bias                                                    ├─768
# │    │    └─1.attn.proj.1.linear.weight                                           ├─65,536
# │    │    └─1.attn.proj.1.bn.weight                                               ├─256
# │    │    └─1.attn.proj.1.bn.bias                                                 ├─256
# │    │    └─1.mlp.ln1.linear.weight                                               ├─131,072
# │    │    └─1.mlp.ln1.bn.weight                                                   ├─512
# │    │    └─1.mlp.ln1.bn.bias                                                     ├─512
# │    │    └─1.mlp.ln2.linear.weight                                               ├─131,072
# │    │    └─1.mlp.ln2.bn.weight                                                   ├─256
# │    │    └─1.mlp.ln2.bn.bias                                                     ├─256
# │    │    └─2.attn.attention_biases                                               ├─784
# │    │    └─2.attn.qkv.linear.weight                                              ├─196,608
# │    │    └─2.attn.qkv.bn.weight                                                  ├─768
# │    │    └─2.attn.qkv.bn.bias                                                    ├─768
# │    │    └─2.attn.proj.1.linear.weight                                           ├─65,536
# │    │    └─2.attn.proj.1.bn.weight                                               ├─256
# │    │    └─2.attn.proj.1.bn.bias                                                 ├─256
# │    │    └─2.mlp.ln1.linear.weight                                               ├─131,072
# │    │    └─2.mlp.ln1.bn.weight                                                   ├─512
# │    │    └─2.mlp.ln1.bn.bias                                                     ├─512
# │    │    └─2.mlp.ln2.linear.weight                                               ├─131,072
# │    │    └─2.mlp.ln2.bn.weight                                                   ├─256
# │    │    └─2.mlp.ln2.bn.bias                                                     ├─256
# │    │    └─3.attn.qkv.linear.weight                                              ├─196,608
# │    │    └─3.attn.qkv.bn.weight                                                  ├─768
# │    │    └─3.attn.qkv.bn.bias                                                    ├─768
# │    │    └─3.attn.proj.1.linear.weight                                           ├─65,536
# │    │    └─3.attn.proj.1.bn.weight                                               ├─256
# │    │    └─3.attn.proj.1.bn.bias                                                 ├─256
# │    │    └─3.mlp.ln1.linear.weight                                               ├─131,072
# │    │    └─3.mlp.ln1.bn.weight                                                   ├─512
# │    │    └─3.mlp.ln1.bn.bias                                                     ├─512
# │    │    └─3.mlp.ln2.linear.weight                                               ├─131,072
# │    │    └─3.mlp.ln2.bn.weight                                                   ├─256
# │    │    └─3.mlp.ln2.bn.bias                                                     └─256
# │    │    └─LevitBlock: 3-9                             [32, 196, 256]            527,872
# │    │    │    └─attn.qkv.linear.weight                                           ├─196,608
# │    │    │    └─attn.qkv.bn.weight                                               ├─768
# │    │    │    └─attn.qkv.bn.bias                                                 ├─768
# │    │    │    └─attn.proj.1.linear.weight                                        ├─65,536
# │    │    │    └─attn.proj.1.bn.weight                                            ├─256
# │    │    │    └─attn.proj.1.bn.bias                                              ├─256
# │    │    │    └─mlp.ln1.linear.weight                                            ├─131,072
# │    │    │    └─mlp.ln1.bn.weight                                                ├─512
# │    │    │    └─mlp.ln1.bn.bias                                                  ├─512
# │    │    │    └─mlp.ln2.linear.weight                                            ├─131,072
# │    │    │    └─mlp.ln2.bn.weight                                                ├─256
# │    │    │    └─mlp.ln2.bn.bias                                                  └─256
# │    │    └─LevitBlock: 3-10                            [32, 196, 256]            528,656
# │    │    │    └─attn.attention_biases                                            ├─784
# │    │    │    └─attn.qkv.linear.weight                                           ├─196,608
# │    │    │    └─attn.qkv.bn.weight                                               ├─768
# │    │    │    └─attn.qkv.bn.bias                                                 ├─768
# │    │    │    └─attn.proj.1.linear.weight                                        ├─65,536
# │    │    │    └─attn.proj.1.bn.weight                                            ├─256
# │    │    │    └─attn.proj.1.bn.bias                                              ├─256
# │    │    │    └─mlp.ln1.linear.weight                                            ├─131,072
# │    │    │    └─mlp.ln1.bn.weight                                                ├─512
# │    │    │    └─mlp.ln1.bn.bias                                                  ├─512
# │    │    │    └─mlp.ln2.linear.weight                                            ├─131,072
# │    │    │    └─mlp.ln2.bn.weight                                                ├─256
# │    │    │    └─mlp.ln2.bn.bias                                                  └─256
# ├─LevitStage_TinyFusion: 1-3                            [32, 49, 384]             --
# │    └─gumbel_gate                                                                ├─4
# │    └─downsample.conv.weight                                                     ├─884,736
# │    └─downsample.conv.bias                                                       ├─384
# │    └─blocks.0.attn.qkv.linear.weight                                            ├─442,368
# │    └─blocks.0.attn.qkv.bn.weight                                                ├─1,152
# │    └─blocks.0.attn.qkv.bn.bias                                                  ├─1,152
# │    └─blocks.0.attn.proj.1.linear.weight                                         ├─147,456
# │    └─blocks.0.attn.proj.1.bn.weight                                             ├─384
# │    └─blocks.0.attn.proj.1.bn.bias                                               ├─384
# │    └─blocks.0.mlp.ln1.linear.weight                                             ├─294,912
# │    └─blocks.0.mlp.ln1.bn.weight                                                 ├─768
# │    └─blocks.0.mlp.ln1.bn.bias                                                   ├─768
# │    └─blocks.0.mlp.ln2.linear.weight                                             ├─294,912
# │    └─blocks.0.mlp.ln2.bn.weight                                                 ├─384
# │    └─blocks.0.mlp.ln2.bn.bias                                                   ├─384
# │    └─blocks.1.attn.attention_biases                                             ├─294
# │    └─blocks.1.attn.qkv.linear.weight                                            ├─442,368
# │    └─blocks.1.attn.qkv.bn.weight                                                ├─1,152
# │    └─blocks.1.attn.qkv.bn.bias                                                  ├─1,152
# │    └─blocks.1.attn.proj.1.linear.weight                                         ├─147,456
# │    └─blocks.1.attn.proj.1.bn.weight                                             ├─384
# │    └─blocks.1.attn.proj.1.bn.bias                                               ├─384
# │    └─blocks.1.mlp.ln1.linear.weight                                             ├─294,912
# │    └─blocks.1.mlp.ln1.bn.weight                                                 ├─768
# │    └─blocks.1.mlp.ln1.bn.bias                                                   ├─768
# │    └─blocks.1.mlp.ln2.linear.weight                                             ├─294,912
# │    └─blocks.1.mlp.ln2.bn.weight                                                 ├─384
# │    └─blocks.1.mlp.ln2.bn.bias                                                   ├─384
# │    └─blocks.2.attn.attention_biases                                             ├─294
# │    └─blocks.2.attn.qkv.linear.weight                                            ├─442,368
# │    └─blocks.2.attn.qkv.bn.weight                                                ├─1,152
# │    └─blocks.2.attn.qkv.bn.bias                                                  ├─1,152
# │    └─blocks.2.attn.proj.1.linear.weight                                         ├─147,456
# │    └─blocks.2.attn.proj.1.bn.weight                                             ├─384
# │    └─blocks.2.attn.proj.1.bn.bias                                               ├─384
# │    └─blocks.2.mlp.ln1.linear.weight                                             ├─294,912
# │    └─blocks.2.mlp.ln1.bn.weight                                                 ├─768
# │    └─blocks.2.mlp.ln1.bn.bias                                                   ├─768
# │    └─blocks.2.mlp.ln2.linear.weight                                             ├─294,912
# │    └─blocks.2.mlp.ln2.bn.weight                                                 ├─384
# │    └─blocks.2.mlp.ln2.bn.bias                                                   ├─384
# │    └─blocks.3.attn.qkv.linear.weight                                            ├─442,368
# │    └─blocks.3.attn.qkv.bn.weight                                                ├─1,152
# │    └─blocks.3.attn.qkv.bn.bias                                                  ├─1,152
# │    └─blocks.3.attn.proj.1.linear.weight                                         ├─147,456
# │    └─blocks.3.attn.proj.1.bn.weight                                             ├─384
# │    └─blocks.3.attn.proj.1.bn.bias                                               ├─384
# │    └─blocks.3.mlp.ln1.linear.weight                                             ├─294,912
# │    └─blocks.3.mlp.ln1.bn.weight                                                 ├─768
# │    └─blocks.3.mlp.ln1.bn.bias                                                   ├─768
# │    └─blocks.3.mlp.ln2.linear.weight                                             ├─294,912
# │    └─blocks.3.mlp.ln2.bn.weight                                                 ├─384
# │    └─blocks.3.mlp.ln2.bn.bias                                                   └─384
# │    └─CNNDownsample: 2-10                              [32, 49, 384]             --
# │    │    └─conv.weight                                                           ├─884,736
# │    │    └─conv.bias                                                             └─384
# │    │    └─Conv2d: 3-11                                [32, 384, 7, 7]           885,120
# │    │    │    └─weight                                                           ├─884,736
# │    │    │    └─bias                                                             └─384
# │    │    └─Hardswish: 3-12                             [32, 384, 7, 7]           --
# │    └─Sequential: 2-11                                 --                        2,370,636
# │    │    └─0.attn.attention_biases                                               ├─294
# │    │    └─0.attn.qkv.linear.weight                                              ├─442,368
# │    │    └─0.attn.qkv.bn.weight                                                  ├─1,152
# │    │    └─0.attn.qkv.bn.bias                                                    ├─1,152
# │    │    └─0.attn.proj.1.linear.weight                                           ├─147,456
# │    │    └─0.attn.proj.1.bn.weight                                               ├─384
# │    │    └─0.attn.proj.1.bn.bias                                                 ├─384
# │    │    └─0.mlp.ln1.linear.weight                                               ├─294,912
# │    │    └─0.mlp.ln1.bn.weight                                                   ├─768
# │    │    └─0.mlp.ln1.bn.bias                                                     ├─768
# │    │    └─0.mlp.ln2.linear.weight                                               ├─294,912
# │    │    └─0.mlp.ln2.bn.weight                                                   ├─384
# │    │    └─0.mlp.ln2.bn.bias                                                     ├─384
# │    │    └─1.attn.attention_biases                                               ├─294
# │    │    └─1.attn.qkv.linear.weight                                              ├─442,368
# │    │    └─1.attn.qkv.bn.weight                                                  ├─1,152
# │    │    └─1.attn.qkv.bn.bias                                                    ├─1,152
# │    │    └─1.attn.proj.1.linear.weight                                           ├─147,456
# │    │    └─1.attn.proj.1.bn.weight                                               ├─384
# │    │    └─1.attn.proj.1.bn.bias                                                 ├─384
# │    │    └─1.mlp.ln1.linear.weight                                               ├─294,912
# │    │    └─1.mlp.ln1.bn.weight                                                   ├─768
# │    │    └─1.mlp.ln1.bn.bias                                                     ├─768
# │    │    └─1.mlp.ln2.linear.weight                                               ├─294,912
# │    │    └─1.mlp.ln2.bn.weight                                                   ├─384
# │    │    └─1.mlp.ln2.bn.bias                                                     ├─384
# │    │    └─2.attn.attention_biases                                               ├─294
# │    │    └─2.attn.qkv.linear.weight                                              ├─442,368
# │    │    └─2.attn.qkv.bn.weight                                                  ├─1,152
# │    │    └─2.attn.qkv.bn.bias                                                    ├─1,152
# │    │    └─2.attn.proj.1.linear.weight                                           ├─147,456
# │    │    └─2.attn.proj.1.bn.weight                                               ├─384
# │    │    └─2.attn.proj.1.bn.bias                                                 ├─384
# │    │    └─2.mlp.ln1.linear.weight                                               ├─294,912
# │    │    └─2.mlp.ln1.bn.weight                                                   ├─768
# │    │    └─2.mlp.ln1.bn.bias                                                     ├─768
# │    │    └─2.mlp.ln2.linear.weight                                               ├─294,912
# │    │    └─2.mlp.ln2.bn.weight                                                   ├─384
# │    │    └─2.mlp.ln2.bn.bias                                                     ├─384
# │    │    └─3.attn.qkv.linear.weight                                              ├─442,368
# │    │    └─3.attn.qkv.bn.weight                                                  ├─1,152
# │    │    └─3.attn.qkv.bn.bias                                                    ├─1,152
# │    │    └─3.attn.proj.1.linear.weight                                           ├─147,456
# │    │    └─3.attn.proj.1.bn.weight                                               ├─384
# │    │    └─3.attn.proj.1.bn.bias                                                 ├─384
# │    │    └─3.mlp.ln1.linear.weight                                               ├─294,912
# │    │    └─3.mlp.ln1.bn.weight                                                   ├─768
# │    │    └─3.mlp.ln1.bn.bias                                                     ├─768
# │    │    └─3.mlp.ln2.linear.weight                                               ├─294,912
# │    │    └─3.mlp.ln2.bn.weight                                                   ├─384
# │    │    └─3.mlp.ln2.bn.bias                                                     └─384
# │    │    └─LevitBlock: 3-13                            [32, 49, 384]             1,185,024
# │    │    │    └─attn.qkv.linear.weight                                           ├─442,368
# │    │    │    └─attn.qkv.bn.weight                                               ├─1,152
# │    │    │    └─attn.qkv.bn.bias                                                 ├─1,152
# │    │    │    └─attn.proj.1.linear.weight                                        ├─147,456
# │    │    │    └─attn.proj.1.bn.weight                                            ├─384
# │    │    │    └─attn.proj.1.bn.bias                                              ├─384
# │    │    │    └─mlp.ln1.linear.weight                                            ├─294,912
# │    │    │    └─mlp.ln1.bn.weight                                                ├─768
# │    │    │    └─mlp.ln1.bn.bias                                                  ├─768
# │    │    │    └─mlp.ln2.linear.weight                                            ├─294,912
# │    │    │    └─mlp.ln2.bn.weight                                                ├─384
# │    │    │    └─mlp.ln2.bn.bias                                                  └─384
# │    │    └─LevitBlock: 3-14                            [32, 49, 384]             1,185,318
# │    │    │    └─attn.attention_biases                                            ├─294
# │    │    │    └─attn.qkv.linear.weight                                           ├─442,368
# │    │    │    └─attn.qkv.bn.weight                                               ├─1,152
# │    │    │    └─attn.qkv.bn.bias                                                 ├─1,152
# │    │    │    └─attn.proj.1.linear.weight                                        ├─147,456
# │    │    │    └─attn.proj.1.bn.weight                                            ├─384
# │    │    │    └─attn.proj.1.bn.bias                                              ├─384
# │    │    │    └─mlp.ln1.linear.weight                                            ├─294,912
# │    │    │    └─mlp.ln1.bn.weight                                                ├─768
# │    │    │    └─mlp.ln1.bn.bias                                                  ├─768
# │    │    │    └─mlp.ln2.linear.weight                                            ├─294,912
# │    │    │    └─mlp.ln2.bn.weight                                                ├─384
# │    │    │    └─mlp.ln2.bn.bias                                                  └─384
# ├─Sequential: 1-4                                       [32, 512, 7, 7]           --
# │    └─0.weight                                                                   ├─196,608
# │    └─0.bias                                                                     ├─512
# │    └─1.weight                                                                   ├─512
# │    └─1.bias                                                                     └─512
# │    └─Conv2d: 2-12                                     [32, 512, 7, 7]           197,120
# │    │    └─weight                                                                ├─196,608
# │    │    └─bias                                                                  └─512
# │    └─BatchNorm2d: 2-13                                [32, 512, 7, 7]           1,024
# │    │    └─weight                                                                ├─512
# │    │    └─bias                                                                  └─512
# │    └─ReLU: 2-14                                       [32, 512, 7, 7]           --
# ├─NormLinear: 1-5                                       [32, 9]                   --
# │    └─bn.weight                                                                  ├─512
# │    └─bn.bias                                                                    ├─512
# │    └─linear.weight                                                              ├─4,608
# │    └─linear.bias                                                                └─9
# │    └─BatchNorm1d: 2-15                                [32, 512]                 1,024
# │    │    └─weight                                                                ├─512
# │    │    └─bias                                                                  └─512
# │    └─Dropout: 2-16                                    [32, 512]                 --
# │    └─Linear: 2-17                                     [32, 9]                   4,617
# │    │    └─weight                                                                ├─4,608
# │    │    └─bias                                                                  └─9
# ├─NormLinear: 1-6                                       [32, 9]                   --
# │    └─bn.weight                                                                  ├─512
# │    └─bn.bias                                                                    ├─512
# │    └─linear.weight                                                              ├─4,608
# │    └─linear.bias                                                                └─9
# │    └─BatchNorm1d: 2-18                                [32, 512]                 1,024
# │    │    └─weight                                                                ├─512
# │    │    └─bias                                                                  └─512
# │    └─Dropout: 2-19                                    [32, 512]                 --
# │    └─Linear: 2-20                                     [32, 9]                   4,617
# │    │    └─weight                                                                ├─4,608
# │    │    └─bias                                                                  └─9
# =========================================================================================================
# Total params: 8,338,260
# Trainable params: 8,338,260
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 17.93
# =========================================================================================================
# Input size (MB): 19.27
# Forward/backward pass size (MB): 897.82
# Params size (MB): 19.64
# Estimated Total Size (MB): 936.72
# =========================================================================================================
# =========================================================================================================
# Layer (type:depth-idx)                                  Output Shape              Param #
# =========================================================================================================
# LevitDistilledTinyfusion                                [32, 9]                   --
# ├─Stem16: 1-1                                           [32, 256, 14, 14]         --
# │    └─conv1.linear.weight                                                        ├─864
# │    └─conv1.bn.weight                                                            ├─32
# │    └─conv1.bn.bias                                                              ├─32
# │    └─conv2.linear.weight                                                        ├─18,432
# │    └─conv2.bn.weight                                                            ├─64
# │    └─conv2.bn.bias                                                              ├─64
# │    └─conv3.linear.weight                                                        ├─73,728
# │    └─conv3.bn.weight                                                            ├─128
# │    └─conv3.bn.bias                                                              ├─128
# │    └─conv4.linear.weight                                                        ├─294,912
# │    └─conv4.bn.weight                                                            ├─256
# │    └─conv4.bn.bias                                                              └─256
# │    └─ConvNorm: 2-1                                    [32, 32, 112, 112]        --
# │    │    └─linear.weight                                                         ├─864
# │    │    └─bn.weight                                                             ├─32
# │    │    └─bn.bias                                                               └─32
# │    │    └─Conv2d: 3-1                                 [32, 32, 112, 112]        864
# │    │    │    └─weight                                                           └─864
# │    │    └─BatchNorm2d: 3-2                            [32, 32, 112, 112]        64
# │    │    │    └─weight                                                           ├─32
# │    │    │    └─bias                                                             └─32
# │    └─Hardswish: 2-2                                   [32, 32, 112, 112]        --
# │    └─ConvNorm: 2-3                                    [32, 64, 56, 56]          --
# │    │    └─linear.weight                                                         ├─18,432
# │    │    └─bn.weight                                                             ├─64
# │    │    └─bn.bias                                                               └─64
# │    │    └─Conv2d: 3-3                                 [32, 64, 56, 56]          18,432
# │    │    │    └─weight                                                           └─18,432
# │    │    └─BatchNorm2d: 3-4                            [32, 64, 56, 56]          128
# │    │    │    └─weight                                                           ├─64
# │    │    │    └─bias                                                             └─64
# │    └─Hardswish: 2-4                                   [32, 64, 56, 56]          --
# │    └─ConvNorm: 2-5                                    [32, 128, 28, 28]         --
# │    │    └─linear.weight                                                         ├─73,728
# │    │    └─bn.weight                                                             ├─128
# │    │    └─bn.bias                                                               └─128
# │    │    └─Conv2d: 3-5                                 [32, 128, 28, 28]         73,728
# │    │    │    └─weight                                                           └─73,728
# │    │    └─BatchNorm2d: 3-6                            [32, 128, 28, 28]         256
# │    │    │    └─weight                                                           ├─128
# │    │    │    └─bias                                                             └─128
# │    └─Hardswish: 2-6                                   [32, 128, 28, 28]         --
# │    └─ConvNorm: 2-7                                    [32, 256, 14, 14]         --
# │    │    └─linear.weight                                                         ├─294,912
# │    │    └─bn.weight                                                             ├─256
# │    │    └─bn.bias                                                               └─256
# │    │    └─Conv2d: 3-7                                 [32, 256, 14, 14]         294,912
# │    │    │    └─weight                                                           └─294,912
# │    │    └─BatchNorm2d: 3-8                            [32, 256, 14, 14]         512
# │    │    │    └─weight                                                           ├─256
# │    │    │    └─bias                                                             └─256
# ├─LevitStage_TinyFusion: 1-2                            [32, 196, 256]            --
# │    └─gumbel_gate                                                                ├─4
# │    └─blocks.0.attn.qkv.linear.weight                                            ├─196,608
# │    └─blocks.0.attn.qkv.bn.weight                                                ├─768
# │    └─blocks.0.attn.qkv.bn.bias                                                  ├─768
# │    └─blocks.0.attn.proj.1.linear.weight                                         ├─65,536
# │    └─blocks.0.attn.proj.1.bn.weight                                             ├─256
# │    └─blocks.0.attn.proj.1.bn.bias                                               ├─256
# │    └─blocks.0.mlp.ln1.linear.weight                                             ├─131,072
# │    └─blocks.0.mlp.ln1.bn.weight                                                 ├─512
# │    └─blocks.0.mlp.ln1.bn.bias                                                   ├─512
# │    └─blocks.0.mlp.ln2.linear.weight                                             ├─131,072
# │    └─blocks.0.mlp.ln2.bn.weight                                                 ├─256
# │    └─blocks.0.mlp.ln2.bn.bias                                                   ├─256
# │    └─blocks.1.attn.attention_biases                                             ├─784
# │    └─blocks.1.attn.qkv.linear.weight                                            ├─196,608
# │    └─blocks.1.attn.qkv.bn.weight                                                ├─768
# │    └─blocks.1.attn.qkv.bn.bias                                                  ├─768
# │    └─blocks.1.attn.proj.1.linear.weight                                         ├─65,536
# │    └─blocks.1.attn.proj.1.bn.weight                                             ├─256
# │    └─blocks.1.attn.proj.1.bn.bias                                               ├─256
# │    └─blocks.1.mlp.ln1.linear.weight                                             ├─131,072
# │    └─blocks.1.mlp.ln1.bn.weight                                                 ├─512
# │    └─blocks.1.mlp.ln1.bn.bias                                                   ├─512
# │    └─blocks.1.mlp.ln2.linear.weight                                             ├─131,072
# │    └─blocks.1.mlp.ln2.bn.weight                                                 ├─256
# │    └─blocks.1.mlp.ln2.bn.bias                                                   ├─256
# │    └─blocks.2.attn.attention_biases                                             ├─784
# │    └─blocks.2.attn.qkv.linear.weight                                            ├─196,608
# │    └─blocks.2.attn.qkv.bn.weight                                                ├─768
# │    └─blocks.2.attn.qkv.bn.bias                                                  ├─768
# │    └─blocks.2.attn.proj.1.linear.weight                                         ├─65,536
# │    └─blocks.2.attn.proj.1.bn.weight                                             ├─256
# │    └─blocks.2.attn.proj.1.bn.bias                                               ├─256
# │    └─blocks.2.mlp.ln1.linear.weight                                             ├─131,072
# │    └─blocks.2.mlp.ln1.bn.weight                                                 ├─512
# │    └─blocks.2.mlp.ln1.bn.bias                                                   ├─512
# │    └─blocks.2.mlp.ln2.linear.weight                                             ├─131,072
# │    └─blocks.2.mlp.ln2.bn.weight                                                 ├─256
# │    └─blocks.2.mlp.ln2.bn.bias                                                   ├─256
# │    └─blocks.3.attn.qkv.linear.weight                                            ├─196,608
# │    └─blocks.3.attn.qkv.bn.weight                                                ├─768
# │    └─blocks.3.attn.qkv.bn.bias                                                  ├─768
# │    └─blocks.3.attn.proj.1.linear.weight                                         ├─65,536
# │    └─blocks.3.attn.proj.1.bn.weight                                             ├─256
# │    └─blocks.3.attn.proj.1.bn.bias                                               ├─256
# │    └─blocks.3.mlp.ln1.linear.weight                                             ├─131,072
# │    └─blocks.3.mlp.ln1.bn.weight                                                 ├─512
# │    └─blocks.3.mlp.ln1.bn.bias                                                   ├─512
# │    └─blocks.3.mlp.ln2.linear.weight                                             ├─131,072
# │    └─blocks.3.mlp.ln2.bn.weight                                                 ├─256
# │    └─blocks.3.mlp.ln2.bn.bias                                                   └─256
# │    └─Identity: 2-8                                    [32, 196, 256]            --
# │    └─Sequential: 2-9                                  --                        1,057,312
# │    │    └─0.attn.attention_biases                                               ├─784
# │    │    └─0.attn.qkv.linear.weight                                              ├─196,608
# │    │    └─0.attn.qkv.bn.weight                                                  ├─768
# │    │    └─0.attn.qkv.bn.bias                                                    ├─768
# │    │    └─0.attn.proj.1.linear.weight                                           ├─65,536
# │    │    └─0.attn.proj.1.bn.weight                                               ├─256
# │    │    └─0.attn.proj.1.bn.bias                                                 ├─256
# │    │    └─0.mlp.ln1.linear.weight                                               ├─131,072
# │    │    └─0.mlp.ln1.bn.weight                                                   ├─512
# │    │    └─0.mlp.ln1.bn.bias                                                     ├─512
# │    │    └─0.mlp.ln2.linear.weight                                               ├─131,072
# │    │    └─0.mlp.ln2.bn.weight                                                   ├─256
# │    │    └─0.mlp.ln2.bn.bias                                                     ├─256
# │    │    └─1.attn.attention_biases                                               ├─784
# │    │    └─1.attn.qkv.linear.weight                                              ├─196,608
# │    │    └─1.attn.qkv.bn.weight                                                  ├─768
# │    │    └─1.attn.qkv.bn.bias                                                    ├─768
# │    │    └─1.attn.proj.1.linear.weight                                           ├─65,536
# │    │    └─1.attn.proj.1.bn.weight                                               ├─256
# │    │    └─1.attn.proj.1.bn.bias                                                 ├─256
# │    │    └─1.mlp.ln1.linear.weight                                               ├─131,072
# │    │    └─1.mlp.ln1.bn.weight                                                   ├─512
# │    │    └─1.mlp.ln1.bn.bias                                                     ├─512
# │    │    └─1.mlp.ln2.linear.weight                                               ├─131,072
# │    │    └─1.mlp.ln2.bn.weight                                                   ├─256
# │    │    └─1.mlp.ln2.bn.bias                                                     ├─256
# │    │    └─2.attn.attention_biases                                               ├─784
# │    │    └─2.attn.qkv.linear.weight                                              ├─196,608
# │    │    └─2.attn.qkv.bn.weight                                                  ├─768
# │    │    └─2.attn.qkv.bn.bias                                                    ├─768
# │    │    └─2.attn.proj.1.linear.weight                                           ├─65,536
# │    │    └─2.attn.proj.1.bn.weight                                               ├─256
# │    │    └─2.attn.proj.1.bn.bias                                                 ├─256
# │    │    └─2.mlp.ln1.linear.weight                                               ├─131,072
# │    │    └─2.mlp.ln1.bn.weight                                                   ├─512
# │    │    └─2.mlp.ln1.bn.bias                                                     ├─512
# │    │    └─2.mlp.ln2.linear.weight                                               ├─131,072
# │    │    └─2.mlp.ln2.bn.weight                                                   ├─256
# │    │    └─2.mlp.ln2.bn.bias                                                     ├─256
# │    │    └─3.attn.qkv.linear.weight                                              ├─196,608
# │    │    └─3.attn.qkv.bn.weight                                                  ├─768
# │    │    └─3.attn.qkv.bn.bias                                                    ├─768
# │    │    └─3.attn.proj.1.linear.weight                                           ├─65,536
# │    │    └─3.attn.proj.1.bn.weight                                               ├─256
# │    │    └─3.attn.proj.1.bn.bias                                                 ├─256
# │    │    └─3.mlp.ln1.linear.weight                                               ├─131,072
# │    │    └─3.mlp.ln1.bn.weight                                                   ├─512
# │    │    └─3.mlp.ln1.bn.bias                                                     ├─512
# │    │    └─3.mlp.ln2.linear.weight                                               ├─131,072
# │    │    └─3.mlp.ln2.bn.weight                                                   ├─256
# │    │    └─3.mlp.ln2.bn.bias                                                     └─256
# │    │    └─LevitBlock: 3-9                             [32, 196, 256]            527,872
# │    │    │    └─attn.qkv.linear.weight                                           ├─196,608
# │    │    │    └─attn.qkv.bn.weight                                               ├─768
# │    │    │    └─attn.qkv.bn.bias                                                 ├─768
# │    │    │    └─attn.proj.1.linear.weight                                        ├─65,536
# │    │    │    └─attn.proj.1.bn.weight                                            ├─256
# │    │    │    └─attn.proj.1.bn.bias                                              ├─256
# │    │    │    └─mlp.ln1.linear.weight                                            ├─131,072
# ...
# │    └─downsample.conv.bias                                                       ├─384
# │    └─blocks.0.attn.qkv.linear.weight                                            ├─442,368
# │    └─blocks.0.attn.qkv.bn.weight                                                ├─1,152
# │    └─blocks.0.attn.qkv.bn.bias                                                  ├─1,152
# │    └─blocks.0.attn.proj.1.linear.weight                                         ├─147,456
# │    └─blocks.0.attn.proj.1.bn.weight                                             ├─384
# │    └─blocks.0.attn.proj.1.bn.bias                                               ├─384
# │    └─blocks.0.mlp.ln1.linear.weight                                             ├─294,912
# │    └─blocks.0.mlp.ln1.bn.weight                                                 ├─768
# │    └─blocks.0.mlp.ln1.bn.bias                                                   ├─768
# │    └─blocks.0.mlp.ln2.linear.weight                                             ├─294,912
# │    └─blocks.0.mlp.ln2.bn.weight                                                 ├─384
# │    └─blocks.0.mlp.ln2.bn.bias                                                   ├─384
# │    └─blocks.1.attn.attention_biases                                             ├─294
# │    └─blocks.1.attn.qkv.linear.weight                                            ├─442,368
# │    └─blocks.1.attn.qkv.bn.weight                                                ├─1,152
# │    └─blocks.1.attn.qkv.bn.bias                                                  ├─1,152
# │    └─blocks.1.attn.proj.1.linear.weight                                         ├─147,456
# │    └─blocks.1.attn.proj.1.bn.weight                                             ├─384
# │    └─blocks.1.attn.proj.1.bn.bias                                               ├─384
# │    └─blocks.1.mlp.ln1.linear.weight                                             ├─294,912
# │    └─blocks.1.mlp.ln1.bn.weight                                                 ├─768
# │    └─blocks.1.mlp.ln1.bn.bias                                                   ├─768
# │    └─blocks.1.mlp.ln2.linear.weight                                             ├─294,912
# │    └─blocks.1.mlp.ln2.bn.weight                                                 ├─384
# │    └─blocks.1.mlp.ln2.bn.bias                                                   ├─384
# │    └─blocks.2.attn.attention_biases                                             ├─294
# │    └─blocks.2.attn.qkv.linear.weight                                            ├─442,368
# │    └─blocks.2.attn.qkv.bn.weight                                                ├─1,152
# │    └─blocks.2.attn.qkv.bn.bias                                                  ├─1,152
# │    └─blocks.2.attn.proj.1.linear.weight                                         ├─147,456
# │    └─blocks.2.attn.proj.1.bn.weight                                             ├─384
# │    └─blocks.2.attn.proj.1.bn.bias                                               ├─384
# │    └─blocks.2.mlp.ln1.linear.weight                                             ├─294,912
# │    └─blocks.2.mlp.ln1.bn.weight                                                 ├─768
# │    └─blocks.2.mlp.ln1.bn.bias                                                   ├─768
# │    └─blocks.2.mlp.ln2.linear.weight                                             ├─294,912
# │    └─blocks.2.mlp.ln2.bn.weight                                                 ├─384
# │    └─blocks.2.mlp.ln2.bn.bias                                                   ├─384
# │    └─blocks.3.attn.qkv.linear.weight                                            ├─442,368
# │    └─blocks.3.attn.qkv.bn.weight                                                ├─1,152
# │    └─blocks.3.attn.qkv.bn.bias                                                  ├─1,152
# │    └─blocks.3.attn.proj.1.linear.weight                                         ├─147,456
# │    └─blocks.3.attn.proj.1.bn.weight                                             ├─384
# │    └─blocks.3.attn.proj.1.bn.bias                                               ├─384
# │    └─blocks.3.mlp.ln1.linear.weight                                             ├─294,912
# │    └─blocks.3.mlp.ln1.bn.weight                                                 ├─768
# │    └─blocks.3.mlp.ln1.bn.bias                                                   ├─768
# │    └─blocks.3.mlp.ln2.linear.weight                                             ├─294,912
# │    └─blocks.3.mlp.ln2.bn.weight                                                 ├─384
# │    └─blocks.3.mlp.ln2.bn.bias                                                   └─384
# │    └─CNNDownsample: 2-10                              [32, 49, 384]             --
# │    │    └─conv.weight                                                           ├─884,736
# │    │    └─conv.bias                                                             └─384
# │    │    └─Conv2d: 3-11                                [32, 384, 7, 7]           885,120
# │    │    │    └─weight                                                           ├─884,736
# │    │    │    └─bias                                                             └─384
# │    │    └─Hardswish: 3-12                             [32, 384, 7, 7]           --
# │    └─Sequential: 2-11                                 --                        2,370,636
# │    │    └─0.attn.attention_biases                                               ├─294
# │    │    └─0.attn.qkv.linear.weight                                              ├─442,368
# │    │    └─0.attn.qkv.bn.weight                                                  ├─1,152
# │    │    └─0.attn.qkv.bn.bias                                                    ├─1,152
# │    │    └─0.attn.proj.1.linear.weight                                           ├─147,456
# │    │    └─0.attn.proj.1.bn.weight                                               ├─384
# │    │    └─0.attn.proj.1.bn.bias                                                 ├─384
# │    │    └─0.mlp.ln1.linear.weight                                               ├─294,912
# │    │    └─0.mlp.ln1.bn.weight                                                   ├─768
# │    │    └─0.mlp.ln1.bn.bias                                                     ├─768
# │    │    └─0.mlp.ln2.linear.weight                                               ├─294,912
# │    │    └─0.mlp.ln2.bn.weight                                                   ├─384
# │    │    └─0.mlp.ln2.bn.bias                                                     ├─384
# │    │    └─1.attn.attention_biases                                               ├─294
# │    │    └─1.attn.qkv.linear.weight                                              ├─442,368
# │    │    └─1.attn.qkv.bn.weight                                                  ├─1,152
# │    │    └─1.attn.qkv.bn.bias                                                    ├─1,152
# │    │    └─1.attn.proj.1.linear.weight                                           ├─147,456
# │    │    └─1.attn.proj.1.bn.weight                                               ├─384
# │    │    └─1.attn.proj.1.bn.bias                                                 ├─384
# │    │    └─1.mlp.ln1.linear.weight                                               ├─294,912
# │    │    └─1.mlp.ln1.bn.weight                                                   ├─768
# │    │    └─1.mlp.ln1.bn.bias                                                     ├─768
# │    │    └─1.mlp.ln2.linear.weight                                               ├─294,912
# │    │    └─1.mlp.ln2.bn.weight                                                   ├─384
# │    │    └─1.mlp.ln2.bn.bias                                                     ├─384
# │    │    └─2.attn.attention_biases                                               ├─294
# │    │    └─2.attn.qkv.linear.weight                                              ├─442,368
# │    │    └─2.attn.qkv.bn.weight                                                  ├─1,152
# │    │    └─2.attn.qkv.bn.bias                                                    ├─1,152
# │    │    └─2.attn.proj.1.linear.weight                                           ├─147,456
# │    │    └─2.attn.proj.1.bn.weight                                               ├─384
# │    │    └─2.attn.proj.1.bn.bias                                                 ├─384
# │    │    └─2.mlp.ln1.linear.weight                                               ├─294,912
# │    │    └─2.mlp.ln1.bn.weight                                                   ├─768
# │    │    └─2.mlp.ln1.bn.bias                                                     ├─768
# │    │    └─2.mlp.ln2.linear.weight                                               ├─294,912
# │    │    └─2.mlp.ln2.bn.weight                                                   ├─384
# │    │    └─2.mlp.ln2.bn.bias                                                     ├─384
# │    │    └─3.attn.qkv.linear.weight                                              ├─442,368
# │    │    └─3.attn.qkv.bn.weight                                                  ├─1,152
# │    │    └─3.attn.qkv.bn.bias                                                    ├─1,152
# │    │    └─3.attn.proj.1.linear.weight                                           ├─147,456
# │    │    └─3.attn.proj.1.bn.weight                                               ├─384
# │    │    └─3.attn.proj.1.bn.bias                                                 ├─384
# │    │    └─3.mlp.ln1.linear.weight                                               ├─294,912
# │    │    └─3.mlp.ln1.bn.weight                                                   ├─768
# │    │    └─3.mlp.ln1.bn.bias                                                     ├─768
# │    │    └─3.mlp.ln2.linear.weight                                               ├─294,912
# │    │    └─3.mlp.ln2.bn.weight                                                   ├─384
# │    │    └─3.mlp.ln2.bn.bias                                                     └─384
# │    │    └─LevitBlock: 3-13                            [32, 49, 384]             1,185,024
# │    │    │    └─attn.qkv.linear.weight                                           ├─442,368
# │    │    │    └─attn.qkv.bn.weight                                               ├─1,152
# │    │    │    └─attn.qkv.bn.bias                                                 ├─1,152
# │    │    │    └─attn.proj.1.linear.weight                                        ├─147,456
# │    │    │    └─attn.proj.1.bn.weight                                            ├─384
# │    │    │    └─attn.proj.1.bn.bias                                              ├─384
# │    │    │    └─mlp.ln1.linear.weight                                            ├─294,912
# │    │    │    └─mlp.ln1.bn.weight                                                ├─768
# │    │    │    └─mlp.ln1.bn.bias                                                  ├─768
# │    │    │    └─mlp.ln2.linear.weight                                            ├─294,912
# │    │    │    └─mlp.ln2.bn.weight                                                ├─384
# │    │    │    └─mlp.ln2.bn.bias                                                  └─384
# │    │    └─LevitBlock: 3-14                            [32, 49, 384]             1,185,318
# │    │    │    └─attn.attention_biases                                            ├─294
# │    │    │    └─attn.qkv.linear.weight                                           ├─442,368
# │    │    │    └─attn.qkv.bn.weight                                               ├─1,152
# │    │    │    └─attn.qkv.bn.bias                                                 ├─1,152
# │    │    │    └─attn.proj.1.linear.weight                                        ├─147,456
# │    │    │    └─attn.proj.1.bn.weight                                            ├─384
# │    │    │    └─attn.proj.1.bn.bias                                              ├─384
# │    │    │    └─mlp.ln1.linear.weight                                            ├─294,912
# │    │    │    └─mlp.ln1.bn.weight                                                ├─768
# │    │    │    └─mlp.ln1.bn.bias                                                  ├─768
# │    │    │    └─mlp.ln2.linear.weight                                            ├─294,912
# │    │    │    └─mlp.ln2.bn.weight                                                ├─384
# │    │    │    └─mlp.ln2.bn.bias                                                  └─384
# ├─Sequential: 1-4                                       [32, 512, 7, 7]           --
# │    └─0.weight                                                                   ├─196,608
# │    └─0.bias                                                                     ├─512
# │    └─1.weight                                                                   ├─512
# │    └─1.bias                                                                     └─512
# │    └─Conv2d: 2-12                                     [32, 512, 7, 7]           197,120
# │    │    └─weight                                                                ├─196,608
# │    │    └─bias                                                                  └─512
# │    └─BatchNorm2d: 2-13                                [32, 512, 7, 7]           1,024
# │    │    └─weight                                                                ├─512
# │    │    └─bias                                                                  └─512
# │    └─ReLU: 2-14                                       [32, 512, 7, 7]           --
# ├─NormLinear: 1-5                                       [32, 9]                   --
# │    └─bn.weight                                                                  ├─512
# │    └─bn.bias                                                                    ├─512
# │    └─linear.weight                                                              ├─4,608
# │    └─linear.bias                                                                └─9
# │    └─BatchNorm1d: 2-15                                [32, 512]                 1,024
# │    │    └─weight                                                                ├─512
# │    │    └─bias                                                                  └─512
# │    └─Dropout: 2-16                                    [32, 512]                 --
# │    └─Linear: 2-17                                     [32, 9]                   4,617
# │    │    └─weight                                                                ├─4,608
# │    │    └─bias                                                                  └─9
# ├─NormLinear: 1-6                                       [32, 9]                   --
# │    └─bn.weight                                                                  ├─512
# │    └─bn.bias                                                                    ├─512
# │    └─linear.weight                                                              ├─4,608
# │    └─linear.bias                                                                └─9
# │    └─BatchNorm1d: 2-18                                [32, 512]                 1,024
# │    │    └─weight                                                                ├─512
# │    │    └─bias                                                                  └─512
# │    └─Dropout: 2-19                                    [32, 512]                 --
# │    └─Linear: 2-20                                     [32, 9]                   4,617
# │    │    └─weight                                                                ├─4,608
# │    │    └─bias                                                                  └─9
# =========================================================================================================
# Total params: 8,338,260
# Trainable params: 8,338,260
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 17.93
# =========================================================================================================
# Input size (MB): 19.27
# Forward/backward pass size (MB): 897.82
# Params size (MB): 19.64
# Estimated Total Size (MB): 936.72
# =========================================================================================================

# %%
import torch.nn.init as init

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)  # CUDA 연산 시 동일한 결과 보장
    torch.cuda.manual_seed_all(seed)  # 멀티-GPU 환경에서 동일한 결과 보장
    torch.backends.cudnn.deterministic = True  # CuDNN 연산을 deterministic하게 설정
    torch.backends.cudnn.benchmark = False  # 연산 속도를 희생하고 일관된 연산을 수행

def initialize_weights(m):
    if isinstance(m, nn.Conv2d):  # Conv 레이어 초기화
        init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
        if m.bias is not None:
            init.constant_(m.bias, 0)
    elif isinstance(m, nn.Linear):  # Linear 레이어 초기화
        init.xavier_uniform_(m.weight)
        if m.bias is not None:
            init.constant_(m.bias, 0)
    elif isinstance(m, nn.BatchNorm2d) or isinstance(m, nn.BatchNorm1d):  # BatchNorm 초기화
        init.constant_(m.weight, 1)
        init.constant_(m.bias, 0)

set_seed(42)  # 랜덤 시드 고정
model.apply(initialize_weights)
# Out:
# LevitDistilledTinyfusion(
#   (stem): Stem16(
#     (conv1): ConvNorm(
#       (linear): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (act1): Hardswish()
#     (conv2): ConvNorm(
#       (linear): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (act2): Hardswish()
#     (conv3): ConvNorm(
#       (linear): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (act3): Hardswish()
#     (conv4): ConvNorm(
#       (linear): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (stage1): LevitStage_TinyFusion(
#     (downsample): Identity()
#     (blocks): Sequential(
#       (0): LevitBlock(
#         (attn): Attention(
#           (qkv): LinearNorm(
#             (linear): Linear(in_features=256, out_features=768, bias=False)
#             (bn): BatchNorm1d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (proj): Sequential(
#             (0): Hardswish()
#             (1): LinearNorm(
#               (linear): Linear(in_features=256, out_features=256, bias=False)
#               (bn): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (drop_path1): Identity()
#         (mlp): LevitMlp(
#           (ln1): LinearNorm(
#             (linear): Linear(in_features=256, out_features=512, bias=False)
#             (bn): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (act): Hardswish()
#           (drop): Dropout(p=0.5, inplace=False)
#           (ln2): LinearNorm(
#             (linear): Linear(in_features=512, out_features=256, bias=False)
#             (bn): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (drop_path2): Identity()
#       )
#       (1): LevitBlock(
#         (attn): Attention(
#           (qkv): LinearNorm(
#             (linear): Linear(in_features=256, out_features=768, bias=False)
#             (bn): BatchNorm1d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (proj): Sequential(
#             (0): Hardswish()
#             (1): LinearNorm(
#               (linear): Linear(in_features=256, out_features=256, bias=False)
#               (bn): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (drop_path1): Identity()
#         (mlp): LevitMlp(
#           (ln1): LinearNorm(
#             (linear): Linear(in_features=256, out_features=512, bias=False)
#             (bn): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (act): Hardswish()
#           (drop): Dropout(p=0.5, inplace=False)
#           (ln2): LinearNorm(
#             (linear): Linear(in_features=512, out_features=256, bias=False)
#             (bn): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (drop_path2): Identity()
#       )
#       (2): LevitBlock(
#         (attn): Attention(
#           (qkv): LinearNorm(
#             (linear): Linear(in_features=256, out_features=768, bias=False)
#             (bn): BatchNorm1d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (proj): Sequential(
#             (0): Hardswish()
#             (1): LinearNorm(
#               (linear): Linear(in_features=256, out_features=256, bias=False)
#               (bn): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (drop_path1): Identity()
#         (mlp): LevitMlp(
#           (ln1): LinearNorm(
#             (linear): Linear(in_features=256, out_features=512, bias=False)
#             (bn): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (act): Hardswish()
#           (drop): Dropout(p=0.5, inplace=False)
#           (ln2): LinearNorm(
#             (linear): Linear(in_features=512, out_features=256, bias=False)
#             (bn): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (drop_path2): Identity()
#       )
#       (3): LevitBlock(
#         (attn): Attention(
#           (qkv): LinearNorm(
#             (linear): Linear(in_features=256, out_features=768, bias=False)
#             (bn): BatchNorm1d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (proj): Sequential(
#             (0): Hardswish()
#             (1): LinearNorm(
#               (linear): Linear(in_features=256, out_features=256, bias=False)
#               (bn): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (drop_path1): Identity()
#         (mlp): LevitMlp(
#           (ln1): LinearNorm(
#             (linear): Linear(in_features=256, out_features=512, bias=False)
#             (bn): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (act): Hardswish()
#           (drop): Dropout(p=0.5, inplace=False)
#           (ln2): LinearNorm(
#             (linear): Linear(in_features=512, out_features=256, bias=False)
#             (bn): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (drop_path2): Identity()
#       )
#     )
#   )
#   (stage2): LevitStage_TinyFusion(
#     (downsample): CNNDownsample(
#       (conv): Conv2d(256, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (act): Hardswish()
#     )
#     (blocks): Sequential(
#       (0): LevitBlock(
#         (attn): Attention(
#           (qkv): LinearNorm(
#             (linear): Linear(in_features=384, out_features=1152, bias=False)
#             (bn): BatchNorm1d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (proj): Sequential(
#             (0): Hardswish()
#             (1): LinearNorm(
#               (linear): Linear(in_features=384, out_features=384, bias=False)
#               (bn): BatchNorm1d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (drop_path1): Identity()
#         (mlp): LevitMlp(
#           (ln1): LinearNorm(
#             (linear): Linear(in_features=384, out_features=768, bias=False)
#             (bn): BatchNorm1d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (act): Hardswish()
#           (drop): Dropout(p=0.5, inplace=False)
#           (ln2): LinearNorm(
#             (linear): Linear(in_features=768, out_features=384, bias=False)
#             (bn): BatchNorm1d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (drop_path2): Identity()
#       )
#       (1): LevitBlock(
#         (attn): Attention(
#           (qkv): LinearNorm(
#             (linear): Linear(in_features=384, out_features=1152, bias=False)
#             (bn): BatchNorm1d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (proj): Sequential(
#             (0): Hardswish()
#             (1): LinearNorm(
#               (linear): Linear(in_features=384, out_features=384, bias=False)
#               (bn): BatchNorm1d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (drop_path1): Identity()
#         (mlp): LevitMlp(
#           (ln1): LinearNorm(
#             (linear): Linear(in_features=384, out_features=768, bias=False)
#             (bn): BatchNorm1d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (act): Hardswish()
#           (drop): Dropout(p=0.5, inplace=False)
#           (ln2): LinearNorm(
#             (linear): Linear(in_features=768, out_features=384, bias=False)
#             (bn): BatchNorm1d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (drop_path2): Identity()
#       )
#       (2): LevitBlock(
#         (attn): Attention(
#           (qkv): LinearNorm(
#             (linear): Linear(in_features=384, out_features=1152, bias=False)
#             (bn): BatchNorm1d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (proj): Sequential(
#             (0): Hardswish()
#             (1): LinearNorm(
#               (linear): Linear(in_features=384, out_features=384, bias=False)
#               (bn): BatchNorm1d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (drop_path1): Identity()
#         (mlp): LevitMlp(
#           (ln1): LinearNorm(
#             (linear): Linear(in_features=384, out_features=768, bias=False)
#             (bn): BatchNorm1d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (act): Hardswish()
#           (drop): Dropout(p=0.5, inplace=False)
#           (ln2): LinearNorm(
#             (linear): Linear(in_features=768, out_features=384, bias=False)
#             (bn): BatchNorm1d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (drop_path2): Identity()
#       )
#       (3): LevitBlock(
#         (attn): Attention(
#           (qkv): LinearNorm(
#             (linear): Linear(in_features=384, out_features=1152, bias=False)
#             (bn): BatchNorm1d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (proj): Sequential(
#             (0): Hardswish()
#             (1): LinearNorm(
#               (linear): Linear(in_features=384, out_features=384, bias=False)
#               (bn): BatchNorm1d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (drop_path1): Identity()
#         (mlp): LevitMlp(
#           (ln1): LinearNorm(
#             (linear): Linear(in_features=384, out_features=768, bias=False)
#             (bn): BatchNorm1d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (act): Hardswish()
#           (drop): Dropout(p=0.5, inplace=False)
#           (ln2): LinearNorm(
#             (linear): Linear(in_features=768, out_features=384, bias=False)
#             (bn): BatchNorm1d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (drop_path2): Identity()
#       )
#     )
#   )
#   (conv1x1): Sequential(
#     (0): Conv2d(384, 512, kernel_size=(1, 1), stride=(1, 1))
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (head): NormLinear(
#     (bn): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (drop): Dropout(p=0.0, inplace=False)
#     (linear): Linear(in_features=512, out_features=9, bias=True)
#   )
#   (head_dist): NormLinear(
#     (bn): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (drop): Dropout(p=0.0, inplace=False)
#     (linear): Linear(in_features=512, out_features=9, bias=True)
#   )
# )

# %%
train_dir = './train/NCT-CRC-HE-100K'

# %%
aug_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.RandomHorizontalFlip(p=0.75),
    transforms.RandomVerticalFlip(p=0.75),
])

transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

# %%
dataset = datasets.ImageFolder(root=train_dir, transform=transform)

# %%
import json

with open("index_dict.json", "r") as f:
    index_dict = json.load(f)
load_train_idx = index_dict["train_idx"]
load_val_idx = index_dict["val_idx"]
load_test_idx = index_dict["test_idx"]

# %%
dataset_train = datasets.ImageFolder(root=train_dir, transform=aug_transform)
dataset_eval = datasets.ImageFolder(root=train_dir, transform=transform)

train_data = Subset(dataset_train, load_train_idx)
val_data = Subset(dataset_eval, load_val_idx)
test_data = Subset(dataset_eval, load_test_idx)

# %%
train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True,
                          num_workers=4, pin_memory=True, persistent_workers=True)

val_loader = DataLoader(val_data, batch_size=batch_size, shuffle=False,
                        num_workers=4, pin_memory=True, persistent_workers=True)

test_loader = DataLoader(test_data, batch_size=batch_size, shuffle=False,
                         num_workers=4, pin_memory=True, persistent_workers=True)

print(f"Train set size: {len(train_data)}")
print(f"Validation set size: {len(val_data)}")
print(f"Test set size: {len(test_data)}")
# Out:
# Train set size: 70000
# Validation set size: 15000
# Test set size: 15000

# %%
# Show one example per class from the training dataset
import matplotlib.pyplot as plt

# Prepare a dictionary to store one example per class
class_examples = {}
for images, labels in train_loader:
    for img, label in zip(images, labels):
        label = label.item()
        if label not in class_examples:
            class_examples[label] = img
        # Stop if we already have one example for each class
        if len(class_examples) == len(dataset.classes):
            break
    if len(class_examples) == len(dataset.classes):
        break

# Display the images and their labels
figure = plt.figure(figsize=(8, 8))
cols = 3  # You can adjust the number of columns as needed
rows = (len(dataset.classes) + cols - 1) // cols  # Calculate required rows
for i, (label, img) in enumerate(class_examples.items(), start=1):
    figure.add_subplot(rows, cols, i)
    plt.title(dataset.classes[label])
    plt.axis("off")
    plt.imshow(img.permute(1, 2, 0).numpy())  # Convert tensor to numpy for display
plt.show()

# %%
gumbel_params = []
other_params = []
exclude = ["head", "head_dist"]

for name, module in model.named_children():
    if name in exclude:
        print(exclude)

for name, param in model.named_parameters():
    if "gumbel_gate" in name:
        gumbel_params.append(param)
        print(name)
    else:
        other_params.append(param)

#model = convert_to_lora_model(model, exclude=exclude)
# Out:
# ['head', 'head_dist']
# ['head', 'head_dist']
# stage1.gumbel_gate
# stage2.gumbel_gate

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam([
    {'params' : gumbel_params, 'lr': learning_rate * 10},
    {'params' : other_params, 'lr': learning_rate}
])
scaler = GradScaler()
# Out:
# <ipython-input-155-ea103f408f9f>:6: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()

# %%
train_losses = []
train_accuracies = []
val_losses = []
val_accuracies = []

# %%
def train(model, train_loader, criterion, optimizer, device, epoch, total_epcohs=100):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    tau_max = 1.0
    tau_min = 0.1
    total_steps = total_epcohs * len(train_loader)
    train_steps = epoch * len(train_loader)

    for i, (inputs, labels) in enumerate(tqdm(train_loader, desc="Training")):
        tau = tau_max - (tau_max - tau_min) * ((train_steps + i) / total_steps)
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()

        with torch.amp.autocast(device_type='cuda'):
            outputs = model(inputs, tau)
            loss = criterion(outputs, labels)

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    epoch_loss = running_loss / len(train_loader)
    accuracy = 100 * correct / total
    print(f"Train Loss: {epoch_loss:.4f}, Train Accuracy: {accuracy:.2f}%")
    print(f"Tau: {tau:.4f}")
    train_losses.append(epoch_loss)
    train_accuracies.append(accuracy)

    print("Each stage of block probabilities:")
    for name, module in model.named_modules():
        if isinstance(module, LevitStage_TinyFusion):
            gate_probs = torch.softmax(module.gumbel_gate, dim=0)
            topk_indx = torch.topk(gate_probs, module.num_select).indices.tolist()
            print(f"{name}")
            for i, prob in enumerate(gate_probs):
                mask = " " if i in topk_indx else "*"
                print(f"Block {i}: {prob:.4f} {mask}")

# %%
# Global variable to track the best validation loss
best_val_loss = float('inf')

def evaluate(model, data_loader, criterion, device, phase="Validation", epoch=0, total_epcohs=100, save_path="best_model.pth"):
    global best_val_loss
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0
    all_labels = []
    all_predictions = []
    tau_max = 1
    tau_min = 0.1
    total_steps = total_epcohs * len(data_loader)
    train_steps = epoch * len(data_loader)

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(tqdm(data_loader, desc=f"{phase}")):
            inputs, labels = inputs.to(device), labels.to(device)
            if phase == "Validation":
                tau = (tau_max) - (tau_max - tau_min) * ((train_steps + i) / total_steps)
            elif phase == "Test":
                tau = 1e-5
            outputs = model(inputs, tau)
            loss = criterion(outputs, labels)

            running_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

            # Save all labels and predictions for balanced accuracy
            all_labels.extend(labels.cpu().numpy())
            all_predictions.extend(predicted.cpu().numpy())

    epoch_loss = running_loss / len(data_loader)
    accuracy = 100 * correct / total
    balanced_acc = balanced_accuracy_score(all_labels, all_predictions)

    print(f"Tau: {tau:.4f}")
    print(f"{phase} Loss: {epoch_loss:.4f}, {phase} Accuracy: {accuracy:.2f}%")
    print(f"Balanced Accuracy: {balanced_acc:.4f}")

    if epoch_loss < best_val_loss:
        best_val_loss = epoch_loss
        torch.save(model.state_dict(), save_path)
        print(f"New best model saved with {phase} loss {epoch_loss:.4f} at {save_path}")

    val_losses.append(epoch_loss)
    val_accuracies.append(accuracy)

# %%
def measure_inference_time(model, data_loader, device):
    model.eval()
    times = []

    with torch.no_grad():
        for inputs, _ in data_loader:
            inputs = inputs.to(device)
            start_time = torch.cuda.Event(enable_timing=True)
            end_time = torch.cuda.Event(enable_timing=True)

            start_time.record()
            _ = model(inputs, tau=0.1)  # inference 수행
            end_time.record()

            # 시간 측정
            torch.cuda.synchronize()  # CUDA에서 모든 커널이 완료될 때까지 대기
            elapsed_time = start_time.elapsed_time(end_time)  # 밀리초 단위로 반환
            times.append(elapsed_time)

    # 통계량 계산
    times_np = np.array(times)
    total_inferences = len(times_np)
    avg_time = np.mean(times_np)
    std_dev = np.std(times_np)
    max_time = np.max(times_np)
    min_time = np.min(times_np)

    # 결과 출력
    print(f"Inference Time Measurement Results:")
    print(f"Total Inferences: {total_inferences}")
    print(f"Average Time: {avg_time:.2f} ms")
    print(f"Standard Deviation: {std_dev:.2f} ms")
    print(f"Maximum Time: {max_time:.2f} ms")
    print(f"Minimum Time: {min_time:.2f} ms")

    return times

# %%
# gumbel_gate 파라미터가 포함되어 있는지 확인
for name, param in model.named_parameters():
    print(f"Parameter name: {name}, requires_grad: {param.requires_grad}")
# Out:
# Parameter name: stem.conv1.linear.weight, requires_grad: True
# Parameter name: stem.conv1.bn.weight, requires_grad: True
# Parameter name: stem.conv1.bn.bias, requires_grad: True
# Parameter name: stem.conv2.linear.weight, requires_grad: True
# Parameter name: stem.conv2.bn.weight, requires_grad: True
# Parameter name: stem.conv2.bn.bias, requires_grad: True
# Parameter name: stem.conv3.linear.weight, requires_grad: True
# Parameter name: stem.conv3.bn.weight, requires_grad: True
# Parameter name: stem.conv3.bn.bias, requires_grad: True
# Parameter name: stem.conv4.linear.weight, requires_grad: True
# Parameter name: stem.conv4.bn.weight, requires_grad: True
# Parameter name: stem.conv4.bn.bias, requires_grad: True
# Parameter name: stage1.gumbel_gate, requires_grad: True
# Parameter name: stage1.blocks.0.attn.attention_biases, requires_grad: True
# Parameter name: stage1.blocks.0.attn.qkv.linear.weight, requires_grad: True
# Parameter name: stage1.blocks.0.attn.qkv.bn.weight, requires_grad: True
# Parameter name: stage1.blocks.0.attn.qkv.bn.bias, requires_grad: True
# Parameter name: stage1.blocks.0.attn.proj.1.linear.weight, requires_grad: True
# Parameter name: stage1.blocks.0.attn.proj.1.bn.weight, requires_grad: True
# Parameter name: stage1.blocks.0.attn.proj.1.bn.bias, requires_grad: True
# Parameter name: stage1.blocks.0.mlp.ln1.linear.weight, requires_grad: True
# Parameter name: stage1.blocks.0.mlp.ln1.bn.weight, requires_grad: True
# Parameter name: stage1.blocks.0.mlp.ln1.bn.bias, requires_grad: True
# Parameter name: stage1.blocks.0.mlp.ln2.linear.weight, requires_grad: True
# Parameter name: stage1.blocks.0.mlp.ln2.bn.weight, requires_grad: True
# Parameter name: stage1.blocks.0.mlp.ln2.bn.bias, requires_grad: True
# Parameter name: stage1.blocks.1.attn.attention_biases, requires_grad: True
# Parameter name: stage1.blocks.1.attn.qkv.linear.weight, requires_grad: True
# Parameter name: stage1.blocks.1.attn.qkv.bn.weight, requires_grad: True
# Parameter name: stage1.blocks.1.attn.qkv.bn.bias, requires_grad: True
# Parameter name: stage1.blocks.1.attn.proj.1.linear.weight, requires_grad: True
# Parameter name: stage1.blocks.1.attn.proj.1.bn.weight, requires_grad: True
# Parameter name: stage1.blocks.1.attn.proj.1.bn.bias, requires_grad: True
# Parameter name: stage1.blocks.1.mlp.ln1.linear.weight, requires_grad: True
# Parameter name: stage1.blocks.1.mlp.ln1.bn.weight, requires_grad: True
# Parameter name: stage1.blocks.1.mlp.ln1.bn.bias, requires_grad: True
# Parameter name: stage1.blocks.1.mlp.ln2.linear.weight, requires_grad: True
# Parameter name: stage1.blocks.1.mlp.ln2.bn.weight, requires_grad: True
# Parameter name: stage1.blocks.1.mlp.ln2.bn.bias, requires_grad: True
# Parameter name: stage1.blocks.2.attn.attention_biases, requires_grad: True
# Parameter name: stage1.blocks.2.attn.qkv.linear.weight, requires_grad: True
# Parameter name: stage1.blocks.2.attn.qkv.bn.weight, requires_grad: True
# Parameter name: stage1.blocks.2.attn.qkv.bn.bias, requires_grad: True
# Parameter name: stage1.blocks.2.attn.proj.1.linear.weight, requires_grad: True
# Parameter name: stage1.blocks.2.attn.proj.1.bn.weight, requires_grad: True
# Parameter name: stage1.blocks.2.attn.proj.1.bn.bias, requires_grad: True
# Parameter name: stage1.blocks.2.mlp.ln1.linear.weight, requires_grad: True
# Parameter name: stage1.blocks.2.mlp.ln1.bn.weight, requires_grad: True
# Parameter name: stage1.blocks.2.mlp.ln1.bn.bias, requires_grad: True
# Parameter name: stage1.blocks.2.mlp.ln2.linear.weight, requires_grad: True
# Parameter name: stage1.blocks.2.mlp.ln2.bn.weight, requires_grad: True
# Parameter name: stage1.blocks.2.mlp.ln2.bn.bias, requires_grad: True
# Parameter name: stage1.blocks.3.attn.qkv.linear.weight, requires_grad: True
# Parameter name: stage1.blocks.3.attn.qkv.bn.weight, requires_grad: True
# Parameter name: stage1.blocks.3.attn.qkv.bn.bias, requires_grad: True
# Parameter name: stage1.blocks.3.attn.proj.1.linear.weight, requires_grad: True
# Parameter name: stage1.blocks.3.attn.proj.1.bn.weight, requires_grad: True
# Parameter name: stage1.blocks.3.attn.proj.1.bn.bias, requires_grad: True
# Parameter name: stage1.blocks.3.mlp.ln1.linear.weight, requires_grad: True
# Parameter name: stage1.blocks.3.mlp.ln1.bn.weight, requires_grad: True
# Parameter name: stage1.blocks.3.mlp.ln1.bn.bias, requires_grad: True
# Parameter name: stage1.blocks.3.mlp.ln2.linear.weight, requires_grad: True
# Parameter name: stage1.blocks.3.mlp.ln2.bn.weight, requires_grad: True
# Parameter name: stage1.blocks.3.mlp.ln2.bn.bias, requires_grad: True
# Parameter name: stage2.gumbel_gate, requires_grad: True
# Parameter name: stage2.downsample.conv.weight, requires_grad: True
# Parameter name: stage2.downsample.conv.bias, requires_grad: True
# Parameter name: stage2.blocks.0.attn.attention_biases, requires_grad: True
# Parameter name: stage2.blocks.0.attn.qkv.linear.weight, requires_grad: True
# Parameter name: stage2.blocks.0.attn.qkv.bn.weight, requires_grad: True
# Parameter name: stage2.blocks.0.attn.qkv.bn.bias, requires_grad: True
# Parameter name: stage2.blocks.0.attn.proj.1.linear.weight, requires_grad: True
# Parameter name: stage2.blocks.0.attn.proj.1.bn.weight, requires_grad: True
# Parameter name: stage2.blocks.0.attn.proj.1.bn.bias, requires_grad: True
# Parameter name: stage2.blocks.0.mlp.ln1.linear.weight, requires_grad: True
# Parameter name: stage2.blocks.0.mlp.ln1.bn.weight, requires_grad: True
# Parameter name: stage2.blocks.0.mlp.ln1.bn.bias, requires_grad: True
# Parameter name: stage2.blocks.0.mlp.ln2.linear.weight, requires_grad: True
# Parameter name: stage2.blocks.0.mlp.ln2.bn.weight, requires_grad: True
# Parameter name: stage2.blocks.0.mlp.ln2.bn.bias, requires_grad: True
# Parameter name: stage2.blocks.1.attn.attention_biases, requires_grad: True
# Parameter name: stage2.blocks.1.attn.qkv.linear.weight, requires_grad: True
# Parameter name: stage2.blocks.1.attn.qkv.bn.weight, requires_grad: True
# Parameter name: stage2.blocks.1.attn.qkv.bn.bias, requires_grad: True
# Parameter name: stage2.blocks.1.attn.proj.1.linear.weight, requires_grad: True
# Parameter name: stage2.blocks.1.attn.proj.1.bn.weight, requires_grad: True
# Parameter name: stage2.blocks.1.attn.proj.1.bn.bias, requires_grad: True
# Parameter name: stage2.blocks.1.mlp.ln1.linear.weight, requires_grad: True
# Parameter name: stage2.blocks.1.mlp.ln1.bn.weight, requires_grad: True
# Parameter name: stage2.blocks.1.mlp.ln1.bn.bias, requires_grad: True
# Parameter name: stage2.blocks.1.mlp.ln2.linear.weight, requires_grad: True
# Parameter name: stage2.blocks.1.mlp.ln2.bn.weight, requires_grad: True
# Parameter name: stage2.blocks.1.mlp.ln2.bn.bias, requires_grad: True
# Parameter name: stage2.blocks.2.attn.attention_biases, requires_grad: True
# Parameter name: stage2.blocks.2.attn.qkv.linear.weight, requires_grad: True
# Parameter name: stage2.blocks.2.attn.qkv.bn.weight, requires_grad: True
# Parameter name: stage2.blocks.2.attn.qkv.bn.bias, requires_grad: True
# Parameter name: stage2.blocks.2.attn.proj.1.linear.weight, requires_grad: True
# Parameter name: stage2.blocks.2.attn.proj.1.bn.weight, requires_grad: True
# Parameter name: stage2.blocks.2.attn.proj.1.bn.bias, requires_grad: True
# Parameter name: stage2.blocks.2.mlp.ln1.linear.weight, requires_grad: True
# Parameter name: stage2.blocks.2.mlp.ln1.bn.weight, requires_grad: True
# Parameter name: stage2.blocks.2.mlp.ln1.bn.bias, requires_grad: True
# Parameter name: stage2.blocks.2.mlp.ln2.linear.weight, requires_grad: True
# Parameter name: stage2.blocks.2.mlp.ln2.bn.weight, requires_grad: True
# Parameter name: stage2.blocks.2.mlp.ln2.bn.bias, requires_grad: True
# Parameter name: stage2.blocks.3.attn.qkv.linear.weight, requires_grad: True
# Parameter name: stage2.blocks.3.attn.qkv.bn.weight, requires_grad: True
# Parameter name: stage2.blocks.3.attn.qkv.bn.bias, requires_grad: True
# Parameter name: stage2.blocks.3.attn.proj.1.linear.weight, requires_grad: True
# Parameter name: stage2.blocks.3.attn.proj.1.bn.weight, requires_grad: True
# Parameter name: stage2.blocks.3.attn.proj.1.bn.bias, requires_grad: True
# Parameter name: stage2.blocks.3.mlp.ln1.linear.weight, requires_grad: True
# Parameter name: stage2.blocks.3.mlp.ln1.bn.weight, requires_grad: True
# Parameter name: stage2.blocks.3.mlp.ln1.bn.bias, requires_grad: True
# Parameter name: stage2.blocks.3.mlp.ln2.linear.weight, requires_grad: True
# Parameter name: stage2.blocks.3.mlp.ln2.bn.weight, requires_grad: True
# Parameter name: stage2.blocks.3.mlp.ln2.bn.bias, requires_grad: True
# Parameter name: conv1x1.0.weight, requires_grad: True
# Parameter name: conv1x1.0.bias, requires_grad: True
# Parameter name: conv1x1.1.weight, requires_grad: True
# Parameter name: conv1x1.1.bias, requires_grad: True
# Parameter name: head.bn.weight, requires_grad: True
# Parameter name: head.bn.bias, requires_grad: True
# Parameter name: head.linear.weight, requires_grad: True
# Parameter name: head.linear.bias, requires_grad: True
# Parameter name: head_dist.bn.weight, requires_grad: True
# Parameter name: head_dist.bn.bias, requires_grad: True
# Parameter name: head_dist.linear.weight, requires_grad: True
# Parameter name: head_dist.linear.bias, requires_grad: True

# %%
def transfer_weights(pretrained_model: LevitDistilled, tinyfusion_model: LevitDistilledTinyfusion, num_blocks):

    pretrained_dict = pretrained_model.state_dict()
    tinyfusion_dict = tinyfusion_model.state_dict()

    new_state_dict = {}

    # 1️⃣ 공통된 가중치 복사 (stem, conv1x1, head, head_dist)
    for key in tinyfusion_dict.keys():
        if key in pretrained_dict and not key.startswith("stage"):
            new_state_dict[key] = pretrained_dict[key]

    stage = []
    for i in range(num_blocks):
        stage.append(f"stage{i}")
    # 2️⃣ stage1, stage2의 가중치 변환 적용
    for stage_name in stage:
        for i in range(num_blocks):  # num_blocks=4
            old_key = f"{stage_name}.blocks.{i}"  # 원래 모델의 key
            new_key = f"{stage_name}.blocks.{i}"  # TinyFusion 모델의 key

            if old_key in pretrained_dict and new_key in tinyfusion_dict:
                new_state_dict[new_key] = pretrained_dict[old_key]

    # 3️⃣ `gumble_gate`는 원래 모델에 없으므로, 초기화된 값 유지 (로드 안함)
    print("✅ 가중치 변환 완료! TinyFusion 모델에 적용합니다.")

    # 4️⃣ 변환된 가중치를 TinyFusion 모델에 로드 (strict=False)
    tinyfusion_model.load_state_dict(new_state_dict, strict=False)

# %%
pretrained_model = LevitDistilled(num_classes=9)
pretrained_model.stage1.blocks[0].attn.compute_attention_bias(14)
pretrained_model.stage1.blocks[1].attn.compute_attention_bias(14)
pretrained_model.stage1.blocks[2].attn.compute_attention_bias(14)
pretrained_model.stage1.blocks[3].attn.compute_attention_bias(14)
pretrained_model.stage2.blocks[0].attn.compute_attention_bias(7)
pretrained_model.stage2.blocks[1].attn.compute_attention_bias(7)
pretrained_model.stage2.blocks[2].attn.compute_attention_bias(7)
pretrained_model.stage2.blocks[3].attn.compute_attention_bias(7)
pretrained_model.load_state_dict(torch.load("HoViT_44_DropPath_0_5.pth"))
# Out:
# <All keys matched successfully>

# %%
transfer_weights(pretrained_model, model, num_blocks=4)
# Out:
# ✅ 가중치 변환 완료! TinyFusion 모델에 적용합니다.

# %%
model = convert_to_lora_model(model, exclude=exclude)

# %%
# gumbel_gate 파라미터가 포함되어 있는지 확인
for name, param in model.named_parameters():
    print(f"Parameter name: {name}, requires_grad: {param.requires_grad}")
# Out:
# Parameter name: stem.conv1.linear.weight, requires_grad: True
# Parameter name: stem.conv1.bn.weight, requires_grad: True
# Parameter name: stem.conv1.bn.bias, requires_grad: True
# Parameter name: stem.conv2.linear.weight, requires_grad: True
# Parameter name: stem.conv2.bn.weight, requires_grad: True
# Parameter name: stem.conv2.bn.bias, requires_grad: True
# Parameter name: stem.conv3.linear.weight, requires_grad: True
# Parameter name: stem.conv3.bn.weight, requires_grad: True
# Parameter name: stem.conv3.bn.bias, requires_grad: True
# Parameter name: stem.conv4.linear.weight, requires_grad: True
# Parameter name: stem.conv4.bn.weight, requires_grad: True
# Parameter name: stem.conv4.bn.bias, requires_grad: True
# Parameter name: stage1.gumbel_gate, requires_grad: True
# Parameter name: stage1.blocks.0.attn.attention_biases, requires_grad: True
# Parameter name: stage1.blocks.0.attn.qkv.linear.weight, requires_grad: True
# Parameter name: stage1.blocks.0.attn.qkv.linear.lora_a.weight, requires_grad: True
# Parameter name: stage1.blocks.0.attn.qkv.linear.lora_b.weight, requires_grad: True
# Parameter name: stage1.blocks.0.attn.qkv.bn.weight, requires_grad: True
# Parameter name: stage1.blocks.0.attn.qkv.bn.bias, requires_grad: True
# Parameter name: stage1.blocks.0.attn.proj.1.linear.weight, requires_grad: True
# Parameter name: stage1.blocks.0.attn.proj.1.linear.lora_a.weight, requires_grad: True
# Parameter name: stage1.blocks.0.attn.proj.1.linear.lora_b.weight, requires_grad: True
# Parameter name: stage1.blocks.0.attn.proj.1.bn.weight, requires_grad: True
# Parameter name: stage1.blocks.0.attn.proj.1.bn.bias, requires_grad: True
# Parameter name: stage1.blocks.0.mlp.ln1.linear.weight, requires_grad: True
# Parameter name: stage1.blocks.0.mlp.ln1.linear.lora_a.weight, requires_grad: True
# Parameter name: stage1.blocks.0.mlp.ln1.linear.lora_b.weight, requires_grad: True
# Parameter name: stage1.blocks.0.mlp.ln1.bn.weight, requires_grad: True
# Parameter name: stage1.blocks.0.mlp.ln1.bn.bias, requires_grad: True
# Parameter name: stage1.blocks.0.mlp.ln2.linear.weight, requires_grad: True
# Parameter name: stage1.blocks.0.mlp.ln2.linear.lora_a.weight, requires_grad: True
# Parameter name: stage1.blocks.0.mlp.ln2.linear.lora_b.weight, requires_grad: True
# Parameter name: stage1.blocks.0.mlp.ln2.bn.weight, requires_grad: True
# Parameter name: stage1.blocks.0.mlp.ln2.bn.bias, requires_grad: True
# Parameter name: stage1.blocks.1.attn.attention_biases, requires_grad: True
# Parameter name: stage1.blocks.1.attn.qkv.linear.weight, requires_grad: True
# Parameter name: stage1.blocks.1.attn.qkv.linear.lora_a.weight, requires_grad: True
# Parameter name: stage1.blocks.1.attn.qkv.linear.lora_b.weight, requires_grad: True
# Parameter name: stage1.blocks.1.attn.qkv.bn.weight, requires_grad: True
# Parameter name: stage1.blocks.1.attn.qkv.bn.bias, requires_grad: True
# Parameter name: stage1.blocks.1.attn.proj.1.linear.weight, requires_grad: True
# Parameter name: stage1.blocks.1.attn.proj.1.linear.lora_a.weight, requires_grad: True
# Parameter name: stage1.blocks.1.attn.proj.1.linear.lora_b.weight, requires_grad: True
# Parameter name: stage1.blocks.1.attn.proj.1.bn.weight, requires_grad: True
# Parameter name: stage1.blocks.1.attn.proj.1.bn.bias, requires_grad: True
# Parameter name: stage1.blocks.1.mlp.ln1.linear.weight, requires_grad: True
# Parameter name: stage1.blocks.1.mlp.ln1.linear.lora_a.weight, requires_grad: True
# Parameter name: stage1.blocks.1.mlp.ln1.linear.lora_b.weight, requires_grad: True
# Parameter name: stage1.blocks.1.mlp.ln1.bn.weight, requires_grad: True
# Parameter name: stage1.blocks.1.mlp.ln1.bn.bias, requires_grad: True
# Parameter name: stage1.blocks.1.mlp.ln2.linear.weight, requires_grad: True
# Parameter name: stage1.blocks.1.mlp.ln2.linear.lora_a.weight, requires_grad: True
# Parameter name: stage1.blocks.1.mlp.ln2.linear.lora_b.weight, requires_grad: True
# Parameter name: stage1.blocks.1.mlp.ln2.bn.weight, requires_grad: True
# Parameter name: stage1.blocks.1.mlp.ln2.bn.bias, requires_grad: True
# Parameter name: stage1.blocks.2.attn.attention_biases, requires_grad: True
# Parameter name: stage1.blocks.2.attn.qkv.linear.weight, requires_grad: True
# Parameter name: stage1.blocks.2.attn.qkv.linear.lora_a.weight, requires_grad: True
# Parameter name: stage1.blocks.2.attn.qkv.linear.lora_b.weight, requires_grad: True
# Parameter name: stage1.blocks.2.attn.qkv.bn.weight, requires_grad: True
# Parameter name: stage1.blocks.2.attn.qkv.bn.bias, requires_grad: True
# Parameter name: stage1.blocks.2.attn.proj.1.linear.weight, requires_grad: True
# Parameter name: stage1.blocks.2.attn.proj.1.linear.lora_a.weight, requires_grad: True
# Parameter name: stage1.blocks.2.attn.proj.1.linear.lora_b.weight, requires_grad: True
# Parameter name: stage1.blocks.2.attn.proj.1.bn.weight, requires_grad: True
# Parameter name: stage1.blocks.2.attn.proj.1.bn.bias, requires_grad: True
# Parameter name: stage1.blocks.2.mlp.ln1.linear.weight, requires_grad: True
# Parameter name: stage1.blocks.2.mlp.ln1.linear.lora_a.weight, requires_grad: True
# Parameter name: stage1.blocks.2.mlp.ln1.linear.lora_b.weight, requires_grad: True
# Parameter name: stage1.blocks.2.mlp.ln1.bn.weight, requires_grad: True
# Parameter name: stage1.blocks.2.mlp.ln1.bn.bias, requires_grad: True
# Parameter name: stage1.blocks.2.mlp.ln2.linear.weight, requires_grad: True
# Parameter name: stage1.blocks.2.mlp.ln2.linear.lora_a.weight, requires_grad: True
# Parameter name: stage1.blocks.2.mlp.ln2.linear.lora_b.weight, requires_grad: True
# Parameter name: stage1.blocks.2.mlp.ln2.bn.weight, requires_grad: True
# Parameter name: stage1.blocks.2.mlp.ln2.bn.bias, requires_grad: True
# Parameter name: stage1.blocks.3.attn.qkv.linear.weight, requires_grad: True
# Parameter name: stage1.blocks.3.attn.qkv.linear.lora_a.weight, requires_grad: True
# Parameter name: stage1.blocks.3.attn.qkv.linear.lora_b.weight, requires_grad: True
# Parameter name: stage1.blocks.3.attn.qkv.bn.weight, requires_grad: True
# Parameter name: stage1.blocks.3.attn.qkv.bn.bias, requires_grad: True
# Parameter name: stage1.blocks.3.attn.proj.1.linear.weight, requires_grad: True
# Parameter name: stage1.blocks.3.attn.proj.1.linear.lora_a.weight, requires_grad: True
# Parameter name: stage1.blocks.3.attn.proj.1.linear.lora_b.weight, requires_grad: True
# Parameter name: stage1.blocks.3.attn.proj.1.bn.weight, requires_grad: True
# Parameter name: stage1.blocks.3.attn.proj.1.bn.bias, requires_grad: True
# Parameter name: stage1.blocks.3.mlp.ln1.linear.weight, requires_grad: True
# Parameter name: stage1.blocks.3.mlp.ln1.linear.lora_a.weight, requires_grad: True
# Parameter name: stage1.blocks.3.mlp.ln1.linear.lora_b.weight, requires_grad: True
# Parameter name: stage1.blocks.3.mlp.ln1.bn.weight, requires_grad: True
# Parameter name: stage1.blocks.3.mlp.ln1.bn.bias, requires_grad: True
# Parameter name: stage1.blocks.3.mlp.ln2.linear.weight, requires_grad: True
# Parameter name: stage1.blocks.3.mlp.ln2.linear.lora_a.weight, requires_grad: True
# Parameter name: stage1.blocks.3.mlp.ln2.linear.lora_b.weight, requires_grad: True
# Parameter name: stage1.blocks.3.mlp.ln2.bn.weight, requires_grad: True
# Parameter name: stage1.blocks.3.mlp.ln2.bn.bias, requires_grad: True
# Parameter name: stage2.gumbel_gate, requires_grad: True
# Parameter name: stage2.downsample.conv.weight, requires_grad: True
# Parameter name: stage2.downsample.conv.bias, requires_grad: True
# Parameter name: stage2.blocks.0.attn.attention_biases, requires_grad: True
# Parameter name: stage2.blocks.0.attn.qkv.linear.weight, requires_grad: True
# Parameter name: stage2.blocks.0.attn.qkv.linear.lora_a.weight, requires_grad: True
# Parameter name: stage2.blocks.0.attn.qkv.linear.lora_b.weight, requires_grad: True
# Parameter name: stage2.blocks.0.attn.qkv.bn.weight, requires_grad: True
# Parameter name: stage2.blocks.0.attn.qkv.bn.bias, requires_grad: True
# Parameter name: stage2.blocks.0.attn.proj.1.linear.weight, requires_grad: True
# Parameter name: stage2.blocks.0.attn.proj.1.linear.lora_a.weight, requires_grad: True
# Parameter name: stage2.blocks.0.attn.proj.1.linear.lora_b.weight, requires_grad: True
# Parameter name: stage2.blocks.0.attn.proj.1.bn.weight, requires_grad: True
# Parameter name: stage2.blocks.0.attn.proj.1.bn.bias, requires_grad: True
# Parameter name: stage2.blocks.0.mlp.ln1.linear.weight, requires_grad: True
# Parameter name: stage2.blocks.0.mlp.ln1.linear.lora_a.weight, requires_grad: True
# Parameter name: stage2.blocks.0.mlp.ln1.linear.lora_b.weight, requires_grad: True
# Parameter name: stage2.blocks.0.mlp.ln1.bn.weight, requires_grad: True
# Parameter name: stage2.blocks.0.mlp.ln1.bn.bias, requires_grad: True
# Parameter name: stage2.blocks.0.mlp.ln2.linear.weight, requires_grad: True
# Parameter name: stage2.blocks.0.mlp.ln2.linear.lora_a.weight, requires_grad: True
# Parameter name: stage2.blocks.0.mlp.ln2.linear.lora_b.weight, requires_grad: True
# Parameter name: stage2.blocks.0.mlp.ln2.bn.weight, requires_grad: True
# Parameter name: stage2.blocks.0.mlp.ln2.bn.bias, requires_grad: True
# Parameter name: stage2.blocks.1.attn.attention_biases, requires_grad: True
# Parameter name: stage2.blocks.1.attn.qkv.linear.weight, requires_grad: True
# Parameter name: stage2.blocks.1.attn.qkv.linear.lora_a.weight, requires_grad: True
# Parameter name: stage2.blocks.1.attn.qkv.linear.lora_b.weight, requires_grad: True
# Parameter name: stage2.blocks.1.attn.qkv.bn.weight, requires_grad: True
# Parameter name: stage2.blocks.1.attn.qkv.bn.bias, requires_grad: True
# Parameter name: stage2.blocks.1.attn.proj.1.linear.weight, requires_grad: True
# Parameter name: stage2.blocks.1.attn.proj.1.linear.lora_a.weight, requires_grad: True
# Parameter name: stage2.blocks.1.attn.proj.1.linear.lora_b.weight, requires_grad: True
# Parameter name: stage2.blocks.1.attn.proj.1.bn.weight, requires_grad: True
# Parameter name: stage2.blocks.1.attn.proj.1.bn.bias, requires_grad: True
# Parameter name: stage2.blocks.1.mlp.ln1.linear.weight, requires_grad: True
# Parameter name: stage2.blocks.1.mlp.ln1.linear.lora_a.weight, requires_grad: True
# Parameter name: stage2.blocks.1.mlp.ln1.linear.lora_b.weight, requires_grad: True
# Parameter name: stage2.blocks.1.mlp.ln1.bn.weight, requires_grad: True
# Parameter name: stage2.blocks.1.mlp.ln1.bn.bias, requires_grad: True
# Parameter name: stage2.blocks.1.mlp.ln2.linear.weight, requires_grad: True
# Parameter name: stage2.blocks.1.mlp.ln2.linear.lora_a.weight, requires_grad: True
# Parameter name: stage2.blocks.1.mlp.ln2.linear.lora_b.weight, requires_grad: True
# Parameter name: stage2.blocks.1.mlp.ln2.bn.weight, requires_grad: True
# Parameter name: stage2.blocks.1.mlp.ln2.bn.bias, requires_grad: True
# Parameter name: stage2.blocks.2.attn.attention_biases, requires_grad: True
# Parameter name: stage2.blocks.2.attn.qkv.linear.weight, requires_grad: True
# Parameter name: stage2.blocks.2.attn.qkv.linear.lora_a.weight, requires_grad: True
# Parameter name: stage2.blocks.2.attn.qkv.linear.lora_b.weight, requires_grad: True
# Parameter name: stage2.blocks.2.attn.qkv.bn.weight, requires_grad: True
# Parameter name: stage2.blocks.2.attn.qkv.bn.bias, requires_grad: True
# Parameter name: stage2.blocks.2.attn.proj.1.linear.weight, requires_grad: True
# Parameter name: stage2.blocks.2.attn.proj.1.linear.lora_a.weight, requires_grad: True
# Parameter name: stage2.blocks.2.attn.proj.1.linear.lora_b.weight, requires_grad: True
# Parameter name: stage2.blocks.2.attn.proj.1.bn.weight, requires_grad: True
# Parameter name: stage2.blocks.2.attn.proj.1.bn.bias, requires_grad: True
# Parameter name: stage2.blocks.2.mlp.ln1.linear.weight, requires_grad: True
# Parameter name: stage2.blocks.2.mlp.ln1.linear.lora_a.weight, requires_grad: True
# Parameter name: stage2.blocks.2.mlp.ln1.linear.lora_b.weight, requires_grad: True
# Parameter name: stage2.blocks.2.mlp.ln1.bn.weight, requires_grad: True
# Parameter name: stage2.blocks.2.mlp.ln1.bn.bias, requires_grad: True
# Parameter name: stage2.blocks.2.mlp.ln2.linear.weight, requires_grad: True
# Parameter name: stage2.blocks.2.mlp.ln2.linear.lora_a.weight, requires_grad: True
# Parameter name: stage2.blocks.2.mlp.ln2.linear.lora_b.weight, requires_grad: True
# Parameter name: stage2.blocks.2.mlp.ln2.bn.weight, requires_grad: True
# Parameter name: stage2.blocks.2.mlp.ln2.bn.bias, requires_grad: True
# Parameter name: stage2.blocks.3.attn.qkv.linear.weight, requires_grad: True
# Parameter name: stage2.blocks.3.attn.qkv.linear.lora_a.weight, requires_grad: True
# Parameter name: stage2.blocks.3.attn.qkv.linear.lora_b.weight, requires_grad: True
# Parameter name: stage2.blocks.3.attn.qkv.bn.weight, requires_grad: True
# Parameter name: stage2.blocks.3.attn.qkv.bn.bias, requires_grad: True
# Parameter name: stage2.blocks.3.attn.proj.1.linear.weight, requires_grad: True
# Parameter name: stage2.blocks.3.attn.proj.1.linear.lora_a.weight, requires_grad: True
# Parameter name: stage2.blocks.3.attn.proj.1.linear.lora_b.weight, requires_grad: True
# Parameter name: stage2.blocks.3.attn.proj.1.bn.weight, requires_grad: True
# Parameter name: stage2.blocks.3.attn.proj.1.bn.bias, requires_grad: True
# Parameter name: stage2.blocks.3.mlp.ln1.linear.weight, requires_grad: True
# Parameter name: stage2.blocks.3.mlp.ln1.linear.lora_a.weight, requires_grad: True
# Parameter name: stage2.blocks.3.mlp.ln1.linear.lora_b.weight, requires_grad: True
# Parameter name: stage2.blocks.3.mlp.ln1.bn.weight, requires_grad: True
# Parameter name: stage2.blocks.3.mlp.ln1.bn.bias, requires_grad: True
# Parameter name: stage2.blocks.3.mlp.ln2.linear.weight, requires_grad: True
# Parameter name: stage2.blocks.3.mlp.ln2.linear.lora_a.weight, requires_grad: True
# Parameter name: stage2.blocks.3.mlp.ln2.linear.lora_b.weight, requires_grad: True
# Parameter name: stage2.blocks.3.mlp.ln2.bn.weight, requires_grad: True
# Parameter name: stage2.blocks.3.mlp.ln2.bn.bias, requires_grad: True
# Parameter name: conv1x1.0.weight, requires_grad: True
# Parameter name: conv1x1.0.bias, requires_grad: True
# Parameter name: conv1x1.1.weight, requires_grad: True
# Parameter name: conv1x1.1.bias, requires_grad: True
# Parameter name: head.bn.weight, requires_grad: True
# Parameter name: head.bn.bias, requires_grad: True
# Parameter name: head.linear.weight, requires_grad: True
# Parameter name: head.linear.bias, requires_grad: True
# Parameter name: head_dist.bn.weight, requires_grad: True
# Parameter name: head_dist.bn.bias, requires_grad: True
# Parameter name: head_dist.linear.weight, requires_grad: True
# Parameter name: head_dist.linear.bias, requires_grad: True

# %%
for name, param in model.named_parameters():
    if "lora_a" in name or "lora_b" in name:
        param.requires_grad = True
        print(f"✅ LoRA Trainable: {name}")
    elif "gumbel_gate" in name:
        param.requires_grad = True
        print(f"✅ TinyFusion Trainable: {name}")
    elif "head" in name or "head_dist" in name:
        param.requires_grad = True
        print(f"✅ Head Trainable: {name}")
    elif "conv1x1" in name:
        param.requires_grad = True
        print(f"✅ Conv1x1 Trainable: {name}")
    #elif "attention_biases" in name:
        #param.requires_grad = True
        #print(f"✅ Attention Biases Trainable: {name}")
    else:
        param.requires_grad = False
# Out:
# ✅ TinyFusion Trainable: stage1.gumbel_gate
# ✅ LoRA Trainable: stage1.blocks.0.attn.qkv.linear.lora_a.weight
# ✅ LoRA Trainable: stage1.blocks.0.attn.qkv.linear.lora_b.weight
# ✅ LoRA Trainable: stage1.blocks.0.attn.proj.1.linear.lora_a.weight
# ✅ LoRA Trainable: stage1.blocks.0.attn.proj.1.linear.lora_b.weight
# ✅ LoRA Trainable: stage1.blocks.0.mlp.ln1.linear.lora_a.weight
# ✅ LoRA Trainable: stage1.blocks.0.mlp.ln1.linear.lora_b.weight
# ✅ LoRA Trainable: stage1.blocks.0.mlp.ln2.linear.lora_a.weight
# ✅ LoRA Trainable: stage1.blocks.0.mlp.ln2.linear.lora_b.weight
# ✅ LoRA Trainable: stage1.blocks.1.attn.qkv.linear.lora_a.weight
# ✅ LoRA Trainable: stage1.blocks.1.attn.qkv.linear.lora_b.weight
# ✅ LoRA Trainable: stage1.blocks.1.attn.proj.1.linear.lora_a.weight
# ✅ LoRA Trainable: stage1.blocks.1.attn.proj.1.linear.lora_b.weight
# ✅ LoRA Trainable: stage1.blocks.1.mlp.ln1.linear.lora_a.weight
# ✅ LoRA Trainable: stage1.blocks.1.mlp.ln1.linear.lora_b.weight
# ✅ LoRA Trainable: stage1.blocks.1.mlp.ln2.linear.lora_a.weight
# ✅ LoRA Trainable: stage1.blocks.1.mlp.ln2.linear.lora_b.weight
# ✅ LoRA Trainable: stage1.blocks.2.attn.qkv.linear.lora_a.weight
# ✅ LoRA Trainable: stage1.blocks.2.attn.qkv.linear.lora_b.weight
# ✅ LoRA Trainable: stage1.blocks.2.attn.proj.1.linear.lora_a.weight
# ✅ LoRA Trainable: stage1.blocks.2.attn.proj.1.linear.lora_b.weight
# ✅ LoRA Trainable: stage1.blocks.2.mlp.ln1.linear.lora_a.weight
# ✅ LoRA Trainable: stage1.blocks.2.mlp.ln1.linear.lora_b.weight
# ✅ LoRA Trainable: stage1.blocks.2.mlp.ln2.linear.lora_a.weight
# ✅ LoRA Trainable: stage1.blocks.2.mlp.ln2.linear.lora_b.weight
# ✅ LoRA Trainable: stage1.blocks.3.attn.qkv.linear.lora_a.weight
# ✅ LoRA Trainable: stage1.blocks.3.attn.qkv.linear.lora_b.weight
# ✅ LoRA Trainable: stage1.blocks.3.attn.proj.1.linear.lora_a.weight
# ✅ LoRA Trainable: stage1.blocks.3.attn.proj.1.linear.lora_b.weight
# ✅ LoRA Trainable: stage1.blocks.3.mlp.ln1.linear.lora_a.weight
# ✅ LoRA Trainable: stage1.blocks.3.mlp.ln1.linear.lora_b.weight
# ✅ LoRA Trainable: stage1.blocks.3.mlp.ln2.linear.lora_a.weight
# ✅ LoRA Trainable: stage1.blocks.3.mlp.ln2.linear.lora_b.weight
# ✅ TinyFusion Trainable: stage2.gumbel_gate
# ✅ LoRA Trainable: stage2.blocks.0.attn.qkv.linear.lora_a.weight
# ✅ LoRA Trainable: stage2.blocks.0.attn.qkv.linear.lora_b.weight
# ✅ LoRA Trainable: stage2.blocks.0.attn.proj.1.linear.lora_a.weight
# ✅ LoRA Trainable: stage2.blocks.0.attn.proj.1.linear.lora_b.weight
# ✅ LoRA Trainable: stage2.blocks.0.mlp.ln1.linear.lora_a.weight
# ✅ LoRA Trainable: stage2.blocks.0.mlp.ln1.linear.lora_b.weight
# ✅ LoRA Trainable: stage2.blocks.0.mlp.ln2.linear.lora_a.weight
# ✅ LoRA Trainable: stage2.blocks.0.mlp.ln2.linear.lora_b.weight
# ✅ LoRA Trainable: stage2.blocks.1.attn.qkv.linear.lora_a.weight
# ✅ LoRA Trainable: stage2.blocks.1.attn.qkv.linear.lora_b.weight
# ✅ LoRA Trainable: stage2.blocks.1.attn.proj.1.linear.lora_a.weight
# ✅ LoRA Trainable: stage2.blocks.1.attn.proj.1.linear.lora_b.weight
# ✅ LoRA Trainable: stage2.blocks.1.mlp.ln1.linear.lora_a.weight
# ✅ LoRA Trainable: stage2.blocks.1.mlp.ln1.linear.lora_b.weight
# ✅ LoRA Trainable: stage2.blocks.1.mlp.ln2.linear.lora_a.weight
# ✅ LoRA Trainable: stage2.blocks.1.mlp.ln2.linear.lora_b.weight
# ✅ LoRA Trainable: stage2.blocks.2.attn.qkv.linear.lora_a.weight
# ✅ LoRA Trainable: stage2.blocks.2.attn.qkv.linear.lora_b.weight
# ✅ LoRA Trainable: stage2.blocks.2.attn.proj.1.linear.lora_a.weight
# ✅ LoRA Trainable: stage2.blocks.2.attn.proj.1.linear.lora_b.weight
# ✅ LoRA Trainable: stage2.blocks.2.mlp.ln1.linear.lora_a.weight
# ✅ LoRA Trainable: stage2.blocks.2.mlp.ln1.linear.lora_b.weight
# ✅ LoRA Trainable: stage2.blocks.2.mlp.ln2.linear.lora_a.weight
# ✅ LoRA Trainable: stage2.blocks.2.mlp.ln2.linear.lora_b.weight
# ✅ LoRA Trainable: stage2.blocks.3.attn.qkv.linear.lora_a.weight
# ✅ LoRA Trainable: stage2.blocks.3.attn.qkv.linear.lora_b.weight
# ✅ LoRA Trainable: stage2.blocks.3.attn.proj.1.linear.lora_a.weight
# ✅ LoRA Trainable: stage2.blocks.3.attn.proj.1.linear.lora_b.weight
# ✅ LoRA Trainable: stage2.blocks.3.mlp.ln1.linear.lora_a.weight
# ✅ LoRA Trainable: stage2.blocks.3.mlp.ln1.linear.lora_b.weight
# ✅ LoRA Trainable: stage2.blocks.3.mlp.ln2.linear.lora_a.weight
# ✅ LoRA Trainable: stage2.blocks.3.mlp.ln2.linear.lora_b.weight
# ✅ Conv1x1 Trainable: conv1x1.0.weight
# ✅ Conv1x1 Trainable: conv1x1.0.bias
# ✅ Conv1x1 Trainable: conv1x1.1.weight
# ✅ Conv1x1 Trainable: conv1x1.1.bias
# ✅ Head Trainable: head.bn.weight
# ✅ Head Trainable: head.bn.bias
# ✅ Head Trainable: head.linear.weight
# ✅ Head Trainable: head.linear.bias
# ✅ Head Trainable: head_dist.bn.weight
# ✅ Head Trainable: head_dist.bn.bias
# ✅ Head Trainable: head_dist.linear.weight
# ✅ Head Trainable: head_dist.linear.bias

# %%
# gumbel_gate 파라미터가 포함되어 있는지 확인
for name, param in model.named_parameters():
    print(f"Parameter name: {name}, requires_grad: {param.requires_grad}")
# Out:
# Parameter name: stem.conv1.linear.weight, requires_grad: False
# Parameter name: stem.conv1.bn.weight, requires_grad: False
# Parameter name: stem.conv1.bn.bias, requires_grad: False
# Parameter name: stem.conv2.linear.weight, requires_grad: False
# Parameter name: stem.conv2.bn.weight, requires_grad: False
# Parameter name: stem.conv2.bn.bias, requires_grad: False
# Parameter name: stem.conv3.linear.weight, requires_grad: False
# Parameter name: stem.conv3.bn.weight, requires_grad: False
# Parameter name: stem.conv3.bn.bias, requires_grad: False
# Parameter name: stem.conv4.linear.weight, requires_grad: False
# Parameter name: stem.conv4.bn.weight, requires_grad: False
# Parameter name: stem.conv4.bn.bias, requires_grad: False
# Parameter name: stage1.gumbel_gate, requires_grad: True
# Parameter name: stage1.blocks.0.attn.attention_biases, requires_grad: False
# Parameter name: stage1.blocks.0.attn.qkv.linear.weight, requires_grad: False
# Parameter name: stage1.blocks.0.attn.qkv.linear.lora_a.weight, requires_grad: True
# Parameter name: stage1.blocks.0.attn.qkv.linear.lora_b.weight, requires_grad: True
# Parameter name: stage1.blocks.0.attn.qkv.bn.weight, requires_grad: False
# Parameter name: stage1.blocks.0.attn.qkv.bn.bias, requires_grad: False
# Parameter name: stage1.blocks.0.attn.proj.1.linear.weight, requires_grad: False
# Parameter name: stage1.blocks.0.attn.proj.1.linear.lora_a.weight, requires_grad: True
# Parameter name: stage1.blocks.0.attn.proj.1.linear.lora_b.weight, requires_grad: True
# Parameter name: stage1.blocks.0.attn.proj.1.bn.weight, requires_grad: False
# Parameter name: stage1.blocks.0.attn.proj.1.bn.bias, requires_grad: False
# Parameter name: stage1.blocks.0.mlp.ln1.linear.weight, requires_grad: False
# Parameter name: stage1.blocks.0.mlp.ln1.linear.lora_a.weight, requires_grad: True
# Parameter name: stage1.blocks.0.mlp.ln1.linear.lora_b.weight, requires_grad: True
# Parameter name: stage1.blocks.0.mlp.ln1.bn.weight, requires_grad: False
# Parameter name: stage1.blocks.0.mlp.ln1.bn.bias, requires_grad: False
# Parameter name: stage1.blocks.0.mlp.ln2.linear.weight, requires_grad: False
# Parameter name: stage1.blocks.0.mlp.ln2.linear.lora_a.weight, requires_grad: True
# Parameter name: stage1.blocks.0.mlp.ln2.linear.lora_b.weight, requires_grad: True
# Parameter name: stage1.blocks.0.mlp.ln2.bn.weight, requires_grad: False
# Parameter name: stage1.blocks.0.mlp.ln2.bn.bias, requires_grad: False
# Parameter name: stage1.blocks.1.attn.attention_biases, requires_grad: False
# Parameter name: stage1.blocks.1.attn.qkv.linear.weight, requires_grad: False
# Parameter name: stage1.blocks.1.attn.qkv.linear.lora_a.weight, requires_grad: True
# Parameter name: stage1.blocks.1.attn.qkv.linear.lora_b.weight, requires_grad: True
# Parameter name: stage1.blocks.1.attn.qkv.bn.weight, requires_grad: False
# Parameter name: stage1.blocks.1.attn.qkv.bn.bias, requires_grad: False
# Parameter name: stage1.blocks.1.attn.proj.1.linear.weight, requires_grad: False
# Parameter name: stage1.blocks.1.attn.proj.1.linear.lora_a.weight, requires_grad: True
# Parameter name: stage1.blocks.1.attn.proj.1.linear.lora_b.weight, requires_grad: True
# Parameter name: stage1.blocks.1.attn.proj.1.bn.weight, requires_grad: False
# Parameter name: stage1.blocks.1.attn.proj.1.bn.bias, requires_grad: False
# Parameter name: stage1.blocks.1.mlp.ln1.linear.weight, requires_grad: False
# Parameter name: stage1.blocks.1.mlp.ln1.linear.lora_a.weight, requires_grad: True
# Parameter name: stage1.blocks.1.mlp.ln1.linear.lora_b.weight, requires_grad: True
# Parameter name: stage1.blocks.1.mlp.ln1.bn.weight, requires_grad: False
# Parameter name: stage1.blocks.1.mlp.ln1.bn.bias, requires_grad: False
# Parameter name: stage1.blocks.1.mlp.ln2.linear.weight, requires_grad: False
# Parameter name: stage1.blocks.1.mlp.ln2.linear.lora_a.weight, requires_grad: True
# Parameter name: stage1.blocks.1.mlp.ln2.linear.lora_b.weight, requires_grad: True
# Parameter name: stage1.blocks.1.mlp.ln2.bn.weight, requires_grad: False
# Parameter name: stage1.blocks.1.mlp.ln2.bn.bias, requires_grad: False
# Parameter name: stage1.blocks.2.attn.attention_biases, requires_grad: False
# Parameter name: stage1.blocks.2.attn.qkv.linear.weight, requires_grad: False
# Parameter name: stage1.blocks.2.attn.qkv.linear.lora_a.weight, requires_grad: True
# Parameter name: stage1.blocks.2.attn.qkv.linear.lora_b.weight, requires_grad: True
# Parameter name: stage1.blocks.2.attn.qkv.bn.weight, requires_grad: False
# Parameter name: stage1.blocks.2.attn.qkv.bn.bias, requires_grad: False
# Parameter name: stage1.blocks.2.attn.proj.1.linear.weight, requires_grad: False
# Parameter name: stage1.blocks.2.attn.proj.1.linear.lora_a.weight, requires_grad: True
# Parameter name: stage1.blocks.2.attn.proj.1.linear.lora_b.weight, requires_grad: True
# Parameter name: stage1.blocks.2.attn.proj.1.bn.weight, requires_grad: False
# Parameter name: stage1.blocks.2.attn.proj.1.bn.bias, requires_grad: False
# Parameter name: stage1.blocks.2.mlp.ln1.linear.weight, requires_grad: False
# Parameter name: stage1.blocks.2.mlp.ln1.linear.lora_a.weight, requires_grad: True
# Parameter name: stage1.blocks.2.mlp.ln1.linear.lora_b.weight, requires_grad: True
# Parameter name: stage1.blocks.2.mlp.ln1.bn.weight, requires_grad: False
# Parameter name: stage1.blocks.2.mlp.ln1.bn.bias, requires_grad: False
# Parameter name: stage1.blocks.2.mlp.ln2.linear.weight, requires_grad: False
# Parameter name: stage1.blocks.2.mlp.ln2.linear.lora_a.weight, requires_grad: True
# Parameter name: stage1.blocks.2.mlp.ln2.linear.lora_b.weight, requires_grad: True
# Parameter name: stage1.blocks.2.mlp.ln2.bn.weight, requires_grad: False
# Parameter name: stage1.blocks.2.mlp.ln2.bn.bias, requires_grad: False
# Parameter name: stage1.blocks.3.attn.qkv.linear.weight, requires_grad: False
# Parameter name: stage1.blocks.3.attn.qkv.linear.lora_a.weight, requires_grad: True
# Parameter name: stage1.blocks.3.attn.qkv.linear.lora_b.weight, requires_grad: True
# Parameter name: stage1.blocks.3.attn.qkv.bn.weight, requires_grad: False
# Parameter name: stage1.blocks.3.attn.qkv.bn.bias, requires_grad: False
# Parameter name: stage1.blocks.3.attn.proj.1.linear.weight, requires_grad: False
# Parameter name: stage1.blocks.3.attn.proj.1.linear.lora_a.weight, requires_grad: True
# Parameter name: stage1.blocks.3.attn.proj.1.linear.lora_b.weight, requires_grad: True
# Parameter name: stage1.blocks.3.attn.proj.1.bn.weight, requires_grad: False
# Parameter name: stage1.blocks.3.attn.proj.1.bn.bias, requires_grad: False
# Parameter name: stage1.blocks.3.mlp.ln1.linear.weight, requires_grad: False
# Parameter name: stage1.blocks.3.mlp.ln1.linear.lora_a.weight, requires_grad: True
# Parameter name: stage1.blocks.3.mlp.ln1.linear.lora_b.weight, requires_grad: True
# Parameter name: stage1.blocks.3.mlp.ln1.bn.weight, requires_grad: False
# Parameter name: stage1.blocks.3.mlp.ln1.bn.bias, requires_grad: False
# Parameter name: stage1.blocks.3.mlp.ln2.linear.weight, requires_grad: False
# Parameter name: stage1.blocks.3.mlp.ln2.linear.lora_a.weight, requires_grad: True
# Parameter name: stage1.blocks.3.mlp.ln2.linear.lora_b.weight, requires_grad: True
# Parameter name: stage1.blocks.3.mlp.ln2.bn.weight, requires_grad: False
# Parameter name: stage1.blocks.3.mlp.ln2.bn.bias, requires_grad: False
# Parameter name: stage2.gumbel_gate, requires_grad: True
# Parameter name: stage2.downsample.conv.weight, requires_grad: False
# Parameter name: stage2.downsample.conv.bias, requires_grad: False
# Parameter name: stage2.blocks.0.attn.attention_biases, requires_grad: False
# Parameter name: stage2.blocks.0.attn.qkv.linear.weight, requires_grad: False
# Parameter name: stage2.blocks.0.attn.qkv.linear.lora_a.weight, requires_grad: True
# Parameter name: stage2.blocks.0.attn.qkv.linear.lora_b.weight, requires_grad: True
# Parameter name: stage2.blocks.0.attn.qkv.bn.weight, requires_grad: False
# Parameter name: stage2.blocks.0.attn.qkv.bn.bias, requires_grad: False
# Parameter name: stage2.blocks.0.attn.proj.1.linear.weight, requires_grad: False
# Parameter name: stage2.blocks.0.attn.proj.1.linear.lora_a.weight, requires_grad: True
# Parameter name: stage2.blocks.0.attn.proj.1.linear.lora_b.weight, requires_grad: True
# Parameter name: stage2.blocks.0.attn.proj.1.bn.weight, requires_grad: False
# Parameter name: stage2.blocks.0.attn.proj.1.bn.bias, requires_grad: False
# Parameter name: stage2.blocks.0.mlp.ln1.linear.weight, requires_grad: False
# Parameter name: stage2.blocks.0.mlp.ln1.linear.lora_a.weight, requires_grad: True
# Parameter name: stage2.blocks.0.mlp.ln1.linear.lora_b.weight, requires_grad: True
# Parameter name: stage2.blocks.0.mlp.ln1.bn.weight, requires_grad: False
# Parameter name: stage2.blocks.0.mlp.ln1.bn.bias, requires_grad: False
# Parameter name: stage2.blocks.0.mlp.ln2.linear.weight, requires_grad: False
# Parameter name: stage2.blocks.0.mlp.ln2.linear.lora_a.weight, requires_grad: True
# Parameter name: stage2.blocks.0.mlp.ln2.linear.lora_b.weight, requires_grad: True
# Parameter name: stage2.blocks.0.mlp.ln2.bn.weight, requires_grad: False
# Parameter name: stage2.blocks.0.mlp.ln2.bn.bias, requires_grad: False
# Parameter name: stage2.blocks.1.attn.attention_biases, requires_grad: False
# Parameter name: stage2.blocks.1.attn.qkv.linear.weight, requires_grad: False
# Parameter name: stage2.blocks.1.attn.qkv.linear.lora_a.weight, requires_grad: True
# Parameter name: stage2.blocks.1.attn.qkv.linear.lora_b.weight, requires_grad: True
# Parameter name: stage2.blocks.1.attn.qkv.bn.weight, requires_grad: False
# Parameter name: stage2.blocks.1.attn.qkv.bn.bias, requires_grad: False
# Parameter name: stage2.blocks.1.attn.proj.1.linear.weight, requires_grad: False
# Parameter name: stage2.blocks.1.attn.proj.1.linear.lora_a.weight, requires_grad: True
# Parameter name: stage2.blocks.1.attn.proj.1.linear.lora_b.weight, requires_grad: True
# Parameter name: stage2.blocks.1.attn.proj.1.bn.weight, requires_grad: False
# Parameter name: stage2.blocks.1.attn.proj.1.bn.bias, requires_grad: False
# Parameter name: stage2.blocks.1.mlp.ln1.linear.weight, requires_grad: False
# Parameter name: stage2.blocks.1.mlp.ln1.linear.lora_a.weight, requires_grad: True
# Parameter name: stage2.blocks.1.mlp.ln1.linear.lora_b.weight, requires_grad: True
# Parameter name: stage2.blocks.1.mlp.ln1.bn.weight, requires_grad: False
# Parameter name: stage2.blocks.1.mlp.ln1.bn.bias, requires_grad: False
# Parameter name: stage2.blocks.1.mlp.ln2.linear.weight, requires_grad: False
# Parameter name: stage2.blocks.1.mlp.ln2.linear.lora_a.weight, requires_grad: True
# Parameter name: stage2.blocks.1.mlp.ln2.linear.lora_b.weight, requires_grad: True
# Parameter name: stage2.blocks.1.mlp.ln2.bn.weight, requires_grad: False
# Parameter name: stage2.blocks.1.mlp.ln2.bn.bias, requires_grad: False
# Parameter name: stage2.blocks.2.attn.attention_biases, requires_grad: False
# Parameter name: stage2.blocks.2.attn.qkv.linear.weight, requires_grad: False
# Parameter name: stage2.blocks.2.attn.qkv.linear.lora_a.weight, requires_grad: True
# Parameter name: stage2.blocks.2.attn.qkv.linear.lora_b.weight, requires_grad: True
# Parameter name: stage2.blocks.2.attn.qkv.bn.weight, requires_grad: False
# Parameter name: stage2.blocks.2.attn.qkv.bn.bias, requires_grad: False
# Parameter name: stage2.blocks.2.attn.proj.1.linear.weight, requires_grad: False
# Parameter name: stage2.blocks.2.attn.proj.1.linear.lora_a.weight, requires_grad: True
# Parameter name: stage2.blocks.2.attn.proj.1.linear.lora_b.weight, requires_grad: True
# Parameter name: stage2.blocks.2.attn.proj.1.bn.weight, requires_grad: False
# Parameter name: stage2.blocks.2.attn.proj.1.bn.bias, requires_grad: False
# Parameter name: stage2.blocks.2.mlp.ln1.linear.weight, requires_grad: False
# Parameter name: stage2.blocks.2.mlp.ln1.linear.lora_a.weight, requires_grad: True
# Parameter name: stage2.blocks.2.mlp.ln1.linear.lora_b.weight, requires_grad: True
# Parameter name: stage2.blocks.2.mlp.ln1.bn.weight, requires_grad: False
# Parameter name: stage2.blocks.2.mlp.ln1.bn.bias, requires_grad: False
# Parameter name: stage2.blocks.2.mlp.ln2.linear.weight, requires_grad: False
# Parameter name: stage2.blocks.2.mlp.ln2.linear.lora_a.weight, requires_grad: True
# Parameter name: stage2.blocks.2.mlp.ln2.linear.lora_b.weight, requires_grad: True
# Parameter name: stage2.blocks.2.mlp.ln2.bn.weight, requires_grad: False
# Parameter name: stage2.blocks.2.mlp.ln2.bn.bias, requires_grad: False
# Parameter name: stage2.blocks.3.attn.qkv.linear.weight, requires_grad: False
# Parameter name: stage2.blocks.3.attn.qkv.linear.lora_a.weight, requires_grad: True
# Parameter name: stage2.blocks.3.attn.qkv.linear.lora_b.weight, requires_grad: True
# Parameter name: stage2.blocks.3.attn.qkv.bn.weight, requires_grad: False
# Parameter name: stage2.blocks.3.attn.qkv.bn.bias, requires_grad: False
# Parameter name: stage2.blocks.3.attn.proj.1.linear.weight, requires_grad: False
# Parameter name: stage2.blocks.3.attn.proj.1.linear.lora_a.weight, requires_grad: True
# Parameter name: stage2.blocks.3.attn.proj.1.linear.lora_b.weight, requires_grad: True
# Parameter name: stage2.blocks.3.attn.proj.1.bn.weight, requires_grad: False
# Parameter name: stage2.blocks.3.attn.proj.1.bn.bias, requires_grad: False
# Parameter name: stage2.blocks.3.mlp.ln1.linear.weight, requires_grad: False
# Parameter name: stage2.blocks.3.mlp.ln1.linear.lora_a.weight, requires_grad: True
# Parameter name: stage2.blocks.3.mlp.ln1.linear.lora_b.weight, requires_grad: True
# Parameter name: stage2.blocks.3.mlp.ln1.bn.weight, requires_grad: False
# Parameter name: stage2.blocks.3.mlp.ln1.bn.bias, requires_grad: False
# Parameter name: stage2.blocks.3.mlp.ln2.linear.weight, requires_grad: False
# Parameter name: stage2.blocks.3.mlp.ln2.linear.lora_a.weight, requires_grad: True
# Parameter name: stage2.blocks.3.mlp.ln2.linear.lora_b.weight, requires_grad: True
# Parameter name: stage2.blocks.3.mlp.ln2.bn.weight, requires_grad: False
# Parameter name: stage2.blocks.3.mlp.ln2.bn.bias, requires_grad: False
# Parameter name: conv1x1.0.weight, requires_grad: True
# Parameter name: conv1x1.0.bias, requires_grad: True
# Parameter name: conv1x1.1.weight, requires_grad: True
# Parameter name: conv1x1.1.bias, requires_grad: True
# Parameter name: head.bn.weight, requires_grad: True
# Parameter name: head.bn.bias, requires_grad: True
# Parameter name: head.linear.weight, requires_grad: True
# Parameter name: head.linear.bias, requires_grad: True
# Parameter name: head_dist.bn.weight, requires_grad: True
# Parameter name: head_dist.bn.bias, requires_grad: True
# Parameter name: head_dist.linear.weight, requires_grad: True
# Parameter name: head_dist.linear.bias, requires_grad: True

# %%
for epoch in range(num_epochs):
    print(f"\nEpoch {epoch+1}/{num_epochs}")
    train(model, train_loader, criterion, optimizer, device, epoch)
    evaluate(model, val_loader, criterion, device, phase="Validation", epoch=epoch)
    if((epoch + 1) % 10 == 0 and epoch > 10):
        save_path = f"HoViT_44_tinyfusion_base_r16a32_{epoch}.pth"
        torch.save(model.state_dict(), save_path)
        print(f"Model weights saved to {save_path}")
        print(f"{epoch+1} model test result:")
        evaluate(model, test_loader, criterion, device, phase="Test")
# Out:
# Epoch 1/100
# Training: 100%|██████████| 2188/2188 [01:53<00:00, 19.23it/s]
# Train Loss: 0.3946, Train Accuracy: 86.34%
# Tau: 0.9910
# Each stage of block probabilities:
# stage1
# Block 0: 0.9387
# Block 1: 0.0249
# Block 2: 0.0243 *
# Block 3: 0.0121 *
# stage2
# Block 0: 0.7365
# Block 1: 0.1081
# Block 2: 0.0861 *
# Block 3: 0.0693 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 68.26it/s]
# Tau: 0.9910
# Validation Loss: 0.2867, Validation Accuracy: 89.89%
# Balanced Accuracy: 0.8948
# New best model saved with Validation loss 0.2867 at best_model.pth
#
# Epoch 2/100
# Training: 100%|██████████| 2188/2188 [01:53<00:00, 19.20it/s]
# Train Loss: 0.2149, Train Accuracy: 92.67%
# Tau: 0.9820
# Each stage of block probabilities:
# stage1
# Block 0: 0.9874
# Block 1: 0.0059
# Block 2: 0.0043 *
# Block 3: 0.0024 *
# stage2
# Block 0: 0.8991
# Block 1: 0.0424
# Block 2: 0.0353 *
# Block 3: 0.0232 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 70.31it/s]
# Tau: 0.9820
# Validation Loss: 0.1811, Validation Accuracy: 93.59%
# Balanced Accuracy: 0.9340
# New best model saved with Validation loss 0.1811 at best_model.pth
#
# Epoch 3/100
# Training: 100%|██████████| 2188/2188 [01:54<00:00, 19.15it/s]
# Train Loss: 0.1764, Train Accuracy: 94.05%
# Tau: 0.9730
# Each stage of block probabilities:
# stage1
# Block 0: 0.9963
# Block 1: 0.0016
# Block 2: 0.0013 *
# Block 3: 0.0007 *
# stage2
# Block 0: 0.9690
# Block 1: 0.0112 *
# Block 2: 0.0125
# Block 3: 0.0073 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 70.71it/s]
# Tau: 0.9730
# Validation Loss: 0.1986, Validation Accuracy: 92.96%
# Balanced Accuracy: 0.9304
#
# Epoch 4/100
# Training: 100%|██████████| 2188/2188 [01:54<00:00, 19.12it/s]
# Train Loss: 0.1551, Train Accuracy: 94.73%
# Tau: 0.9640
# Each stage of block probabilities:
# stage1
# Block 0: 0.9980
# Block 1: 0.0009
# Block 2: 0.0007 *
# Block 3: 0.0004 *
# stage2
# Block 0: 0.9813
# Block 1: 0.0069 *
# Block 2: 0.0086
# Block 3: 0.0032 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 73.37it/s]
# Tau: 0.9640
# Validation Loss: 0.1533, Validation Accuracy: 94.72%
# Balanced Accuracy: 0.9471
# New best model saved with Validation loss 0.1533 at best_model.pth
#
# Epoch 5/100
# Training: 100%|██████████| 2188/2188 [01:54<00:00, 19.12it/s]
# Train Loss: 0.1393, Train Accuracy: 95.31%
# Tau: 0.9550
# Each stage of block probabilities:
# stage1
# Block 0: 0.9990
# Block 1: 0.0004
# Block 2: 0.0004 *
# Block 3: 0.0002 *
# stage2
# Block 0: 0.9916
# Block 1: 0.0032 *
# Block 2: 0.0035
# Block 3: 0.0017 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 70.22it/s]
# Tau: 0.9550
# Validation Loss: 0.1532, Validation Accuracy: 94.62%
# Balanced Accuracy: 0.9460
# New best model saved with Validation loss 0.1532 at best_model.pth
#
# Epoch 6/100
# Training: 100%|██████████| 2188/2188 [01:53<00:00, 19.27it/s]
# Train Loss: 0.1322, Train Accuracy: 95.50%
# Tau: 0.9460
# Each stage of block probabilities:
# stage1
# Block 0: 0.9994
# Block 1: 0.0003
# Block 2: 0.0002 *
# Block 3: 0.0002 *
# stage2
# Block 0: 0.9967
# Block 1: 0.0010 *
# Block 2: 0.0015
# Block 3: 0.0008 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 67.80it/s]
# Tau: 0.9460
# Validation Loss: 0.1168, Validation Accuracy: 95.98%
# Balanced Accuracy: 0.9592
# New best model saved with Validation loss 0.1168 at best_model.pth
#
# Epoch 7/100
# Training: 100%|██████████| 2188/2188 [01:54<00:00, 19.08it/s]
# Train Loss: 0.1220, Train Accuracy: 95.75%
# Tau: 0.9370
# Each stage of block probabilities:
# stage1
# Block 0: 0.9996
# Block 1: 0.0002
# Block 2: 0.0001 *
# Block 3: 0.0001 *
# stage2
# Block 0: 0.9957
# Block 1: 0.0012 *
# Block 2: 0.0021
# Block 3: 0.0010 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 68.31it/s]
# Tau: 0.9370
# Validation Loss: 0.1307, Validation Accuracy: 95.64%
# Balanced Accuracy: 0.9581
#
# Epoch 8/100
# Training: 100%|██████████| 2188/2188 [01:54<00:00, 19.16it/s]
# Train Loss: 0.1140, Train Accuracy: 96.04%
# Tau: 0.9280
# Each stage of block probabilities:
# stage1
# Block 0: 0.9997
# Block 1: 0.0001
# Block 2: 0.0001 *
# Block 3: 0.0001 *
# stage2
# Block 0: 0.9967
# Block 1: 0.0010 *
# Block 2: 0.0016
# Block 3: 0.0006 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 71.24it/s]
# Tau: 0.9280
# Validation Loss: 0.1117, Validation Accuracy: 96.13%
# Balanced Accuracy: 0.9610
# New best model saved with Validation loss 0.1117 at best_model.pth
#
# Epoch 9/100
# Training: 100%|██████████| 2188/2188 [01:54<00:00, 19.15it/s]
# Train Loss: 0.1118, Train Accuracy: 96.15%
# Tau: 0.9190
# Each stage of block probabilities:
# stage1
# Block 0: 0.9998
# Block 1: 0.0001
# Block 2: 0.0001 *
# Block 3: 0.0001 *
# stage2
# Block 0: 0.9981
# Block 1: 0.0006 *
# Block 2: 0.0009
# Block 3: 0.0003 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 70.68it/s]
# Tau: 0.9190
# Validation Loss: 0.1322, Validation Accuracy: 95.45%
# Balanced Accuracy: 0.9554
#
# Epoch 10/100
# Training: 100%|██████████| 2188/2188 [01:54<00:00, 19.16it/s]
# Train Loss: 0.1054, Train Accuracy: 96.37%
# Tau: 0.9100
# Each stage of block probabilities:
# stage1
# Block 0: 0.9998
# Block 1: 0.0001
# Block 2: 0.0001 *
# Block 3: 0.0001 *
# stage2
# Block 0: 0.9989
# Block 1: 0.0004 *
# Block 2: 0.0004
# Block 3: 0.0002 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 68.87it/s]
# Tau: 0.9100
# Validation Loss: 0.1210, Validation Accuracy: 95.76%
# Balanced Accuracy: 0.9570
#
# Epoch 11/100
# Training: 100%|██████████| 2188/2188 [01:54<00:00, 19.10it/s]
# Train Loss: 0.0993, Train Accuracy: 96.54%
# Tau: 0.9010
# Each stage of block probabilities:
# stage1
# Block 0: 0.9999
# Block 1: 0.0001
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# stage2
# Block 0: 0.9985
# Block 1: 0.0004 *
# Block 2: 0.0006
# Block 3: 0.0004 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 70.13it/s]
# Tau: 0.9010
# Validation Loss: 0.1227, Validation Accuracy: 95.73%
# Balanced Accuracy: 0.9584
#
# Epoch 12/100
# Training: 100%|██████████| 2188/2188 [01:54<00:00, 19.06it/s]
# Train Loss: 0.0969, Train Accuracy: 96.65%
# Tau: 0.8920
# Each stage of block probabilities:
# stage1
# Block 0: 0.9999
# Block 1: 0.0001
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# stage2
# Block 0: 0.9988
# Block 1: 0.0003 *
# Block 2: 0.0005
# Block 3: 0.0004 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 71.61it/s]
# Tau: 0.8920
# Validation Loss: 0.1302, Validation Accuracy: 95.65%
# Balanced Accuracy: 0.9577
#
# Epoch 13/100
# Training: 100%|██████████| 2188/2188 [01:54<00:00, 19.12it/s]
# Train Loss: 0.0923, Train Accuracy: 96.85%
# Tau: 0.8830
# Each stage of block probabilities:
# stage1
# Block 0: 0.9999
# Block 1: 0.0000
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# stage2
# Block 0: 0.9993
# Block 1: 0.0003
# Block 2: 0.0002 *
# Block 3: 0.0002 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 69.12it/s]
# Tau: 0.8830
# Validation Loss: 0.1106, Validation Accuracy: 96.21%
# Balanced Accuracy: 0.9625
# New best model saved with Validation loss 0.1106 at best_model.pth
#
# Epoch 14/100
# Training: 100%|██████████| 2188/2188 [01:54<00:00, 19.16it/s]
# Train Loss: 0.0897, Train Accuracy: 96.91%
# Tau: 0.8740
# Each stage of block probabilities:
# stage1
# Block 0: 0.9999
# Block 1: 0.0001
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# stage2
# Block 0: 0.9995
# Block 1: 0.0002
# Block 2: 0.0001 *
# Block 3: 0.0001 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 70.17it/s]
# Tau: 0.8740
# Validation Loss: 0.1235, Validation Accuracy: 95.95%
# Balanced Accuracy: 0.9609
#
# Epoch 15/100
# Training: 100%|██████████| 2188/2188 [01:53<00:00, 19.22it/s]
# Train Loss: 0.0857, Train Accuracy: 97.05%
# Tau: 0.8650
# Each stage of block probabilities:
# stage1
# Block 0: 0.9999
# Block 1: 0.0001
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# stage2
# Block 0: 0.9997
# Block 1: 0.0001
# Block 2: 0.0001 *
# Block 3: 0.0001 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 71.99it/s]
# Tau: 0.8650
# Validation Loss: 0.1286, Validation Accuracy: 95.91%
# Balanced Accuracy: 0.9607
#
# Epoch 16/100
# Training: 100%|██████████| 2188/2188 [01:53<00:00, 19.23it/s]
# Train Loss: 0.0874, Train Accuracy: 97.01%
# Tau: 0.8560
# Each stage of block probabilities:
# stage1
# Block 0: 0.9999
# Block 1: 0.0000
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# stage2
# Block 0: 0.9997
# Block 1: 0.0001
# Block 2: 0.0001 *
# Block 3: 0.0001 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 73.63it/s]
# Tau: 0.8560
# Validation Loss: 0.1250, Validation Accuracy: 96.07%
# Balanced Accuracy: 0.9622
#
# Epoch 17/100
# Training: 100%|██████████| 2188/2188 [01:54<00:00, 19.13it/s]
# Train Loss: 0.0816, Train Accuracy: 97.22%
# Tau: 0.8470
# Each stage of block probabilities:
# stage1
# Block 0: 0.9999
# Block 1: 0.0000
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# stage2
# Block 0: 0.9997
# Block 1: 0.0001 *
# Block 2: 0.0001
# Block 3: 0.0001 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 68.76it/s]
# Tau: 0.8470
# Validation Loss: 0.1263, Validation Accuracy: 95.99%
# Balanced Accuracy: 0.9606
#
# Epoch 18/100
# Training: 100%|██████████| 2188/2188 [01:54<00:00, 19.17it/s]
# Train Loss: 0.0796, Train Accuracy: 97.27%
# Tau: 0.8380
# Each stage of block probabilities:
# stage1
# Block 0: 0.9999
# Block 1: 0.0000
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# stage2
# Block 0: 0.9997
# Block 1: 0.0001 *
# Block 2: 0.0001
# Block 3: 0.0001 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 67.64it/s]
# Tau: 0.8380
# Validation Loss: 0.1351, Validation Accuracy: 95.48%
# Balanced Accuracy: 0.9562
#
# Epoch 19/100
# Training: 100%|██████████| 2188/2188 [01:53<00:00, 19.20it/s]
# Train Loss: 0.0785, Train Accuracy: 97.30%
# Tau: 0.8290
# Each stage of block probabilities:
# stage1
# Block 0: 0.9999
# Block 1: 0.0000
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# stage2
# Block 0: 0.9998
# Block 1: 0.0001 *
# Block 2: 0.0001 *
# Block 3: 0.0001
# Validation: 100%|██████████| 469/469 [00:06<00:00, 72.32it/s]
# Tau: 0.8290
# Validation Loss: 0.1116, Validation Accuracy: 96.37%
# Balanced Accuracy: 0.9641
#
# Epoch 20/100
# Training: 100%|██████████| 2188/2188 [01:54<00:00, 19.19it/s]
# Train Loss: 0.0778, Train Accuracy: 97.27%
# Tau: 0.8200
# Each stage of block probabilities:
# stage1
# Block 0: 0.9999
# Block 1: 0.0001
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# stage2
# Block 0: 0.9997
# Block 1: 0.0001
# Block 2: 0.0001 *
# Block 3: 0.0001 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 70.74it/s]
# Tau: 0.8200
# Validation Loss: 0.1172, Validation Accuracy: 96.35%
# Balanced Accuracy: 0.9645
# Model weights saved to HoViT_44_tinyfusion_base_r16a32_19.pth
# 20 model test result:
# Test: 100%|██████████| 469/469 [00:07<00:00, 66.28it/s]
# Tau: 0.0000
# Test Loss: 0.1138, Test Accuracy: 96.55%
# Balanced Accuracy: 0.9667
#
# Epoch 21/100
# Training: 100%|██████████| 2188/2188 [01:55<00:00, 18.96it/s]
# Train Loss: 0.0743, Train Accuracy: 97.41%
# Tau: 0.8110
# Each stage of block probabilities:
# stage1
# Block 0: 0.9999
# Block 1: 0.0001
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# stage2
# Block 0: 0.9998
# Block 1: 0.0001 *
# Block 2: 0.0001 *
# Block 3: 0.0001
# Validation: 100%|██████████| 469/469 [00:06<00:00, 73.24it/s]
# Tau: 0.8110
# Validation Loss: 0.1253, Validation Accuracy: 96.04%
# Balanced Accuracy: 0.9618
#
# Epoch 22/100
# Training: 100%|██████████| 2188/2188 [01:53<00:00, 19.25it/s]
# Train Loss: 0.0736, Train Accuracy: 97.46%
# Tau: 0.8020
# Each stage of block probabilities:
# stage1
# Block 0: 0.9999
# Block 1: 0.0001
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# stage2
# Block 0: 0.9997
# Block 1: 0.0001 *
# Block 2: 0.0001 *
# Block 3: 0.0001
# Validation: 100%|██████████| 469/469 [00:06<00:00, 72.03it/s]
# Tau: 0.8020
# Validation Loss: 0.1092, Validation Accuracy: 96.55%
# Balanced Accuracy: 0.9653
# New best model saved with Validation loss 0.1092 at best_model.pth
#
# Epoch 23/100
# Training: 100%|██████████| 2188/2188 [01:54<00:00, 19.18it/s]
# Train Loss: 0.0707, Train Accuracy: 97.50%
# Tau: 0.7930
# Each stage of block probabilities:
# stage1
# Block 0: 0.9999
# Block 1: 0.0000
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# stage2
# Block 0: 0.9997
# Block 1: 0.0001 *
# Block 2: 0.0001 *
# Block 3: 0.0002
# Validation: 100%|██████████| 469/469 [00:06<00:00, 68.66it/s]
# Tau: 0.7930
# Validation Loss: 0.1112, Validation Accuracy: 96.53%
# Balanced Accuracy: 0.9664
#
# Epoch 24/100
# Training: 100%|██████████| 2188/2188 [01:53<00:00, 19.27it/s]
# Train Loss: 0.0713, Train Accuracy: 97.53%
# Tau: 0.7840
# Each stage of block probabilities:
# stage1
# Block 0: 0.9999
# Block 1: 0.0001
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# stage2
# Block 0: 0.9997
# Block 1: 0.0001 *
# Block 2: 0.0001 *
# Block 3: 0.0002
# Validation: 100%|██████████| 469/469 [00:06<00:00, 67.43it/s]
# Tau: 0.7840
# Validation Loss: 0.1016, Validation Accuracy: 96.85%
# Balanced Accuracy: 0.9686
# New best model saved with Validation loss 0.1016 at best_model.pth
#
# Epoch 25/100
# Training: 100%|██████████| 2188/2188 [01:53<00:00, 19.30it/s]
# Train Loss: 0.0675, Train Accuracy: 97.67%
# Tau: 0.7750
# Each stage of block probabilities:
# stage1
# Block 0: 0.9999
# Block 1: 0.0001
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# stage2
# Block 0: 0.9997
# Block 1: 0.0001 *
# Block 2: 0.0000 *
# Block 3: 0.0002
# Validation: 100%|██████████| 469/469 [00:06<00:00, 69.97it/s]
# Tau: 0.7750
# Validation Loss: 0.1113, Validation Accuracy: 96.55%
# Balanced Accuracy: 0.9663
#
# Epoch 26/100
# Training: 100%|██████████| 2188/2188 [01:53<00:00, 19.25it/s]
# Train Loss: 0.0676, Train Accuracy: 97.67%
# Tau: 0.7660
# Each stage of block probabilities:
# stage1
# Block 0: 0.9999
# Block 1: 0.0001
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# stage2
# Block 0: 0.9998
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0001
# Validation: 100%|██████████| 469/469 [00:06<00:00, 73.03it/s]
# Tau: 0.7660
# Validation Loss: 0.1083, Validation Accuracy: 96.63%
# Balanced Accuracy: 0.9670
#
# Epoch 27/100
# Training: 100%|██████████| 2188/2188 [01:53<00:00, 19.33it/s]
# Train Loss: 0.0670, Train Accuracy: 97.64%
# Tau: 0.7570
# Each stage of block probabilities:
# stage1
# Block 0: 0.9999
# Block 1: 0.0001
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# stage2
# Block 0: 0.9998
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0001
# Validation: 100%|██████████| 469/469 [00:06<00:00, 69.05it/s]
# Tau: 0.7570
# Validation Loss: 0.1224, Validation Accuracy: 96.53%
# Balanced Accuracy: 0.9658
#
# Epoch 28/100
# Training: 100%|██████████| 2188/2188 [01:54<00:00, 19.18it/s]
# Train Loss: 0.0659, Train Accuracy: 97.70%
# Tau: 0.7480
# Each stage of block probabilities:
# stage1
# Block 0: 0.9999
# Block 1: 0.0001
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# stage2
# Block 0: 0.9998
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0001
# Validation: 100%|██████████| 469/469 [00:06<00:00, 70.72it/s]
# Tau: 0.7480
# Validation Loss: 0.1035, Validation Accuracy: 96.75%
# Balanced Accuracy: 0.9684
#
# Epoch 29/100
# Training: 100%|██████████| 2188/2188 [01:53<00:00, 19.24it/s]
# Train Loss: 0.0643, Train Accuracy: 97.80%
# Tau: 0.7390
# Each stage of block probabilities:
# stage1
# Block 0: 0.9999
# Block 1: 0.0001
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# stage2
# Block 0: 0.9999
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0001
# Validation: 100%|██████████| 469/469 [00:06<00:00, 69.76it/s]
# Tau: 0.7390
# Validation Loss: 0.1212, Validation Accuracy: 96.39%
# Balanced Accuracy: 0.9653
#
# Epoch 30/100
# Training: 100%|██████████| 2188/2188 [01:54<00:00, 19.17it/s]
# Train Loss: 0.0624, Train Accuracy: 97.79%
# Tau: 0.7300
# Each stage of block probabilities:
# stage1
# Block 0: 0.9999
# Block 1: 0.0001
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# stage2
# Block 0: 0.9999
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0000
# Validation: 100%|██████████| 469/469 [00:06<00:00, 70.19it/s]
# Tau: 0.7300
# Validation Loss: 0.1119, Validation Accuracy: 96.47%
# Balanced Accuracy: 0.9649
# Model weights saved to HoViT_44_tinyfusion_base_r16a32_29.pth
# 30 model test result:
# Test: 100%|██████████| 469/469 [00:06<00:00, 71.51it/s]
# Tau: 0.0000
# Test Loss: 0.1169, Test Accuracy: 96.57%
# Balanced Accuracy: 0.9664
#
# Epoch 31/100
# Training: 100%|██████████| 2188/2188 [01:54<00:00, 19.06it/s]
# Train Loss: 0.0615, Train Accuracy: 97.78%
# Tau: 0.7210
# Each stage of block probabilities:
# stage1
# Block 0: 0.9999
# Block 1: 0.0000
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# stage2
# Block 0: 0.9999
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0000
# Validation: 100%|██████████| 469/469 [00:06<00:00, 69.56it/s]
# Tau: 0.7210
# Validation Loss: 0.1138, Validation Accuracy: 96.37%
# Balanced Accuracy: 0.9653
#
# Epoch 32/100
# Training: 100%|██████████| 2188/2188 [01:54<00:00, 19.06it/s]
# Train Loss: 0.0607, Train Accuracy: 97.85%
# Tau: 0.7120
# Each stage of block probabilities:
# stage1
# Block 0: 0.9999
# Block 1: 0.0000
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# stage2
# Block 0: 0.9999
# Block 1: 0.0000
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 69.78it/s]
# Tau: 0.7120
# Validation Loss: 0.1269, Validation Accuracy: 96.26%
# Balanced Accuracy: 0.9637
#
# Epoch 33/100
# Training: 100%|██████████| 2188/2188 [01:55<00:00, 19.00it/s]
# Train Loss: 0.0598, Train Accuracy: 97.92%
# Tau: 0.7030
# Each stage of block probabilities:
# stage1
# Block 0: 1.0000
# Block 1: 0.0000
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# stage2
# Block 0: 0.9999
# Block 1: 0.0001
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 72.19it/s]
# Tau: 0.7030
# Validation Loss: 0.0975, Validation Accuracy: 97.14%
# Balanced Accuracy: 0.9719
# New best model saved with Validation loss 0.0975 at best_model.pth
#
# Epoch 34/100
# Training: 100%|██████████| 2188/2188 [01:55<00:00, 19.02it/s]
# Train Loss: 0.0604, Train Accuracy: 97.92%
# Tau: 0.6940
# Each stage of block probabilities:
# stage1
# Block 0: 1.0000
# Block 1: 0.0000
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# stage2
# Block 0: 0.9999
# Block 1: 0.0000
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 68.83it/s]
# Tau: 0.6940
# Validation Loss: 0.1162, Validation Accuracy: 96.61%
# Balanced Accuracy: 0.9676
#
# Epoch 35/100
# Training: 100%|██████████| 2188/2188 [01:54<00:00, 19.10it/s]
# Train Loss: 0.0578, Train Accuracy: 97.94%
# Tau: 0.6850
# Each stage of block probabilities:
# stage1
# Block 0: 1.0000
# Block 1: 0.0000
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# stage2
# Block 0: 0.9999
# Block 1: 0.0000
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 68.17it/s]
# Tau: 0.6850
# Validation Loss: 0.1361, Validation Accuracy: 95.50%
# Balanced Accuracy: 0.9580
#
# Epoch 36/100
# Training: 100%|██████████| 2188/2188 [01:54<00:00, 19.12it/s]
# Train Loss: 0.0574, Train Accuracy: 97.94%
# Tau: 0.6760
# Each stage of block probabilities:
# stage1
# Block 0: 1.0000
# Block 1: 0.0000
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# stage2
# Block 0: 0.9999
# Block 1: 0.0000
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 72.77it/s]
# Tau: 0.6760
# Validation Loss: 0.1263, Validation Accuracy: 96.36%
# Balanced Accuracy: 0.9654
#
# Epoch 37/100
# Training: 100%|██████████| 2188/2188 [01:54<00:00, 19.07it/s]
# Train Loss: 0.0569, Train Accuracy: 98.01%
# Tau: 0.6670
# Each stage of block probabilities:
# stage1
# Block 0: 1.0000
# Block 1: 0.0000
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# stage2
# Block 0: 0.9999
# Block 1: 0.0000
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 71.61it/s]
# Tau: 0.6670
# Validation Loss: 0.1080, Validation Accuracy: 96.93%
# Balanced Accuracy: 0.9706
#
# Epoch 38/100
# Training: 100%|██████████| 2188/2188 [01:53<00:00, 19.29it/s]
# Train Loss: 0.0558, Train Accuracy: 98.00%
# Tau: 0.6580
# Each stage of block probabilities:
# stage1
# Block 0: 1.0000
# Block 1: 0.0000
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# stage2
# Block 0: 0.9999
# Block 1: 0.0001
# Block 2: 0.0000 *
# Block 3: 0.0001 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 68.38it/s]
# Tau: 0.6580
# Validation Loss: 0.1078, Validation Accuracy: 96.81%
# Balanced Accuracy: 0.9686
#
# Epoch 39/100
# Training: 100%|██████████| 2188/2188 [01:53<00:00, 19.33it/s]
# Train Loss: 0.0541, Train Accuracy: 98.05%
# Tau: 0.6490
# Each stage of block probabilities:
# stage1
# Block 0: 1.0000
# Block 1: 0.0000
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# stage2
# Block 0: 0.9998
# Block 1: 0.0001
# Block 2: 0.0000 *
# Block 3: 0.0001 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 68.82it/s]
# Tau: 0.6490
# Validation Loss: 0.1221, Validation Accuracy: 96.78%
# Balanced Accuracy: 0.9675
#
# Epoch 40/100
# Training: 100%|██████████| 2188/2188 [01:54<00:00, 19.05it/s]
# Train Loss: 0.0561, Train Accuracy: 98.00%
# Tau: 0.6400
# Each stage of block probabilities:
# stage1
# Block 0: 1.0000
# Block 1: 0.0000
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# stage2
# Block 0: 0.9998
# Block 1: 0.0001 *
# Block 2: 0.0000 *
# Block 3: 0.0001
# Validation: 100%|██████████| 469/469 [00:06<00:00, 72.04it/s]
# Tau: 0.6400
# Validation Loss: 0.1190, Validation Accuracy: 96.57%
# Balanced Accuracy: 0.9673
# Model weights saved to HoViT_44_tinyfusion_base_r16a32_39.pth
# 40 model test result:
# Test: 100%|██████████| 469/469 [00:06<00:00, 70.87it/s]
# Tau: 0.0000
# Test Loss: 0.1398, Test Accuracy: 96.69%
# Balanced Accuracy: 0.9684
#
# Epoch 41/100
# Training: 100%|██████████| 2188/2188 [01:53<00:00, 19.25it/s]
# Train Loss: 0.0568, Train Accuracy: 98.01%
# Tau: 0.6310
# Each stage of block probabilities:
# stage1
# Block 0: 1.0000
# Block 1: 0.0000
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# stage2
# Block 0: 0.9998
# Block 1: 0.0001 *
# Block 2: 0.0000 *
# Block 3: 0.0001
# Validation: 100%|██████████| 469/469 [00:06<00:00, 69.12it/s]
# Tau: 0.6310
# Validation Loss: 0.1240, Validation Accuracy: 96.16%
# Balanced Accuracy: 0.9621
#
# Epoch 42/100
# Training: 100%|██████████| 2188/2188 [01:53<00:00, 19.33it/s]
# Train Loss: 0.0532, Train Accuracy: 98.12%
# Tau: 0.6220
# Each stage of block probabilities:
# stage1
# Block 0: 1.0000
# Block 1: 0.0000
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# stage2
# Block 0: 0.9999
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0001
# Validation: 100%|██████████| 469/469 [00:06<00:00, 70.51it/s]
# Tau: 0.6220
# Validation Loss: 0.1278, Validation Accuracy: 96.35%
# Balanced Accuracy: 0.9650
#
# Epoch 43/100
# Training: 100%|██████████| 2188/2188 [01:54<00:00, 19.12it/s]
# Train Loss: 0.0515, Train Accuracy: 98.15%
# Tau: 0.6130
# Each stage of block probabilities:
# stage1
# Block 0: 1.0000
# Block 1: 0.0000
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# stage2
# Block 0: 0.9999
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0000
# Validation: 100%|██████████| 469/469 [00:06<00:00, 71.82it/s]
# Tau: 0.6130
# Validation Loss: 0.1121, Validation Accuracy: 96.83%
# Balanced Accuracy: 0.9692
#
# Epoch 44/100
# Training: 100%|██████████| 2188/2188 [01:53<00:00, 19.24it/s]
# Train Loss: 0.0529, Train Accuracy: 98.19%
# Tau: 0.6040
# Each stage of block probabilities:
# stage1
# Block 0: 0.9999
# Block 1: 0.0000
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# stage2
# Block 0: 0.9999
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0000
# Validation: 100%|██████████| 469/469 [00:06<00:00, 72.16it/s]
# Tau: 0.6040
# Validation Loss: 0.1551, Validation Accuracy: 95.39%
# Balanced Accuracy: 0.9564
#
# Epoch 45/100
# Training: 100%|██████████| 2188/2188 [01:55<00:00, 18.99it/s]
# Train Loss: 0.0529, Train Accuracy: 98.14%
# Tau: 0.5950
# Each stage of block probabilities:
# stage1
# Block 0: 0.9999
# Block 1: 0.0000
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# stage2
# Block 0: 0.9999
# Block 1: 0.0000 *
# Block 2: 0.0000
# Block 3: 0.0000 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 68.41it/s]
# Tau: 0.5950
# Validation Loss: 0.1242, Validation Accuracy: 96.93%
# Balanced Accuracy: 0.9692
#
# Epoch 46/100
# Training: 100%|██████████| 2188/2188 [01:53<00:00, 19.23it/s]
# Train Loss: 0.0508, Train Accuracy: 98.18%
# Tau: 0.5860
# Each stage of block probabilities:
# stage1
# Block 0: 0.9999
# Block 1: 0.0000
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# stage2
# Block 0: 0.9999
# Block 1: 0.0000 *
# Block 2: 0.0000
# Block 3: 0.0000 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 70.71it/s]
# Tau: 0.5860
# Validation Loss: 0.1161, Validation Accuracy: 96.81%
# Balanced Accuracy: 0.9688
#
# Epoch 47/100
# Training: 100%|██████████| 2188/2188 [01:54<00:00, 19.18it/s]
# Train Loss: 0.0505, Train Accuracy: 98.26%
# Tau: 0.5770
# Each stage of block probabilities:
# stage1
# Block 0: 0.9999
# Block 1: 0.0000
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# stage2
# Block 0: 0.9999
# Block 1: 0.0000 *
# Block 2: 0.0000
# Block 3: 0.0000 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 72.20it/s]
# Tau: 0.5770
# Validation Loss: 0.1305, Validation Accuracy: 95.95%
# Balanced Accuracy: 0.9622
#
# Epoch 48/100
# Training: 100%|██████████| 2188/2188 [01:54<00:00, 19.16it/s]
# Train Loss: 0.0496, Train Accuracy: 98.28%
# Tau: 0.5680
# Each stage of block probabilities:
# stage1
# Block 0: 0.9999
# Block 1: 0.0001
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# stage2
# Block 0: 0.9999
# Block 1: 0.0000 *
# Block 2: 0.0000
# Block 3: 0.0000 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 74.32it/s]
# Tau: 0.5680
# Validation Loss: 0.1119, Validation Accuracy: 96.81%
# Balanced Accuracy: 0.9679
#
# Epoch 49/100
# Training: 100%|██████████| 2188/2188 [01:53<00:00, 19.28it/s]
# Train Loss: 0.0497, Train Accuracy: 98.27%
# Tau: 0.5590
# Each stage of block probabilities:
# stage1
# Block 0: 0.9999
# Block 1: 0.0001
# Block 2: 0.0001 *
# Block 3: 0.0000 *
# stage2
# Block 0: 0.9999
# Block 1: 0.0000 *
# Block 2: 0.0000
# Block 3: 0.0000 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 72.02it/s]
# Tau: 0.5590
# Validation Loss: 0.1123, Validation Accuracy: 97.18%
# Balanced Accuracy: 0.9726
#
# Epoch 50/100
# Training: 100%|██████████| 2188/2188 [01:53<00:00, 19.26it/s]
# Train Loss: 0.0476, Train Accuracy: 98.33%
# Tau: 0.5500
# Each stage of block probabilities:
# stage1
# Block 0: 0.9999
# Block 1: 0.0001
# Block 2: 0.0001 *
# Block 3: 0.0000 *
# stage2
# Block 0: 0.9999
# Block 1: 0.0000 *
# Block 2: 0.0000
# Block 3: 0.0000 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 69.75it/s]
# Tau: 0.5500
# Validation Loss: 0.1311, Validation Accuracy: 96.46%
# Balanced Accuracy: 0.9666
# Model weights saved to HoViT_44_tinyfusion_base_r16a32_49.pth
# 50 model test result:
# Test: 100%|██████████| 469/469 [00:06<00:00, 71.86it/s]
# Tau: 0.0000
# Test Loss: 0.1323, Test Accuracy: 96.69%
# Balanced Accuracy: 0.9688
#
# Epoch 51/100
# Training: 100%|██████████| 2188/2188 [01:53<00:00, 19.24it/s]
# Train Loss: 0.0480, Train Accuracy: 98.32%
# Tau: 0.5410
# Each stage of block probabilities:
# stage1
# Block 0: 0.9999
# Block 1: 0.0000 *
# Block 2: 0.0000
# Block 3: 0.0000 *
# stage2
# Block 0: 0.9999
# Block 1: 0.0000 *
# Block 2: 0.0001
# Block 3: 0.0000 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 72.43it/s]
# Tau: 0.5410
# Validation Loss: 0.1282, Validation Accuracy: 96.50%
# Balanced Accuracy: 0.9668
#
# Epoch 52/100
# Training: 100%|██████████| 2188/2188 [01:53<00:00, 19.27it/s]
# Train Loss: 0.0480, Train Accuracy: 98.27%
# Tau: 0.5320
# Each stage of block probabilities:
# stage1
# Block 0: 0.9999
# Block 1: 0.0000 *
# Block 2: 0.0001
# Block 3: 0.0000 *
# stage2
# Block 0: 0.9999
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0000
# Validation: 100%|██████████| 469/469 [00:06<00:00, 70.34it/s]
# Tau: 0.5320
# Validation Loss: 0.1176, Validation Accuracy: 96.72%
# Balanced Accuracy: 0.9681
#
# Epoch 53/100
# Training: 100%|██████████| 2188/2188 [01:53<00:00, 19.29it/s]
# Train Loss: 0.0458, Train Accuracy: 98.46%
# Tau: 0.5230
# Each stage of block probabilities:
# stage1
# Block 0: 0.9999
# Block 1: 0.0001 *
# Block 2: 0.0001
# Block 3: 0.0000 *
# stage2
# Block 0: 0.9999
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0001
# Validation: 100%|██████████| 469/469 [00:06<00:00, 69.37it/s]
# Tau: 0.5230
# Validation Loss: 0.1317, Validation Accuracy: 96.43%
# Balanced Accuracy: 0.9661
#
# Epoch 54/100
# Training: 100%|██████████| 2188/2188 [01:54<00:00, 19.14it/s]
# Train Loss: 0.0464, Train Accuracy: 98.32%
# Tau: 0.5140
# Each stage of block probabilities:
# stage1
# Block 0: 0.9998
# Block 1: 0.0001 *
# Block 2: 0.0001
# Block 3: 0.0000 *
# stage2
# Block 0: 0.9999
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0001
# Validation: 100%|██████████| 469/469 [00:06<00:00, 70.38it/s]
# Tau: 0.5140
# Validation Loss: 0.1301, Validation Accuracy: 96.56%
# Balanced Accuracy: 0.9679
#
# Epoch 55/100
# Training: 100%|██████████| 2188/2188 [01:53<00:00, 19.26it/s]
# Train Loss: 0.0468, Train Accuracy: 98.39%
# Tau: 0.5050
# Each stage of block probabilities:
# stage1
# Block 0: 0.9998
# Block 1: 0.0001
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# stage2
# Block 0: 0.9999
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0001
# Validation: 100%|██████████| 469/469 [00:06<00:00, 71.93it/s]
# Tau: 0.5050
# Validation Loss: 0.1215, Validation Accuracy: 96.31%
# Balanced Accuracy: 0.9645
#
# Epoch 56/100
# Training: 100%|██████████| 2188/2188 [01:53<00:00, 19.20it/s]
# Train Loss: 0.0458, Train Accuracy: 98.41%
# Tau: 0.4960
# Each stage of block probabilities:
# stage1
# Block 0: 0.9999
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0001
# stage2
# Block 0: 0.9999
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0000
# Validation: 100%|██████████| 469/469 [00:06<00:00, 70.51it/s]
# Tau: 0.4960
# Validation Loss: 0.1063, Validation Accuracy: 97.15%
# Balanced Accuracy: 0.9716
#
# Epoch 57/100
# Training: 100%|██████████| 2188/2188 [01:53<00:00, 19.25it/s]
# Train Loss: 0.0451, Train Accuracy: 98.41%
# Tau: 0.4870
# Each stage of block probabilities:
# stage1
# Block 0: 0.9999
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0001
# stage2
# Block 0: 0.9999
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0000
# Validation: 100%|██████████| 469/469 [00:06<00:00, 71.78it/s]
# Tau: 0.4870
# Validation Loss: 0.1177, Validation Accuracy: 96.82%
# Balanced Accuracy: 0.9691
#
# Epoch 58/100
# Training: 100%|██████████| 2188/2188 [01:53<00:00, 19.28it/s]
# Train Loss: 0.0418, Train Accuracy: 98.55%
# Tau: 0.4780
# Each stage of block probabilities:
# stage1
# Block 0: 0.9999
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0000
# stage2
# Block 0: 0.9999
# Block 1: 0.0000
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 70.70it/s]
# Tau: 0.4780
# Validation Loss: 0.1224, Validation Accuracy: 96.79%
# Balanced Accuracy: 0.9687
#
# Epoch 59/100
# Training: 100%|██████████| 2188/2188 [01:53<00:00, 19.22it/s]
# Train Loss: 0.0450, Train Accuracy: 98.44%
# Tau: 0.4690
# Each stage of block probabilities:
# stage1
# Block 0: 0.9999
# Block 1: 0.0000
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# stage2
# Block 0: 0.9999
# Block 1: 0.0000
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 68.83it/s]
# Tau: 0.4690
# Validation Loss: 0.0948, Validation Accuracy: 97.09%
# Balanced Accuracy: 0.9714
# New best model saved with Validation loss 0.0948 at best_model.pth
#
# Epoch 60/100
# Training: 100%|██████████| 2188/2188 [01:53<00:00, 19.26it/s]
# Train Loss: 0.0452, Train Accuracy: 98.41%
# Tau: 0.4600
# Each stage of block probabilities:
# stage1
# Block 0: 0.9999
# Block 1: 0.0001
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# stage2
# Block 0: 0.9999
# Block 1: 0.0000
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 73.16it/s]
# Tau: 0.4600
# Validation Loss: 0.1237, Validation Accuracy: 96.66%
# Balanced Accuracy: 0.9678
# Model weights saved to HoViT_44_tinyfusion_base_r16a32_59.pth
# 60 model test result:
# Test: 100%|██████████| 469/469 [00:06<00:00, 70.25it/s]
# Tau: 0.0000
# Test Loss: 0.1533, Test Accuracy: 96.42%
# Balanced Accuracy: 0.9653
#
# Epoch 61/100
# Training: 100%|██████████| 2188/2188 [01:53<00:00, 19.31it/s]
# Train Loss: 0.0448, Train Accuracy: 98.40%
# Tau: 0.4510
# Each stage of block probabilities:
# stage1
# Block 0: 0.9998
# Block 1: 0.0001
# Block 2: 0.0000 *
# Block 3: 0.0001 *
# stage2
# Block 0: 0.9998
# Block 1: 0.0001 *
# Block 2: 0.0000 *
# Block 3: 0.0001
# Validation: 100%|██████████| 469/469 [00:06<00:00, 68.49it/s]
# Tau: 0.4510
# Validation Loss: 0.1088, Validation Accuracy: 96.92%
# Balanced Accuracy: 0.9696
#
# Epoch 62/100
# Training: 100%|██████████| 2188/2188 [01:53<00:00, 19.32it/s]
# Train Loss: 0.0452, Train Accuracy: 98.44%
# Tau: 0.4420
# Each stage of block probabilities:
# stage1
# Block 0: 0.9998
# Block 1: 0.0001
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# stage2
# Block 0: 0.9999
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0000
# Validation: 100%|██████████| 469/469 [00:06<00:00, 70.01it/s]
# Tau: 0.4420
# Validation Loss: 0.1133, Validation Accuracy: 96.82%
# Balanced Accuracy: 0.9687
#
# Epoch 63/100
# Training: 100%|██████████| 2188/2188 [01:53<00:00, 19.24it/s]
# Train Loss: 0.0430, Train Accuracy: 98.49%
# Tau: 0.4330
# Each stage of block probabilities:
# stage1
# Block 0: 0.9998
# Block 1: 0.0001
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# stage2
# Block 0: 0.9999
# Block 1: 0.0001
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 71.71it/s]
# Tau: 0.4330
# Validation Loss: 0.1161, Validation Accuracy: 96.75%
# Balanced Accuracy: 0.9688
#
# Epoch 64/100
# Training: 100%|██████████| 2188/2188 [01:54<00:00, 19.15it/s]
# Train Loss: 0.0430, Train Accuracy: 98.47%
# Tau: 0.4240
# Each stage of block probabilities:
# stage1
# Block 0: 0.9997
# Block 1: 0.0002
# Block 2: 0.0001 *
# Block 3: 0.0001 *
# stage2
# Block 0: 0.9999
# Block 1: 0.0000
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 71.04it/s]
# Tau: 0.4240
# Validation Loss: 0.1178, Validation Accuracy: 96.99%
# Balanced Accuracy: 0.9712
#
# Epoch 65/100
# Training: 100%|██████████| 2188/2188 [01:53<00:00, 19.20it/s]
# Train Loss: 0.0425, Train Accuracy: 98.46%
# Tau: 0.4150
# Each stage of block probabilities:
# stage1
# Block 0: 0.9997
# Block 1: 0.0001
# Block 2: 0.0001 *
# Block 3: 0.0001 *
# stage2
# Block 0: 0.9999
# Block 1: 0.0000
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 69.46it/s]
# Tau: 0.4150
# Validation Loss: 0.1249, Validation Accuracy: 96.64%
# Balanced Accuracy: 0.9676
#
# Epoch 66/100
# Training: 100%|██████████| 2188/2188 [01:53<00:00, 19.29it/s]
# Train Loss: 0.0442, Train Accuracy: 98.47%
# Tau: 0.4060
# Each stage of block probabilities:
# stage1
# Block 0: 0.9998
# Block 1: 0.0001
# Block 2: 0.0001 *
# Block 3: 0.0001 *
# stage2
# Block 0: 0.9999
# Block 1: 0.0000
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 70.51it/s]
# Tau: 0.4060
# Validation Loss: 0.1007, Validation Accuracy: 96.74%
# Balanced Accuracy: 0.9687
#
# Epoch 67/100
# Training: 100%|██████████| 2188/2188 [01:53<00:00, 19.29it/s]
# Train Loss: 0.0439, Train Accuracy: 98.44%
# Tau: 0.3970
# Each stage of block probabilities:
# stage1
# Block 0: 0.9998
# Block 1: 0.0001 *
# Block 2: 0.0001 *
# Block 3: 0.0001
# stage2
# Block 0: 0.9999
# Block 1: 0.0000
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 70.28it/s]
# Tau: 0.3970
# Validation Loss: 0.1149, Validation Accuracy: 97.22%
# Balanced Accuracy: 0.9729
#
# Epoch 68/100
# Training: 100%|██████████| 2188/2188 [01:54<00:00, 19.16it/s]
# Train Loss: 0.0397, Train Accuracy: 98.63%
# Tau: 0.3880
# Each stage of block probabilities:
# stage1
# Block 0: 0.9998
# Block 1: 0.0001 *
# Block 2: 0.0001 *
# Block 3: 0.0001
# stage2
# Block 0: 0.9999
# Block 1: 0.0000
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 69.66it/s]
# Tau: 0.3880
# Validation Loss: 0.1302, Validation Accuracy: 96.29%
# Balanced Accuracy: 0.9656
#
# Epoch 69/100
# Training: 100%|██████████| 2188/2188 [01:54<00:00, 19.17it/s]
# Train Loss: 0.0413, Train Accuracy: 98.54%
# Tau: 0.3790
# Each stage of block probabilities:
# stage1
# Block 0: 0.9998
# Block 1: 0.0001 *
# Block 2: 0.0001
# Block 3: 0.0001 *
# stage2
# Block 0: 0.9999
# Block 1: 0.0000
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 71.59it/s]
# Tau: 0.3790
# Validation Loss: 0.1080, Validation Accuracy: 97.16%
# Balanced Accuracy: 0.9718
#
# Epoch 70/100
# Training: 100%|██████████| 2188/2188 [01:53<00:00, 19.24it/s]
# Train Loss: 0.0401, Train Accuracy: 98.60%
# Tau: 0.3700
# Each stage of block probabilities:
# stage1
# Block 0: 0.9998
# Block 1: 0.0001 *
# Block 2: 0.0001
# Block 3: 0.0001 *
# stage2
# Block 0: 0.9999
# Block 1: 0.0000
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 69.96it/s]
# Tau: 0.3700
# Validation Loss: 0.1184, Validation Accuracy: 96.91%
# Balanced Accuracy: 0.9697
# Model weights saved to HoViT_44_tinyfusion_base_r16a32_69.pth
# 70 model test result:
# Test: 100%|██████████| 469/469 [00:06<00:00, 70.73it/s]
# Tau: 0.0000
# Test Loss: 0.1352, Test Accuracy: 96.69%
# Balanced Accuracy: 0.9681
#
# Epoch 71/100
# Training: 100%|██████████| 2188/2188 [01:53<00:00, 19.24it/s]
# Train Loss: 0.0427, Train Accuracy: 98.51%
# Tau: 0.3610
# Each stage of block probabilities:
# stage1
# Block 0: 0.9999
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0000
# stage2
# Block 0: 0.9999
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0000
# Validation: 100%|██████████| 469/469 [00:06<00:00, 72.76it/s]
# Tau: 0.3610
# Validation Loss: 0.1105, Validation Accuracy: 97.00%
# Balanced Accuracy: 0.9696
#
# Epoch 72/100
# Training: 100%|██████████| 2188/2188 [01:53<00:00, 19.23it/s]
# Train Loss: 0.0397, Train Accuracy: 98.62%
# Tau: 0.3520
# Each stage of block probabilities:
# stage1
# Block 0: 0.9998
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0001
# stage2
# Block 0: 0.9999
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0000
# Validation: 100%|██████████| 469/469 [00:06<00:00, 71.47it/s]
# Tau: 0.3520
# Validation Loss: 0.1109, Validation Accuracy: 96.99%
# Balanced Accuracy: 0.9700
#
# Epoch 73/100
# Training: 100%|██████████| 2188/2188 [01:55<00:00, 18.89it/s]
# Train Loss: 0.0408, Train Accuracy: 98.62%
# Tau: 0.3430
# Each stage of block probabilities:
# stage1
# Block 0: 0.9999
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0001
# stage2
# Block 0: 0.9999
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0000
# Validation: 100%|██████████| 469/469 [00:06<00:00, 69.28it/s]
# Tau: 0.3430
# Validation Loss: 0.0945, Validation Accuracy: 97.10%
# Balanced Accuracy: 0.9720
# New best model saved with Validation loss 0.0945 at best_model.pth
#
# Epoch 74/100
# Training: 100%|██████████| 2188/2188 [01:54<00:00, 19.13it/s]
# Train Loss: 0.0392, Train Accuracy: 98.64%
# Tau: 0.3340
# Each stage of block probabilities:
# stage1
# Block 0: 0.9999
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0001
# stage2
# Block 0: 0.9999
# Block 1: 0.0000
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 68.59it/s]
# Tau: 0.3340
# Validation Loss: 0.1081, Validation Accuracy: 97.09%
# Balanced Accuracy: 0.9706
#
# Epoch 75/100
# Training: 100%|██████████| 2188/2188 [01:54<00:00, 19.06it/s]
# Train Loss: 0.0393, Train Accuracy: 98.64%
# Tau: 0.3250
# Each stage of block probabilities:
# stage1
# Block 0: 0.9999
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0001
# stage2
# Block 0: 0.9999
# Block 1: 0.0000
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 72.32it/s]
# Tau: 0.3250
# Validation Loss: 0.0955, Validation Accuracy: 97.18%
# Balanced Accuracy: 0.9721
#
# Epoch 76/100
# Training: 100%|██████████| 2188/2188 [01:54<00:00, 19.13it/s]
# Train Loss: 0.0400, Train Accuracy: 98.60%
# Tau: 0.3160
# Each stage of block probabilities:
# stage1
# Block 0: 0.9999
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0001
# stage2
# Block 0: 0.9998
# Block 1: 0.0001 *
# Block 2: 0.0000 *
# Block 3: 0.0001
# Validation: 100%|██████████| 469/469 [00:06<00:00, 71.51it/s]
# Tau: 0.3160
# Validation Loss: 0.0952, Validation Accuracy: 97.63%
# Balanced Accuracy: 0.9769
#
# Epoch 77/100
# Training: 100%|██████████| 2188/2188 [01:54<00:00, 19.11it/s]
# Train Loss: 0.0397, Train Accuracy: 98.59%
# Tau: 0.3070
# Each stage of block probabilities:
# stage1
# Block 0: 0.9999
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0000
# stage2
# Block 0: 0.9998
# Block 1: 0.0001
# Block 2: 0.0001 *
# Block 3: 0.0001 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 68.02it/s]
# Tau: 0.3070
# Validation Loss: 0.1202, Validation Accuracy: 96.69%
# Balanced Accuracy: 0.9683
#
# Epoch 78/100
# Training: 100%|██████████| 2188/2188 [01:54<00:00, 19.10it/s]
# Train Loss: 0.0379, Train Accuracy: 98.70%
# Tau: 0.2980
# Each stage of block probabilities:
# stage1
# Block 0: 0.9999
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0000
# stage2
# Block 0: 0.9998
# Block 1: 0.0001
# Block 2: 0.0000 *
# Block 3: 0.0001 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 67.76it/s]
# Tau: 0.2980
# Validation Loss: 0.0945, Validation Accuracy: 97.19%
# Balanced Accuracy: 0.9721
#
# Epoch 79/100
# Training: 100%|██████████| 2188/2188 [01:53<00:00, 19.26it/s]
# Train Loss: 0.0394, Train Accuracy: 98.62%
# Tau: 0.2890
# Each stage of block probabilities:
# stage1
# Block 0: 0.9999
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0000
# stage2
# Block 0: 0.9998
# Block 1: 0.0001
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 67.12it/s]
# Tau: 0.2890
# Validation Loss: 0.1162, Validation Accuracy: 97.05%
# Balanced Accuracy: 0.9705
#
# Epoch 80/100
# Training: 100%|██████████| 2188/2188 [01:53<00:00, 19.23it/s]
# Train Loss: 0.0390, Train Accuracy: 98.63%
# Tau: 0.2800
# Each stage of block probabilities:
# stage1
# Block 0: 0.9999
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0000
# stage2
# Block 0: 0.9999
# Block 1: 0.0001
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 72.15it/s]
# Tau: 0.2800
# Validation Loss: 0.1015, Validation Accuracy: 97.21%
# Balanced Accuracy: 0.9721
# Model weights saved to HoViT_44_tinyfusion_base_r16a32_79.pth
# 80 model test result:
# Test: 100%|██████████| 469/469 [00:06<00:00, 70.09it/s]
# Tau: 0.0000
# Test Loss: 0.1257, Test Accuracy: 97.07%
# Balanced Accuracy: 0.9716
#
# Epoch 81/100
# Training: 100%|██████████| 2188/2188 [01:54<00:00, 19.09it/s]
# Train Loss: 0.0384, Train Accuracy: 98.61%
# Tau: 0.2710
# Each stage of block probabilities:
# stage1
# Block 0: 0.9999
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0000
# stage2
# Block 0: 0.9999
# Block 1: 0.0000
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 69.36it/s]
# Tau: 0.2710
# Validation Loss: 0.1185, Validation Accuracy: 96.41%
# Balanced Accuracy: 0.9652
#
# Epoch 82/100
# Training: 100%|██████████| 2188/2188 [01:54<00:00, 19.12it/s]
# Train Loss: 0.0375, Train Accuracy: 98.66%
# Tau: 0.2620
# Each stage of block probabilities:
# stage1
# Block 0: 0.9999
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0000
# stage2
# Block 0: 0.9999
# Block 1: 0.0000
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 71.65it/s]
# Tau: 0.2620
# Validation Loss: 0.0787, Validation Accuracy: 97.69%
# Balanced Accuracy: 0.9774
# New best model saved with Validation loss 0.0787 at best_model.pth
#
# Epoch 83/100
# Training: 100%|██████████| 2188/2188 [01:53<00:00, 19.19it/s]
# Train Loss: 0.0371, Train Accuracy: 98.72%
# Tau: 0.2530
# Each stage of block probabilities:
# stage1
# Block 0: 0.9999
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0000
# stage2
# Block 0: 0.9999
# Block 1: 0.0000
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 72.32it/s]
# Tau: 0.2530
# Validation Loss: 0.0926, Validation Accuracy: 97.43%
# Balanced Accuracy: 0.9751
#
# Epoch 84/100
# Training: 100%|██████████| 2188/2188 [01:54<00:00, 19.09it/s]
# Train Loss: 0.0396, Train Accuracy: 98.61%
# Tau: 0.2440
# Each stage of block probabilities:
# stage1
# Block 0: 1.0000
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0000
# stage2
# Block 0: 0.9999
# Block 1: 0.0000
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 68.08it/s]
# Tau: 0.2440
# Validation Loss: 0.1017, Validation Accuracy: 97.21%
# Balanced Accuracy: 0.9721
#
# Epoch 85/100
# Training: 100%|██████████| 2188/2188 [01:54<00:00, 19.17it/s]
# Train Loss: 0.0350, Train Accuracy: 98.77%
# Tau: 0.2350
# Each stage of block probabilities:
# stage1
# Block 0: 1.0000
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0000
# stage2
# Block 0: 0.9999
# Block 1: 0.0000
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 69.32it/s]
# Tau: 0.2350
# Validation Loss: 0.1287, Validation Accuracy: 96.88%
# Balanced Accuracy: 0.9697
#
# Epoch 86/100
# Training: 100%|██████████| 2188/2188 [01:53<00:00, 19.22it/s]
# Train Loss: 0.0357, Train Accuracy: 98.69%
# Tau: 0.2260
# Each stage of block probabilities:
# stage1
# Block 0: 1.0000
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0000
# stage2
# Block 0: 0.9999
# Block 1: 0.0000
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 71.26it/s]
# Tau: 0.2260
# Validation Loss: 0.1143, Validation Accuracy: 97.11%
# Balanced Accuracy: 0.9706
#
# Epoch 87/100
# Training: 100%|██████████| 2188/2188 [01:53<00:00, 19.21it/s]
# Train Loss: 0.0374, Train Accuracy: 98.60%
# Tau: 0.2170
# Each stage of block probabilities:
# stage1
# Block 0: 1.0000
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0000
# stage2
# Block 0: 0.9999
# Block 1: 0.0000
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 72.46it/s]
# Tau: 0.2170
# Validation Loss: 0.1067, Validation Accuracy: 97.15%
# Balanced Accuracy: 0.9718
#
# Epoch 88/100
# Training: 100%|██████████| 2188/2188 [01:53<00:00, 19.22it/s]
# Train Loss: 0.0369, Train Accuracy: 98.71%
# Tau: 0.2080
# Each stage of block probabilities:
# stage1
# Block 0: 1.0000
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0000
# stage2
# Block 0: 0.9999
# Block 1: 0.0000
# Block 2: 0.0000 *
# Block 3: 0.0000 *
# Validation: 100%|██████████| 469/469 [00:06<00:00, 72.55it/s]
# Tau: 0.2080
# Validation Loss: 0.1059, Validation Accuracy: 97.43%
# Balanced Accuracy: 0.9747
#
# Epoch 89/100
# Training: 100%|██████████| 2188/2188 [01:54<00:00, 19.13it/s]
# Train Loss: 0.0350, Train Accuracy: 98.79%
# Tau: 0.1990
# Each stage of block probabilities:
# stage1
# Block 0: 1.0000
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0000
# stage2
# Block 0: 0.9999
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0000
# Validation: 100%|██████████| 469/469 [00:07<00:00, 66.46it/s]
# Tau: 0.1990
# Validation Loss: 0.1062, Validation Accuracy: 96.59%
# Balanced Accuracy: 0.9669
#
# Epoch 90/100
# Training: 100%|██████████| 2188/2188 [01:54<00:00, 19.10it/s]
# Train Loss: 0.0338, Train Accuracy: 98.81%
# Tau: 0.1900
# Each stage of block probabilities:
# stage1
# Block 0: 1.0000
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0000
# stage2
# Block 0: 0.9999
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0000
# Validation: 100%|██████████| 469/469 [00:06<00:00, 70.22it/s]
# Tau: 0.1900
# Validation Loss: 0.1037, Validation Accuracy: 97.45%
# Balanced Accuracy: 0.9753
# Model weights saved to HoViT_44_tinyfusion_base_r16a32_89.pth
# 90 model test result:
# Test: 100%|██████████| 469/469 [00:06<00:00, 70.68it/s]
# Tau: 0.0000
# Test Loss: 0.1391, Test Accuracy: 97.23%
# Balanced Accuracy: 0.9732
#
# Epoch 91/100
# Training: 100%|██████████| 2188/2188 [01:54<00:00, 19.11it/s]
# Train Loss: 0.0360, Train Accuracy: 98.70%
# Tau: 0.1810
# Each stage of block probabilities:
# stage1
# Block 0: 1.0000
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0000
# stage2
# Block 0: 0.9999
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0000
# Validation: 100%|██████████| 469/469 [00:06<00:00, 67.91it/s]
# Tau: 0.1810
# Validation Loss: 0.1007, Validation Accuracy: 97.39%
# Balanced Accuracy: 0.9735
#
# Epoch 92/100
# Training: 100%|██████████| 2188/2188 [01:54<00:00, 19.13it/s]
# Train Loss: 0.0353, Train Accuracy: 98.75%
# Tau: 0.1720
# Each stage of block probabilities:
# stage1
# Block 0: 1.0000
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0000
# stage2
# Block 0: 0.9999
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0000
# Validation: 100%|██████████| 469/469 [00:06<00:00, 69.84it/s]
# Tau: 0.1720
# Validation Loss: 0.1104, Validation Accuracy: 97.16%
# Balanced Accuracy: 0.9722
#
# Epoch 93/100
# Training: 100%|██████████| 2188/2188 [01:53<00:00, 19.25it/s]
# Train Loss: 0.0355, Train Accuracy: 98.75%
# Tau: 0.1630
# Each stage of block probabilities:
# stage1
# Block 0: 1.0000
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0000
# stage2
# Block 0: 0.9999
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0000
# Validation: 100%|██████████| 469/469 [00:06<00:00, 70.98it/s]
# Tau: 0.1630
# Validation Loss: 0.1193, Validation Accuracy: 97.14%
# Balanced Accuracy: 0.9714
#
# Epoch 94/100
# Training: 100%|██████████| 2188/2188 [01:54<00:00, 19.19it/s]
# Train Loss: 0.0348, Train Accuracy: 98.76%
# Tau: 0.1540
# Each stage of block probabilities:
# stage1
# Block 0: 1.0000
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0000
# stage2
# Block 0: 1.0000
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0000
# Validation: 100%|██████████| 469/469 [00:06<00:00, 69.98it/s]
# Tau: 0.1540
# Validation Loss: 0.0894, Validation Accuracy: 97.39%
# Balanced Accuracy: 0.9742
#
# Epoch 95/100
# Training: 100%|██████████| 2188/2188 [01:53<00:00, 19.25it/s]
# Train Loss: 0.0329, Train Accuracy: 98.83%
# Tau: 0.1450
# Each stage of block probabilities:
# stage1
# Block 0: 1.0000
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0000
# stage2
# Block 0: 1.0000
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0000
# Validation: 100%|██████████| 469/469 [00:06<00:00, 70.94it/s]
# Tau: 0.1450
# Validation Loss: 0.1012, Validation Accuracy: 97.13%
# Balanced Accuracy: 0.9721
#
# Epoch 96/100
# Training: 100%|██████████| 2188/2188 [01:53<00:00, 19.23it/s]
# Train Loss: 0.0351, Train Accuracy: 98.78%
# Tau: 0.1360
# Each stage of block probabilities:
# stage1
# Block 0: 1.0000
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0000
# stage2
# Block 0: 1.0000
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0000
# Validation: 100%|██████████| 469/469 [00:06<00:00, 67.85it/s]
# Tau: 0.1360
# Validation Loss: 0.0997, Validation Accuracy: 97.59%
# Balanced Accuracy: 0.9763
#
# Epoch 97/100
# Training: 100%|██████████| 2188/2188 [01:53<00:00, 19.23it/s]
# Train Loss: 0.0349, Train Accuracy: 98.79%
# Tau: 0.1270
# Each stage of block probabilities:
# stage1
# Block 0: 1.0000
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0000
# stage2
# Block 0: 1.0000
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0000
# Validation: 100%|██████████| 469/469 [00:06<00:00, 68.74it/s]
# Tau: 0.1270
# Validation Loss: 0.0995, Validation Accuracy: 97.31%
# Balanced Accuracy: 0.9734
#
# Epoch 98/100
# Training: 100%|██████████| 2188/2188 [01:53<00:00, 19.22it/s]
# Train Loss: 0.0328, Train Accuracy: 98.85%
# Tau: 0.1180
# Each stage of block probabilities:
# stage1
# Block 0: 1.0000
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0000
# stage2
# Block 0: 1.0000
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0000
# Validation: 100%|██████████| 469/469 [00:06<00:00, 69.59it/s]
# Tau: 0.1180
# Validation Loss: 0.1155, Validation Accuracy: 97.15%
# Balanced Accuracy: 0.9715
#
# Epoch 99/100
# Training: 100%|██████████| 2188/2188 [01:53<00:00, 19.24it/s]
# Train Loss: 0.0349, Train Accuracy: 98.78%
# Tau: 0.1090
# Each stage of block probabilities:
# stage1
# Block 0: 1.0000
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0000
# stage2
# Block 0: 1.0000
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0000
# Validation: 100%|██████████| 469/469 [00:06<00:00, 72.88it/s]
# Tau: 0.1090
# Validation Loss: 0.1183, Validation Accuracy: 97.19%
# Balanced Accuracy: 0.9723
#
# Epoch 100/100
# Training: 100%|██████████| 2188/2188 [01:53<00:00, 19.21it/s]
# Train Loss: 0.0346, Train Accuracy: 98.77%
# Tau: 0.1000
# Each stage of block probabilities:
# stage1
# Block 0: 1.0000
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0000
# stage2
# Block 0: 1.0000
# Block 1: 0.0000 *
# Block 2: 0.0000 *
# Block 3: 0.0000
# Validation: 100%|██████████| 469/469 [00:06<00:00, 70.79it/s]
# Tau: 0.1000
# Validation Loss: 0.1245, Validation Accuracy: 97.07%
# Balanced Accuracy: 0.9714
# Model weights saved to HoViT_44_tinyfusion_base_r16a32_99.pth
# 100 model test result:
# Test: 100%|██████████| 469/469 [00:06<00:00, 71.11it/s]
# Tau: 0.0000
# Test Loss: 0.1511, Test Accuracy: 96.91%
# Balanced Accuracy: 0.9700

# %%
print("train_loss length : ", len(train_losses))
print("train_acc length : ", len(train_accuracies))
print("val_loss length : ", len(val_losses))
print("val_acc length : ", len(val_accuracies))

print("val_adj : ", len(val_losses[:num_epochs]))
print("val_acc_adj : ", len(val_accuracies[:num_epochs]))
# Out:
# train_loss length :  100
# train_acc length :  100
# val_loss length :  109
# val_acc length :  109
# val_adj :  100
# val_acc_adj :  100

# %%
# Plot the metrics
epochs = range(1, num_epochs + 1)

plt.figure(figsize=(12, 5))

# Plot training and validation loss
plt.subplot(1, 2, 1)
plt.plot(epochs, train_losses, label="Train Loss")
plt.plot(epochs, val_losses[:num_epochs], label="Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training and Validation Loss")
plt.legend()

# Plot training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(epochs, train_accuracies, label="Train Accuracy")
plt.plot(epochs, val_accuracies[:num_epochs], label="Validation Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Training and Validation Accuracy")
plt.legend()

plt.tight_layout()
plt.show()

# %%
times = measure_inference_time(model, test_loader, device)
# Out:
# Inference Time Measurement Results:
# Total Inferences: 469
# Average Time: 10.92 ms
# Standard Deviation: 2.30 ms
# Maximum Time: 22.50 ms
# Minimum Time: 8.57 ms

# %%
from torch import profiler

dummy_input = torch.randn(32, 3, 224, 224).cuda()

# Profiling inference
with profiler.profile(
    activities=[
       profiler.ProfilerActivity.CPU,
        profiler.ProfilerActivity.CUDA,  # Include if using GPU
    ],
    on_trace_ready=profiler.tensorboard_trace_handler("./logs"),  # Optional logging
    record_shapes=True,
    with_stack=True
) as prof:
    with torch.no_grad():
        model(dummy_input, tau=0.1)


# Print results
print(prof.key_averages().table(sort_by="cuda_time_total" if torch.cuda.is_available() else "cpu_time_total", row_limit=10))
# Out:
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                            aten::matmul         6.27%       1.083ms        26.63%       4.596ms      82.071us       0.000us         0.00%       3.051ms      54.486us            56
#                                            aten::linear         1.90%     327.221us        20.74%       3.579ms      71.585us       0.000us         0.00%       2.342ms      46.840us            50
#                                                aten::mm         9.42%       1.626ms        13.86%       2.393ms      49.847us       2.318ms        41.01%       2.318ms      48.296us            48
#                                  ampere_sgemm_32x128_tn         0.00%       0.000us         0.00%       0.000us       0.000us     823.805us        14.57%     823.805us      45.767us            18
#                                            aten::conv2d         0.94%     161.857us        10.01%       1.727ms     287.906us       0.000us         0.00%     612.479us     102.080us             6
#                                       aten::convolution         0.32%      54.740us         9.07%       1.566ms     260.930us       0.000us         0.00%     612.479us     102.080us             6
#                                      aten::_convolution         1.15%     198.387us         8.75%       1.511ms     251.807us       0.000us         0.00%     612.479us     102.080us             6
#                                 aten::cudnn_convolution         5.62%     970.340us         7.23%       1.247ms     207.813us     597.599us        10.57%     597.599us      99.600us             6
#                                               aten::bmm         1.70%     292.838us         2.14%     368.805us      46.101us     567.293us        10.04%     567.293us      70.912us             8
#                                               aten::add         3.13%     539.559us         4.89%     843.807us      24.818us     514.971us         9.11%     514.971us      15.146us            34
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 17.257ms
# Self CUDA time total: 5.653ms

# %%
save_path = "HoViTdrop_44_tinyfusion_base_r16a32.pth"
torch.save(model.state_dict(), save_path)
print(f"Model weights saved to {save_path}")
# Out:
# Model weights saved to HoViTdrop_44_tinyfusion_base_r16a32.pth

# %%
from sklearn.metrics import f1_score, recall_score, precision_score, roc_curve, auc

def score_evaluate(model, data_loader, criterion, device, phase="Validation"):
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0

    all_labels = []
    all_preds = []

    with torch.no_grad():
        for inputs, labels in tqdm(data_loader, desc=f"{phase}"):
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs, tau=0.1)
            loss = criterion(outputs, labels)

            running_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(predicted.cpu().numpy())

    overall_f1 = f1_score(all_labels, all_preds, average="macro")
    overall_recall = recall_score(all_labels, all_preds, average="macro")
    overall_precision = precision_score(all_labels, all_preds, average="macro")

    f1_per_class = f1_score(all_labels, all_preds, average=None)
    recall_per_class = recall_score(all_labels, all_preds, average=None)
    precision_per_class = precision_score(all_labels, all_preds, average=None)
    class_labels = sorted(set(all_labels))

    epoch_loss = running_loss / len(data_loader)
    accuracy = 100 * correct / total
    print(f"{phase} Loss: {epoch_loss:.4f}, {phase} Accuracy: {accuracy:.2f}%")
    val_losses.append(epoch_loss)
    val_accuracies.append(accuracy)

    print(f"Overall - F1: {overall_f1:.4f}, Recall: {overall_recall:.4f}, Precision: {overall_precision:.4f}")
    print("Per-Class Metrics:")
    for i, label in enumerate(class_labels):
        print(f"Class {label} - F1: {f1_per_class[i]:.4f}, Recall: {recall_per_class[i]:.4f}, Precision: {precision_per_class[i]:.4f}")

    return overall_f1, overall_recall, overall_precision, f1_per_class, recall_per_class, precision_per_class

# %%
from sklearn.preprocessing import label_binarize

def roc_auc(model, data_loader, device, num_classes):

    y = ["F1", "Precision", "Recall"]

    model.eval()
    all_labels = []
    all_scores = []

    with torch.no_grad():
        for inputs, labels in tqdm(data_loader, desc="ROC AUC"):
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)
            all_labels.extend(labels.cpu().numpy())
            all_scores.extend(outputs.cpu().numpy())

    all_labels = label_binarize(all_labels, classes=list(range(num_classes)))
    print(f"Binarized all_labels shape: {all_labels.shape}")
    print(f"All_scores shape: {np.array(all_scores).shape}")

    fpr, tpr, _ = roc_curve(all_labels.ravel(), np.array(all_scores).ravel())
    roc_auc_value = auc(fpr, tpr)

    plt.figure(figsize=(9, 7))
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc_value:0.4f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend(loc="lower right")
    plt.show()

    print(f"Overall ROC AUC: {roc_auc_value:.4f}")

    return fpr, tpr, roc_auc_value

# %%
overall_f1, overall_recall, overall_precision, f1_per_class, recall_per_class, precision_per_class = score_evaluate(model, test_loader, criterion, device, phase="Test")
# Out:
# Test: 100%|██████████| 469/469 [00:06<00:00, 68.67it/s]
# Test Loss: 0.1535, Test Accuracy: 96.95%
# Overall - F1: 0.9696, Recall: 0.9702, Precision: 0.9693
# Per-Class Metrics:
# Class 0 - F1: 0.9914, Recall: 0.9930, Precision: 0.9898
# Class 1 - F1: 0.9940, Recall: 0.9912, Precision: 0.9968
# Class 2 - F1: 0.9380, Recall: 0.9155, Precision: 0.9617
# Class 3 - F1: 0.9971, Recall: 0.9954, Precision: 0.9988
# Class 4 - F1: 0.9722, Recall: 0.9700, Precision: 0.9744
# Class 5 - F1: 0.9698, Recall: 0.9744, Precision: 0.9653
# Class 6 - F1: 0.9665, Recall: 0.9772, Precision: 0.9561
# Class 7 - F1: 0.9292, Recall: 0.9585, Precision: 0.9016
# Class 8 - F1: 0.9680, Recall: 0.9571, Precision: 0.9790

# %%
x = ["ADI", "BACK", "DEB", "LYM", "MUC", "MUS", "NORM", 'STR', "TUM"]
y = ["F1", "Precision", "Recall"]

f1_score_list = []
precision_score_list = []
recall_score_list = []

for i, class_name in enumerate(x):
    f1_score_list.append(f1_per_class[i])
    precision_score_list.append(precision_per_class[i])
    recall_score_list.append(recall_per_class[i])

x.append("Overall")
f1_score_list.append(overall_f1)
precision_score_list.append(overall_precision)
recall_score_list.append(overall_recall)

score_list = [f1_score_list, precision_score_list, recall_score_list]
score_list = np.array(score_list)
plt.figure(figsize=(20, 12))
score_cm = plt.matshow(score_list, cmap=plt.cm.Blues, alpha=0.3)
plt.xticks(range(len(x)), x)
plt.yticks(range(len(y)), y)
for i in range(len(y)):
    for j in range(len(x)):
        # 행렬의 각각의 수치를 각 칸의 중앙에 넣어준다
        plt.text(x=j, y=i,
                     s="{:.2f}".format(score_list[i, j]),
                     va='center',
                     ha='center',
                     )
